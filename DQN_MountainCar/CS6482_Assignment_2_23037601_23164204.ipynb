# %% [markdown]
# ### Student Name : SAJIN MOHAMED PALLIKKATHODI ERATHALI
# ### Student Id : 23037601
# ### Student Name : AKSHATA BHEEMASAMUDRA MALLIKARJUNAPPA
# ### Student Id : 23164204

# %% [markdown]
# ## The code executes completely without any error. We have implemented 4 versions of Deep Q Network.
# 1. Vanilla DQN [Section 4]
# 2. Fixed DQN [Section 5]
# 3. Double DQN [Section 6]
# 4. Double DQN with Double Q Learning(Coin Flip Approach) [Section 7]

# %% [markdown]
# # The following are some of the implementations we have adopted to obtain the results.
# 1. Github:nitish-kalan. (2023). MountainCar-v0-Deep-Q-Learning-DQN-Keras: train_model.py. [Online]. Available at: https://github.com/nitish-kalan/MountainCar-v0-Deep-Q-Learning-DQN-Keras/blob/master/train_model.py [Accessed: 25 March, 2024].
# 2. Kaggle. (2020). Core SP20 RL Notebook. [Online]. Available at: https://www.kaggle.com/code/ucfaibot/core-sp20-rl/notebook [Accessed: 19 March, 2024].
# 3. Kaggle. (2020). Mountain Car is a Classic Reinforcement Learning Problem Notebook. [Online]. Available at: https://www.kaggle.com/code/rezafazel63/mountain-car-is-a-classic-reinforcement-learning/notebook [Accessed: 20 March, 2024].
# 4. Github:pylSER. (2021). Deep-Reinforcement-learning-Mountain-Car: MountainCarV2.py. [Online]. Available at: https://github.com/pylSER/Deep-Reinforcement-learning-Mountain-Car/blob/master/MountainCarV2.py [Accessed: 27 March, 2024].
# 5. rlpy. (2022). MountainCar.py. [Online]. Available at: https://github.com/rlpy/rlpy/blob/master/rlpy/Domains/MountainCar.py [Accessed: April 1, 2024].

# %% [markdown]
# # 1. Vanilla DQN [Section 4]

# %%
# Installing gym environment version 0.21.0
# !pip install 'gym [atari,accept-rom-license]==0.21.0'
# Out:
# Requirement already satisfied: gym[accept-rom-license,atari]==0.21.0 in /Users/Sajin/MultiPDFchatMistral-7B/myenv/lib/python3.10/site-packages (0.21.0)
# Requirement already satisfied: numpy>=1.18.0 in /Users/Sajin/MultiPDFchatMistral-7B/myenv/lib/python3.10/site-packages (from gym[accept-rom-license,atari]==0.21.0) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/Sajin/MultiPDFchatMistral-7B/myenv/lib/python3.10/site-packages (from gym[accept-rom-license,atari]==0.21.0) (3.0.0)
# Requirement already satisfied: ale-py~=0.7.1 in /Users/Sajin/MultiPDFchatMistral-7B/myenv/lib/python3.10/site-packages (from gym[accept-rom-license,atari]==0.21.0) (0.7.5)
# Requirement already satisfied: autorom[accept-rom-license]~=0.4.2 in /Users/Sajin/MultiPDFchatMistral-7B/myenv/lib/python3.10/site-packages (from gym[accept-rom-license,atari]==0.21.0) (0.4.2)
# Requirement already satisfied: importlib-resources in /Users/Sajin/MultiPDFchatMistral-7B/myenv/lib/python3.10/site-packages (from ale-py~=0.7.1->gym[accept-rom-license,atari]==0.21.0) (6.4.0)
# Requirement already satisfied: requests in /Users/Sajin/MultiPDFchatMistral-7B/myenv/lib/python3.10/site-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]==0.21.0) (2.31.0)
# Requirement already satisfied: tqdm in /Users/Sajin/MultiPDFchatMistral-7B/myenv/lib/python3.10/site-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]==0.21.0) (4.66.2)
# Requirement already satisfied: click in /Users/Sajin/MultiPDFchatMistral-7B/myenv/lib/python3.10/site-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]==0.21.0) (8.1.7)
# Requirement already satisfied: AutoROM.accept-rom-license in /Users/Sajin/MultiPDFchatMistral-7B/myenv/lib/python3.10/site-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]==0.21.0) (0.6.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Sajin/MultiPDFchatMistral-7B/myenv/lib/python3.10/site-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]==0.21.0) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Sajin/MultiPDFchatMistral-7B/myenv/lib/python3.10/site-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]==0.21.0) (2024.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/Sajin/MultiPDFchatMistral-7B/myenv/lib/python3.10/site-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]==0.21.0) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/Sajin/MultiPDFchatMistral-7B/myenv/lib/python3.10/site-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]==0.21.0) (2.2.1)
#
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Importing packages and libraries

# %%
import os
os.environ['SDL_VIDEODRIVER'] = 'dummy'
import gym
import matplotlib.animation
import matplotlib.pyplot as plt
import numpy as np
import pygame
from packaging import version
import tensorflow as tf
assert version.parse(tf.__version__) >= version.parse("2.15.0")

import random
from collections import deque
# Out:
# c:\Users\91776\Desktop\Masters\UL\Modules\RL\venv\lib\site-packages\tensorflow\__init__.py:30: DeprecationWarning: The distutils package is deprecated and slated for removal in Python 3.12. Use setuptools or check PEP 632 for potential alternatives
#   import distutils as _distutils

# %%
random.seed(2212)
np.random.seed(2212)
tf.random.set_seed(2212)

# %% [markdown]
# ## Hyperparameters [Section 3]

# %%
# The number of sequential interacgtions the car has with its environment.
EPISODES = 600
# The size of the experience replay (section ---)
REPLAY_MEMORY_SIZE = 1_00_000
# Minimum size of experience replay required
MINIMUM_REPLAY_MEMORY = 1_000
# The number of sample we fetch from the experience replay during training
MINIBATCH_SIZE = 32
# The hyperparameter which balances exploration and exploitation by agent
EPSILON = 0.1
# The rate at which the epsilon decreases
EPSILON_DECAY = 0.99
MINIMUM_EPSILON = 0.001
# The discount factor which doiscunts future reward in favor of immediate reward (gamma)
DISCOUNT = 0.99
# The simulated environment used by the agent (car)
ENV_NAME = 'MountainCar-v0'

# %% [markdown]
# ## Defining environment [Section 2]

# %%
# creates an environment
env = gym.make(ENV_NAME)
# Returns dimensionality of action space (0-> push left, 1-> no acceleration, 2-> push right)
action_dim = env.action_space.n
# Returns dimensionality of observation space (position [-1.2, 0.6], velocity[-0.07,0.07])
observation_dim = env.observation_space.shape

# %% [markdown]
# ## Defining Deep Q Network model [Section 3.5 and Section 4.3]

# %% [markdown]
# A sequential model with 400 input neurons and 300 neurons in the hidden layer and 3 in the output layer

# %%
# Creating simple sequential neural network model with 3 layers (400, 300, 2)
model = tf.keras.Sequential([
    tf.keras.layers.Dense(400, activation='relu', input_shape=observation_dim),
    tf.keras.layers.Dense(300, activation='relu'),
    tf.keras.layers.Dense(action_dim, activation='linear')
])

'''Compiling the neural network using Mean Square Error as loss function and
Adam as the optimizer which will learn at a rate of 0.005'''
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(learning_rate=0.005))

# %% [markdown]
# ## Defining Epsilon greedy policy [section 3.1]

# %%
'''Defining epsilon greedy policy function to determine an action
to decide whether to explore or exploit the knowledge acquired'''
def epsilon_greedy_policy(state, epsilon):
    # Explore if random value from uniform distribution is less than exploration factor epsilon
    if np.random.uniform(0, 1) < epsilon:
        action = np.random.randint(0, action_dim)
        return action
    else:
    # Exploit
        action = np.argmax(model.predict(np.expand_dims(state, axis=0), verbose=0)[0])
        return action

# %% [markdown]
# ## Defining the sample experience [Section 4.1.1]

# %%
# Replay memory (experience replay) to store experiances of the model with the environment
replay_buffer = deque(maxlen=REPLAY_MEMORY_SIZE)

'''This function samples a minibatch of experiences from the replay buffer for training the model.'''
def sample_experience(MINIBATCH_SIZE):
    # random sampling  batch size(32) number of values from the replay buffer
    minibatch = random.sample(replay_buffer, MINIBATCH_SIZE)
    # list to store the current state
    X_cur_states = []
    # list to store the next state
    X_next_states = []

    # populating the current and next states list
    for index, sample in enumerate(minibatch):
        cur_state, action, reward, next_state, done = sample
        X_cur_states.append(cur_state)
        X_next_states.append(next_state)

    # converting into arrays
    X_cur_states = np.array(X_cur_states)
    X_next_states = np.array(X_next_states)
    return minibatch,X_cur_states,X_next_states

# %% [markdown]
# ## Defining the step function [Section 4]

# %%
max_reward = -999999


'''This function defines the steps the agent has to take based on the epsilon greedy policy
 and accumulates the reward'''
def play_one_step(env, state, epsilon, episode_length):
    # defining reward acquired in each episode
    global episode_reward
    # Calling epsilon greedy function to select action
    action = epsilon_greedy_policy(state, epsilon)
    # Executing the action and returns 4 values
    next_state, reward, done, info = env.step(action)
    # accumulating rewards in each step of the epsiode(max=-200)
    episode_reward += reward
    # truncating if the car reaches the flag on the mountain top within 200 steps
    if done and episode_length < 200:
        # If episode is ended then we have won the game. Defining Stratagem to make the agent learn faster
        reward = 250 + episode_reward
        # save the model weights if we get a epsiode reward greater than maximum reward defined
        if(episode_reward > max_reward):
            print("Saving the model with reward", episode_reward)
            model.save_weights("agent"+str(episode_reward)+"_agent_.weights.h5")
    else:
        # In oher cases reward will be proportional to the distance that car has travelled
        # from it's previous location + velocity of the car
        reward = 5*abs(next_state[0] - state[0]) + 3*abs(state[1])

    # append this result to the replay buffer(experince replay)
    replay_buffer.append((state, action, reward, next_state, done))

    return next_state, episode_reward, max_reward, done, info

# %% [markdown]
# ## Defining the training function [Section 4.1]

# %%
rewards = []
'''The function creates and updates the q table and updates the model weights based on the Bellman's equation'''
def training_step(MINIBATCH_SIZE):
    # retrieving the array of values from the replay buffer
    minibatch, X_cur_states, X_next_states = sample_experience(MINIBATCH_SIZE)
    # predict state action values
    cur_action_values = model.predict(X_cur_states, verbose=0)

    # action values for the next_states taken from our agent (Q network)
    next_action_values = model.predict(X_next_states, verbose=0)

    for index, sample in enumerate(minibatch):

        cur_state, action, reward, next_state, done = sample
        # estimate the optimal state action values
        if not done:
            # Bellman's optimality equation
            '''A way to estimate the optimal state value of any state s(Q(st, at)) = sum of all discounted future rewards the agent can expect on average after it reaches a state s, assuming it acts optimally'''
            # Q(st, at) = reward + DISCOUNT * max(Q(s(t+1), a(t+1)))
            cur_action_values[index][action] = reward + DISCOUNT * np.amax(next_action_values[index])
        else:
            # Q(st, at) = reward
            cur_action_values[index][action] = reward

    # train the agent with new Q values for the states and the actions
    model.fit(X_cur_states, cur_action_values, verbose=0)

# %% [markdown]
# ## Running the episodes

# %%
# Looping through episodes
for episode in range(EPISODES):
    # resetting the environment for the state to be reset
    state = env.reset()
    # initializing variables used
    done = False
    episode_reward = 0
    episode_length = 0

    # Running through different sets of steps
    while not done:
        # incrementing episode length(number of steps)
        episode_length += 1
        # calling the play_one_step function to execute the steps
        next_state, reward, max_reward, done, info  = play_one_step(env,state, EPSILON, episode_length)
        # update the current state with the next state for the episode to continue
        state = next_state

        # Checking if the replay buffer size is less than the minimum required replay buffer size for training to start
        if(len(replay_buffer) < MINIMUM_REPLAY_MEMORY):
            continue
        # when the minimum replay buffer size is populated
        training_step(MINIBATCH_SIZE)


    # recording the values for visualizing the results
    max_reward = max(reward, max_reward)
    print('Episode', episode, 'Episodic Reward', reward, 'Maximum Reward', max_reward, 'EPSILON', EPSILON)
    rewards.append(reward)

    # Epsilon decay for the next episode
    if(EPSILON > MINIMUM_EPSILON and len(replay_buffer) > MINIMUM_REPLAY_MEMORY):
        EPSILON *= EPSILON_DECAY
# Out:
# Episode 0 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.1
# Episode 1 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.1
# Episode 2 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.1
# Episode 3 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.1
# Episode 4 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.1
# Episode 5 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.1
# Episode 6 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.099
# Episode 7 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.09801
# Episode 8 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.0970299
# Episode 9 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.096059601
# Episode 10 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.09509900499
# Episode 11 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.0941480149401
# Episode 12 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.093206534790699
# Episode 13 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.09227446944279201
# Episode 14 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.09135172474836409
# Episode 15 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.09043820750088044
# Episode 16 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.08953382542587164
# Episode 17 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.08863848717161292
# Episode 18 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.08775210229989679
# Episode 19 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.08687458127689782
# Episode 20 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.08600583546412884
# Episode 21 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.08514577710948755
# Episode 22 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.08429431933839267
# Episode 23 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.08345137614500873
# Episode 24 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.08261686238355864
# Episode 25 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.08179069375972306
# Episode 26 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.08097278682212583
# Saving the model with reward -199.0
# Episode 27 Episodic Reward -199.0 Maximum Reward -199.0 EPSILON 0.08016305895390458
# Episode 28 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.07936142836436554
# Episode 29 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.07856781408072187
# Episode 30 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.07778213593991465
# Episode 31 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.0770043145805155
# Episode 32 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.07623427143471034
# Episode 33 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.07547192872036323
# Episode 34 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.0747172094331596
# Episode 35 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.073970037338828
# Episode 36 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.07323033696543972
# Episode 37 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.07249803359578533
# Episode 38 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.07177305325982747
# Episode 39 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.0710553227272292
# Episode 40 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.07034476949995691
# Episode 41 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.06964132180495734
# Episode 42 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.06894490858690777
# Episode 43 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.06825545950103869
# Episode 44 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.0675729049060283
# Episode 45 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.06689717585696801
# Episode 46 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.06622820409839833
# Episode 47 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.06556592205741435
# Episode 48 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.0649102628368402
# Episode 49 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.06426116020847181
# Episode 50 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.06361854860638709
# Episode 51 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.06298236312032322
# Episode 52 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.06235253948911999
# Episode 53 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.06172901409422879
# Episode 54 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.061111723953286505
# Episode 55 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.06050060671375364
# Episode 56 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.0598956006466161
# Episode 57 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.05929664464014994
# Episode 58 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.05870367819374844
# Episode 59 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.05811664141181096
# Episode 60 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.05753547499769285
# Episode 61 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.05696012024771592
# Episode 62 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.05639051904523876
# Episode 63 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.05582661385478637
# Episode 64 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.05526834771623851
# Episode 65 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.054715664239076124
# Episode 66 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.054168507596685365
# Episode 67 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.053626822520718515
# Episode 68 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.05309055429551133
# Episode 69 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.05255964875255621
# Episode 70 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.05203405226503065
# Episode 71 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.05151371174238034
# Episode 72 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.050998574624956536
# Episode 73 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.05048858887870697
# Episode 74 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.0499837029899199
# Episode 75 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.049483865960020704
# Episode 76 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.0489890273004205
# Episode 77 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.048499137027416296
# Episode 78 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.048014145657142134
# Episode 79 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.04753400420057071
# Episode 80 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.047058664158565
# Episode 81 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.046588077516979354
# Episode 82 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.04612219674180956
# Episode 83 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.04566097477439147
# Episode 84 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.045204365026647556
# Episode 85 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.04475232137638108
# Episode 86 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.044304798162617266
# Episode 87 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.043861750180991095
# Episode 88 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.04342313267918119
# Episode 89 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.04298890135238938
# Episode 90 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.042559012338865485
# Episode 91 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.04213342221547683
# Episode 92 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.04171208799332206
# Episode 93 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.041294967113388835
# Episode 94 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.04088201744225495
# Episode 95 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.0404731972678324
# Episode 96 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.04006846529515407
# Episode 97 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.039667780642202534
# Episode 98 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.03927110283578051
# Episode 99 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.0388783918074227
# Episode 100 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.03848960788934848
# Episode 101 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.038104711810454994
# Episode 102 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.037723664692350445
# Episode 103 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.03734642804542694
# Episode 104 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.03697296376497267
# Episode 105 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.03660323412732295
# Episode 106 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.03623720178604972
# Episode 107 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.035874829768189224
# Episode 108 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.03551608147050733
# Episode 109 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.03516092065580226
# Episode 110 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.034809311449244235
# Episode 111 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.03446121833475179
# Episode 112 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.03411660615140427
# Episode 113 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.03377544008989023
# Episode 114 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.03343768568899133
# Episode 115 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.03310330883210142
# Episode 116 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.03277227574378041
# Episode 117 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.032444552986342606
# Episode 118 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.03212010745647918
# Episode 119 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.03179890638191439
# Episode 120 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.03148091731809525
# Episode 121 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.031166108144914297
# Episode 122 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.030854447063465153
# Episode 123 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.030545902592830503
# Episode 124 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.030240443566902198
# Episode 125 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.029938039131233177
# Episode 126 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.029638658739920845
# Episode 127 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.029342272152521637
# Episode 128 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.02904884943099642
# Episode 129 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.028758360936686458
# Episode 130 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.028470777327319594
# Episode 131 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.028186069554046397
# Episode 132 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.027904208858505933
# Episode 133 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.027625166769920873
# Episode 134 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.027348915102221663
# Episode 135 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.027075425951199446
# Episode 136 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.026804671691687453
# Episode 137 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.02653662497477058
# Episode 138 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.026271258725022874
# Episode 139 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.026008546137772644
# Episode 140 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.025748460676394917
# Episode 141 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.025490976069630966
# Episode 142 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.025236066308934657
# Episode 143 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.02498370564584531
# Episode 144 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.024733868589386858
# Episode 145 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.02448652990349299
# Episode 146 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.02424166460445806
# Episode 147 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.02399924795841348
# Episode 148 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.023759255478829344
# Episode 149 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.02352166292404105
# Episode 150 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.02328644629480064
# Episode 151 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.023053581831852635
# Episode 152 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.022823046013534107
# Episode 153 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.022594815553398765
# Episode 154 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.022368867397864776
# Episode 155 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.02214517872388613
# Episode 156 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.021923726936647268
# Episode 157 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.021704489667280794
# Episode 158 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.021487444770607985
# Episode 159 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.021272570322901904
# Episode 160 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.021059844619672884
# Episode 161 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.020849246173476155
# Episode 162 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.020640753711741393
# Episode 163 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.020434346174623978
# Episode 164 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.020230002712877736
# Episode 165 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.02002770268574896
# Episode 166 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.01982742565889147
# Episode 167 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.019629151402302553
# Episode 168 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.019432859888279527
# Episode 169 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.019238531289396732
# Episode 170 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.019046145976502765
# Episode 171 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.018855684516737737
# Episode 172 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.01866712767157036
# Episode 173 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.018480456394854655
# Episode 174 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.018295651830906107
# Episode 175 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.018112695312597047
# Episode 176 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.017931568359471076
# Episode 177 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.017752252675876365
# Episode 178 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.0175747301491176
# Episode 179 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.017398982847626424
# Episode 180 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.01722499301915016
# Episode 181 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.01705274308895866
# Episode 182 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.01688221565806907
# Episode 183 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.01671339350148838
# Episode 184 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.016546259566473494
# Episode 185 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.01638079697080876
# Episode 186 Episodic Reward -200.0 Maximum Reward -199.0 EPSILON 0.016216989001100673
# Saving the model with reward -152.0
# Episode 187 Episodic Reward -152.0 Maximum Reward -152.0 EPSILON 0.016054819111089667
# Episode 188 Episodic Reward -200.0 Maximum Reward -152.0 EPSILON 0.01589427091997877
# Episode 189 Episodic Reward -170.0 Maximum Reward -152.0 EPSILON 0.01573532821077898
# Episode 190 Episodic Reward -200.0 Maximum Reward -152.0 EPSILON 0.015577974928671192
# Episode 191 Episodic Reward -200.0 Maximum Reward -152.0 EPSILON 0.01542219517938448
# Episode 192 Episodic Reward -200.0 Maximum Reward -152.0 EPSILON 0.015267973227590634
# Episode 193 Episodic Reward -200.0 Maximum Reward -152.0 EPSILON 0.015115293495314729
# Episode 194 Episodic Reward -200.0 Maximum Reward -152.0 EPSILON 0.01496414056036158
# Episode 195 Episodic Reward -200.0 Maximum Reward -152.0 EPSILON 0.014814499154757965
# Episode 196 Episodic Reward -200.0 Maximum Reward -152.0 EPSILON 0.014666354163210386
# Episode 197 Episodic Reward -181.0 Maximum Reward -152.0 EPSILON 0.014519690621578282
# Episode 198 Episodic Reward -194.0 Maximum Reward -152.0 EPSILON 0.014374493715362499
# Episode 199 Episodic Reward -183.0 Maximum Reward -152.0 EPSILON 0.014230748778208874
# Episode 200 Episodic Reward -180.0 Maximum Reward -152.0 EPSILON 0.014088441290426785
# Episode 201 Episodic Reward -200.0 Maximum Reward -152.0 EPSILON 0.013947556877522518
# Episode 202 Episodic Reward -168.0 Maximum Reward -152.0 EPSILON 0.013808081308747293
# Saving the model with reward -146.0
# Episode 203 Episodic Reward -146.0 Maximum Reward -146.0 EPSILON 0.01367000049565982
# Episode 204 Episodic Reward -200.0 Maximum Reward -146.0 EPSILON 0.013533300490703223
# Episode 205 Episodic Reward -200.0 Maximum Reward -146.0 EPSILON 0.01339796748579619
# Episode 206 Episodic Reward -200.0 Maximum Reward -146.0 EPSILON 0.013263987810938228
# Episode 207 Episodic Reward -181.0 Maximum Reward -146.0 EPSILON 0.013131347932828845
# Episode 208 Episodic Reward -175.0 Maximum Reward -146.0 EPSILON 0.013000034453500557
# Episode 209 Episodic Reward -200.0 Maximum Reward -146.0 EPSILON 0.01287003410896555
# Episode 210 Episodic Reward -175.0 Maximum Reward -146.0 EPSILON 0.012741333767875895
# Episode 211 Episodic Reward -200.0 Maximum Reward -146.0 EPSILON 0.012613920430197136
# Episode 212 Episodic Reward -200.0 Maximum Reward -146.0 EPSILON 0.012487781225895164
# Episode 213 Episodic Reward -200.0 Maximum Reward -146.0 EPSILON 0.012362903413636212
# Episode 214 Episodic Reward -200.0 Maximum Reward -146.0 EPSILON 0.01223927437949985
# Episode 215 Episodic Reward -200.0 Maximum Reward -146.0 EPSILON 0.012116881635704851
# Episode 216 Episodic Reward -200.0 Maximum Reward -146.0 EPSILON 0.011995712819347802
# Episode 217 Episodic Reward -200.0 Maximum Reward -146.0 EPSILON 0.011875755691154323
# Episode 218 Episodic Reward -200.0 Maximum Reward -146.0 EPSILON 0.01175699813424278
# Episode 219 Episodic Reward -200.0 Maximum Reward -146.0 EPSILON 0.011639428152900352
# Episode 220 Episodic Reward -200.0 Maximum Reward -146.0 EPSILON 0.011523033871371349
# Episode 221 Episodic Reward -161.0 Maximum Reward -146.0 EPSILON 0.011407803532657634
# Saving the model with reward -140.0
# Episode 222 Episodic Reward -140.0 Maximum Reward -140.0 EPSILON 0.011293725497331058
# Saving the model with reward -126.0
# Episode 223 Episodic Reward -126.0 Maximum Reward -126.0 EPSILON 0.011180788242357747
# Episode 224 Episodic Reward -200.0 Maximum Reward -126.0 EPSILON 0.01106898035993417
# Episode 225 Episodic Reward -190.0 Maximum Reward -126.0 EPSILON 0.010958290556334828
# Episode 226 Episodic Reward -200.0 Maximum Reward -126.0 EPSILON 0.01084870765077148
# Episode 227 Episodic Reward -165.0 Maximum Reward -126.0 EPSILON 0.010740220574263765
# Episode 228 Episodic Reward -200.0 Maximum Reward -126.0 EPSILON 0.010632818368521127
# Episode 229 Episodic Reward -200.0 Maximum Reward -126.0 EPSILON 0.010526490184835915
# Episode 230 Episodic Reward -200.0 Maximum Reward -126.0 EPSILON 0.010421225282987556
# Episode 231 Episodic Reward -200.0 Maximum Reward -126.0 EPSILON 0.01031701303015768
# Episode 232 Episodic Reward -200.0 Maximum Reward -126.0 EPSILON 0.010213842899856104
# Episode 233 Episodic Reward -200.0 Maximum Reward -126.0 EPSILON 0.010111704470857543
# Episode 234 Episodic Reward -148.0 Maximum Reward -126.0 EPSILON 0.010010587426148968
# Episode 235 Episodic Reward -200.0 Maximum Reward -126.0 EPSILON 0.009910481551887479
# Episode 236 Episodic Reward -198.0 Maximum Reward -126.0 EPSILON 0.009811376736368603
# Episode 237 Episodic Reward -200.0 Maximum Reward -126.0 EPSILON 0.009713262969004917
# Episode 238 Episodic Reward -200.0 Maximum Reward -126.0 EPSILON 0.009616130339314867
# Episode 239 Episodic Reward -144.0 Maximum Reward -126.0 EPSILON 0.009519969035921718
# Episode 240 Episodic Reward -200.0 Maximum Reward -126.0 EPSILON 0.009424769345562502
# Episode 241 Episodic Reward -154.0 Maximum Reward -126.0 EPSILON 0.009330521652106877
# Episode 242 Episodic Reward -164.0 Maximum Reward -126.0 EPSILON 0.009237216435585808
# Episode 243 Episodic Reward -200.0 Maximum Reward -126.0 EPSILON 0.009144844271229951
# Episode 244 Episodic Reward -196.0 Maximum Reward -126.0 EPSILON 0.00905339582851765
# Episode 245 Episodic Reward -200.0 Maximum Reward -126.0 EPSILON 0.008962861870232474
# Episode 246 Episodic Reward -200.0 Maximum Reward -126.0 EPSILON 0.008873233251530149
# Episode 247 Episodic Reward -200.0 Maximum Reward -126.0 EPSILON 0.008784500919014848
# Episode 248 Episodic Reward -156.0 Maximum Reward -126.0 EPSILON 0.0086966559098247
# Episode 249 Episodic Reward -200.0 Maximum Reward -126.0 EPSILON 0.008609689350726452
# Episode 250 Episodic Reward -200.0 Maximum Reward -126.0 EPSILON 0.008523592457219188
# Episode 251 Episodic Reward -200.0 Maximum Reward -126.0 EPSILON 0.008438356532646995
# Episode 252 Episodic Reward -200.0 Maximum Reward -126.0 EPSILON 0.008353972967320525
# Episode 253 Episodic Reward -200.0 Maximum Reward -126.0 EPSILON 0.00827043323764732
# Saving the model with reward -121.0
# Episode 254 Episodic Reward -121.0 Maximum Reward -121.0 EPSILON 0.008187728905270846
# Episode 255 Episodic Reward -200.0 Maximum Reward -121.0 EPSILON 0.008105851616218138
# Episode 256 Episodic Reward -153.0 Maximum Reward -121.0 EPSILON 0.008024793100055957
# Episode 257 Episodic Reward -180.0 Maximum Reward -121.0 EPSILON 0.007944545169055397
# Episode 258 Episodic Reward -164.0 Maximum Reward -121.0 EPSILON 0.007865099717364843
# Episode 259 Episodic Reward -200.0 Maximum Reward -121.0 EPSILON 0.0077864487201911945
# Episode 260 Episodic Reward -194.0 Maximum Reward -121.0 EPSILON 0.0077085842329892825
# Episode 261 Episodic Reward -189.0 Maximum Reward -121.0 EPSILON 0.00763149839065939
# Episode 262 Episodic Reward -200.0 Maximum Reward -121.0 EPSILON 0.0075551834067527955
# Saving the model with reward -114.0
# Episode 263 Episodic Reward -114.0 Maximum Reward -114.0 EPSILON 0.007479631572685268
# Episode 264 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.007404835256958415
# Episode 265 Episodic Reward -163.0 Maximum Reward -114.0 EPSILON 0.007330786904388831
# Episode 266 Episodic Reward -138.0 Maximum Reward -114.0 EPSILON 0.007257479035344943
# Episode 267 Episodic Reward -138.0 Maximum Reward -114.0 EPSILON 0.007184904244991494
# Episode 268 Episodic Reward -152.0 Maximum Reward -114.0 EPSILON 0.007113055202541579
# Episode 269 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.007041924650516163
# Episode 270 Episodic Reward -165.0 Maximum Reward -114.0 EPSILON 0.006971505404011002
# Episode 271 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.006901790349970892
# Episode 272 Episodic Reward -159.0 Maximum Reward -114.0 EPSILON 0.006832772446471183
# Episode 273 Episodic Reward -158.0 Maximum Reward -114.0 EPSILON 0.006764444722006471
# Episode 274 Episodic Reward -172.0 Maximum Reward -114.0 EPSILON 0.006696800274786406
# Episode 275 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.006629832272038541
# Episode 276 Episodic Reward -159.0 Maximum Reward -114.0 EPSILON 0.006563533949318156
# Episode 277 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.006497898609824975
# Episode 278 Episodic Reward -158.0 Maximum Reward -114.0 EPSILON 0.006432919623726724
# Episode 279 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.006368590427489457
# Episode 280 Episodic Reward -185.0 Maximum Reward -114.0 EPSILON 0.006304904523214563
# Episode 281 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.006241855477982417
# Episode 282 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.0061794369232025925
# Episode 283 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.006117642553970567
# Episode 284 Episodic Reward -135.0 Maximum Reward -114.0 EPSILON 0.006056466128430861
# Saving the model with reward -95.0
# Episode 285 Episodic Reward -95.0 Maximum Reward -95.0 EPSILON 0.005995901467146553
# Episode 286 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.005935942452475087
# Episode 287 Episodic Reward -157.0 Maximum Reward -95.0 EPSILON 0.005876583027950337
# Episode 288 Episodic Reward -144.0 Maximum Reward -95.0 EPSILON 0.005817817197670833
# Episode 289 Episodic Reward -173.0 Maximum Reward -95.0 EPSILON 0.005759639025694124
# Episode 290 Episodic Reward -115.0 Maximum Reward -95.0 EPSILON 0.005702042635437183
# Episode 291 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.005645022209082811
# Episode 292 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0055885719869919834
# Episode 293 Episodic Reward -139.0 Maximum Reward -95.0 EPSILON 0.005532686267122063
# Episode 294 Episodic Reward -124.0 Maximum Reward -95.0 EPSILON 0.005477359404450843
# Episode 295 Episodic Reward -119.0 Maximum Reward -95.0 EPSILON 0.005422585810406335
# Episode 296 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.005368359952302271
# Episode 297 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0053146763527792485
# Episode 298 Episodic Reward -169.0 Maximum Reward -95.0 EPSILON 0.005261529589251456
# Episode 299 Episodic Reward -139.0 Maximum Reward -95.0 EPSILON 0.0052089142933589416
# Episode 300 Episodic Reward -152.0 Maximum Reward -95.0 EPSILON 0.005156825150425352
# Episode 301 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.005105256898921099
# Episode 302 Episodic Reward -165.0 Maximum Reward -95.0 EPSILON 0.005054204329931888
# Episode 303 Episodic Reward -142.0 Maximum Reward -95.0 EPSILON 0.005003662286632569
# Episode 304 Episodic Reward -182.0 Maximum Reward -95.0 EPSILON 0.004953625663766243
# Episode 305 Episodic Reward -156.0 Maximum Reward -95.0 EPSILON 0.00490408940712858
# Episode 306 Episodic Reward -120.0 Maximum Reward -95.0 EPSILON 0.004855048513057294
# Episode 307 Episodic Reward -114.0 Maximum Reward -95.0 EPSILON 0.004806498027926721
# Episode 308 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.004758433047647454
# Episode 309 Episodic Reward -137.0 Maximum Reward -95.0 EPSILON 0.004710848717170979
# Episode 310 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.004663740229999269
# Episode 311 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.004617102827699277
# Episode 312 Episodic Reward -158.0 Maximum Reward -95.0 EPSILON 0.004570931799422284
# Episode 313 Episodic Reward -189.0 Maximum Reward -95.0 EPSILON 0.004525222481428061
# Episode 314 Episodic Reward -134.0 Maximum Reward -95.0 EPSILON 0.00447997025661378
# Episode 315 Episodic Reward -147.0 Maximum Reward -95.0 EPSILON 0.004435170554047642
# Episode 316 Episodic Reward -155.0 Maximum Reward -95.0 EPSILON 0.004390818848507166
# Episode 317 Episodic Reward -176.0 Maximum Reward -95.0 EPSILON 0.004346910660022094
# Episode 318 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.004303441553421873
# Episode 319 Episodic Reward -155.0 Maximum Reward -95.0 EPSILON 0.004260407137887654
# Episode 320 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.004217803066508778
# Episode 321 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.00417562503584369
# Episode 322 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.004133868785485253
# Episode 323 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.004092530097630401
# Episode 324 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.004051604796654096
# Episode 325 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.004011088748687555
# Episode 326 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.003970977861200679
# Episode 327 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.003931268082588672
# Episode 328 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0038919554017627853
# Episode 329 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0038530358477451574
# Episode 330 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.003814505489267706
# Episode 331 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.003776360434375029
# Episode 332 Episodic Reward -144.0 Maximum Reward -95.0 EPSILON 0.0037385968300312784
# Episode 333 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0037012108617309656
# Episode 334 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.003664198753113656
# Episode 335 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0036275567655825194
# Episode 336 Episodic Reward -141.0 Maximum Reward -95.0 EPSILON 0.003591281197926694
# Episode 337 Episodic Reward -188.0 Maximum Reward -95.0 EPSILON 0.003555368385947427
# Episode 338 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0035198147020879525
# Episode 339 Episodic Reward -188.0 Maximum Reward -95.0 EPSILON 0.003484616555067073
# Episode 340 Episodic Reward -155.0 Maximum Reward -95.0 EPSILON 0.003449770389516402
# Episode 341 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.003415272685621238
# Episode 342 Episodic Reward -144.0 Maximum Reward -95.0 EPSILON 0.003381119958765026
# Episode 343 Episodic Reward -173.0 Maximum Reward -95.0 EPSILON 0.0033473087591773757
# Episode 344 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.003313835671585602
# Episode 345 Episodic Reward -144.0 Maximum Reward -95.0 EPSILON 0.003280697314869746
# Episode 346 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.003247890341721049
# Episode 347 Episodic Reward -160.0 Maximum Reward -95.0 EPSILON 0.003215411438303838
# Episode 348 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0031832573239207996
# Episode 349 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0031514247506815914
# Episode 350 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0031199105031747753
# Episode 351 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0030887113981430277
# Episode 352 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0030578242841615972
# Episode 353 Episodic Reward -154.0 Maximum Reward -95.0 EPSILON 0.0030272460413199812
# Episode 354 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0029969735809067814
# Episode 355 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0029670038450977138
# Episode 356 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0029373338066467367
# Episode 357 Episodic Reward -181.0 Maximum Reward -95.0 EPSILON 0.0029079604685802694
# Episode 358 Episodic Reward -161.0 Maximum Reward -95.0 EPSILON 0.0028788808638944667
# Episode 359 Episodic Reward -154.0 Maximum Reward -95.0 EPSILON 0.002850092055255522
# Episode 360 Episodic Reward -159.0 Maximum Reward -95.0 EPSILON 0.002821591134702967
# Episode 361 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0027933752233559373
# Episode 362 Episodic Reward -176.0 Maximum Reward -95.0 EPSILON 0.002765441471122378
# Episode 363 Episodic Reward -149.0 Maximum Reward -95.0 EPSILON 0.002737787056411154
# Episode 364 Episodic Reward -111.0 Maximum Reward -95.0 EPSILON 0.0027104091858470426
# Episode 365 Episodic Reward -159.0 Maximum Reward -95.0 EPSILON 0.002683305093988572
# Episode 366 Episodic Reward -125.0 Maximum Reward -95.0 EPSILON 0.0026564720430486866
# Episode 367 Episodic Reward -169.0 Maximum Reward -95.0 EPSILON 0.0026299073226182
# Episode 368 Episodic Reward -174.0 Maximum Reward -95.0 EPSILON 0.0026036082493920178
# Episode 369 Episodic Reward -160.0 Maximum Reward -95.0 EPSILON 0.0025775721668980975
# Episode 370 Episodic Reward -179.0 Maximum Reward -95.0 EPSILON 0.0025517964452291164
# Episode 371 Episodic Reward -196.0 Maximum Reward -95.0 EPSILON 0.0025262784807768253
# Episode 372 Episodic Reward -117.0 Maximum Reward -95.0 EPSILON 0.0025010156959690572
# Episode 373 Episodic Reward -155.0 Maximum Reward -95.0 EPSILON 0.0024760055390093665
# Episode 374 Episodic Reward -173.0 Maximum Reward -95.0 EPSILON 0.002451245483619273
# Episode 375 Episodic Reward -135.0 Maximum Reward -95.0 EPSILON 0.0024267330287830804
# Episode 376 Episodic Reward -168.0 Maximum Reward -95.0 EPSILON 0.00240246569849525
# Episode 377 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.002378441041510297
# Episode 378 Episodic Reward -178.0 Maximum Reward -95.0 EPSILON 0.002354656631095194
# Episode 379 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.002331110064784242
# Episode 380 Episodic Reward -144.0 Maximum Reward -95.0 EPSILON 0.0023077989641364
# Episode 381 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.002284720974495036
# Episode 382 Episodic Reward -125.0 Maximum Reward -95.0 EPSILON 0.0022618737647500855
# Episode 383 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.002239255027102585
# Episode 384 Episodic Reward -194.0 Maximum Reward -95.0 EPSILON 0.002216862476831559
# Episode 385 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0021946938520632435
# Episode 386 Episodic Reward -180.0 Maximum Reward -95.0 EPSILON 0.002172746913542611
# Episode 387 Episodic Reward -173.0 Maximum Reward -95.0 EPSILON 0.0021510194444071848
# Episode 388 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.002129509249963113
# Episode 389 Episodic Reward -195.0 Maximum Reward -95.0 EPSILON 0.002108214157463482
# Episode 390 Episodic Reward -148.0 Maximum Reward -95.0 EPSILON 0.0020871320158888473
# Episode 391 Episodic Reward -150.0 Maximum Reward -95.0 EPSILON 0.0020662606957299588
# Episode 392 Episodic Reward -173.0 Maximum Reward -95.0 EPSILON 0.002045598088772659
# Episode 393 Episodic Reward -112.0 Maximum Reward -95.0 EPSILON 0.0020251421078849325
# Episode 394 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.002004890686806083
# Episode 395 Episodic Reward -141.0 Maximum Reward -95.0 EPSILON 0.001984841779938022
# Episode 396 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0019649933621386415
# Episode 397 Episodic Reward -108.0 Maximum Reward -95.0 EPSILON 0.001945343428517255
# Episode 398 Episodic Reward -163.0 Maximum Reward -95.0 EPSILON 0.0019258899942320826
# Episode 399 Episodic Reward -134.0 Maximum Reward -95.0 EPSILON 0.0019066310942897618
# Episode 400 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0018875647833468641
# Episode 401 Episodic Reward -156.0 Maximum Reward -95.0 EPSILON 0.0018686891355133954
# Episode 402 Episodic Reward -189.0 Maximum Reward -95.0 EPSILON 0.0018500022441582614
# Episode 403 Episodic Reward -164.0 Maximum Reward -95.0 EPSILON 0.0018315022217166787
# Episode 404 Episodic Reward -196.0 Maximum Reward -95.0 EPSILON 0.001813187199499512
# Episode 405 Episodic Reward -155.0 Maximum Reward -95.0 EPSILON 0.0017950553275045168
# Episode 406 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0017771047742294716
# Episode 407 Episodic Reward -142.0 Maximum Reward -95.0 EPSILON 0.001759333726487177
# Episode 408 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.001741740389222305
# Episode 409 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.001724322985330082
# Episode 410 Episodic Reward -176.0 Maximum Reward -95.0 EPSILON 0.0017070797554767812
# Episode 411 Episodic Reward -166.0 Maximum Reward -95.0 EPSILON 0.0016900089579220134
# Episode 412 Episodic Reward -195.0 Maximum Reward -95.0 EPSILON 0.0016731088683427933
# Episode 413 Episodic Reward -134.0 Maximum Reward -95.0 EPSILON 0.0016563777796593654
# Episode 414 Episodic Reward -155.0 Maximum Reward -95.0 EPSILON 0.0016398140018627717
# Episode 415 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.001623415861844144
# Episode 416 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0016071817032257026
# Episode 417 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0015911098861934455
# Episode 418 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.001575198787331511
# Episode 419 Episodic Reward -182.0 Maximum Reward -95.0 EPSILON 0.001559446799458196
# Episode 420 Episodic Reward -187.0 Maximum Reward -95.0 EPSILON 0.001543852331463614
# Episode 421 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0015284138081489778
# Episode 422 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.001513129670067488
# Episode 423 Episodic Reward -173.0 Maximum Reward -95.0 EPSILON 0.0014979983733668131
# Episode 424 Episodic Reward -175.0 Maximum Reward -95.0 EPSILON 0.001483018389633145
# Episode 425 Episodic Reward -141.0 Maximum Reward -95.0 EPSILON 0.0014681882057368135
# Episode 426 Episodic Reward -154.0 Maximum Reward -95.0 EPSILON 0.0014535063236794453
# Episode 427 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0014389712604426508
# Episode 428 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0014245815478382243
# Episode 429 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.001410335732359842
# Episode 430 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0013962323750362437
# Episode 431 Episodic Reward -191.0 Maximum Reward -95.0 EPSILON 0.0013822700512858813
# Episode 432 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0013684473507730225
# Episode 433 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0013547628772652921
# Episode 434 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0013412152484926392
# Episode 435 Episodic Reward -164.0 Maximum Reward -95.0 EPSILON 0.0013278030960077129
# Episode 436 Episodic Reward -152.0 Maximum Reward -95.0 EPSILON 0.0013145250650476357
# Episode 437 Episodic Reward -178.0 Maximum Reward -95.0 EPSILON 0.0013013798143971594
# Episode 438 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0012883660162531878
# Episode 439 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.001275482356090656
# Episode 440 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0012627275325297494
# Episode 441 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0012501002572044518
# Episode 442 Episodic Reward -197.0 Maximum Reward -95.0 EPSILON 0.0012375992546324072
# Episode 443 Episodic Reward -179.0 Maximum Reward -95.0 EPSILON 0.0012252232620860832
# Episode 444 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0012129710294652223
# Episode 445 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0012008413191705702
# Episode 446 Episodic Reward -149.0 Maximum Reward -95.0 EPSILON 0.0011888329059788645
# Episode 447 Episodic Reward -111.0 Maximum Reward -95.0 EPSILON 0.001176944576919076
# Episode 448 Episodic Reward -174.0 Maximum Reward -95.0 EPSILON 0.0011651751311498853
# Episode 449 Episodic Reward -149.0 Maximum Reward -95.0 EPSILON 0.0011535233798383865
# Episode 450 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0011419881460400026
# Episode 451 Episodic Reward -167.0 Maximum Reward -95.0 EPSILON 0.0011305682645796026
# Episode 452 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0011192625819338065
# Episode 453 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0011080699561144684
# Episode 454 Episodic Reward -157.0 Maximum Reward -95.0 EPSILON 0.0010969892565533238
# Episode 455 Episodic Reward -122.0 Maximum Reward -95.0 EPSILON 0.0010860193639877906
# Episode 456 Episodic Reward -194.0 Maximum Reward -95.0 EPSILON 0.0010751591703479127
# Episode 457 Episodic Reward -143.0 Maximum Reward -95.0 EPSILON 0.0010644075786444334
# Episode 458 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.001053763502857989
# Episode 459 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.001043225867829409
# Episode 460 Episodic Reward -187.0 Maximum Reward -95.0 EPSILON 0.001032793609151115
# Episode 461 Episodic Reward -159.0 Maximum Reward -95.0 EPSILON 0.0010224656730596037
# Episode 462 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0010122410163290077
# Episode 463 Episodic Reward -159.0 Maximum Reward -95.0 EPSILON 0.0010021186061657176
# Episode 464 Episodic Reward -164.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 465 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 466 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 467 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 468 Episodic Reward -138.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 469 Episodic Reward -170.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 470 Episodic Reward -116.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 471 Episodic Reward -160.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 472 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 473 Episodic Reward -152.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 474 Episodic Reward -173.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 475 Episodic Reward -162.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 476 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 477 Episodic Reward -123.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 478 Episodic Reward -119.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 479 Episodic Reward -157.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 480 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 481 Episodic Reward -159.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 482 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 483 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 484 Episodic Reward -184.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 485 Episodic Reward -179.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 486 Episodic Reward -168.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 487 Episodic Reward -122.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 488 Episodic Reward -194.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 489 Episodic Reward -188.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 490 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 491 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 492 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 493 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 494 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 495 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 496 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 497 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 498 Episodic Reward -199.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 499 Episodic Reward -188.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 500 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 501 Episodic Reward -146.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 502 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 503 Episodic Reward -164.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 504 Episodic Reward -121.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 505 Episodic Reward -174.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 506 Episodic Reward -171.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 507 Episodic Reward -158.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 508 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 509 Episodic Reward -165.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 510 Episodic Reward -99.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 511 Episodic Reward -171.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 512 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 513 Episodic Reward -162.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 514 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 515 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 516 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 517 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 518 Episodic Reward -132.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 519 Episodic Reward -145.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 520 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 521 Episodic Reward -186.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 522 Episodic Reward -106.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 523 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 524 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 525 Episodic Reward -191.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 526 Episodic Reward -150.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 527 Episodic Reward -159.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 528 Episodic Reward -178.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 529 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 530 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 531 Episodic Reward -192.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 532 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 533 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 534 Episodic Reward -181.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 535 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 536 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 537 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 538 Episodic Reward -168.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 539 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 540 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 541 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 542 Episodic Reward -178.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 543 Episodic Reward -175.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 544 Episodic Reward -167.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 545 Episodic Reward -158.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 546 Episodic Reward -153.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 547 Episodic Reward -155.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 548 Episodic Reward -140.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 549 Episodic Reward -116.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 550 Episodic Reward -156.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 551 Episodic Reward -143.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 552 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 553 Episodic Reward -117.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 554 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 555 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 556 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 557 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 558 Episodic Reward -196.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 559 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 560 Episodic Reward -131.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 561 Episodic Reward -158.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 562 Episodic Reward -122.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 563 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 564 Episodic Reward -132.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 565 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 566 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 567 Episodic Reward -156.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 568 Episodic Reward -105.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 569 Episodic Reward -128.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 570 Episodic Reward -151.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 571 Episodic Reward -153.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 572 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 573 Episodic Reward -186.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 574 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 575 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 576 Episodic Reward -137.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 577 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 578 Episodic Reward -154.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 579 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 580 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 581 Episodic Reward -146.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 582 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 583 Episodic Reward -166.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 584 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 585 Episodic Reward -155.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 586 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 587 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 588 Episodic Reward -185.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 589 Episodic Reward -165.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 590 Episodic Reward -143.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 591 Episodic Reward -166.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 592 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 593 Episodic Reward -143.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 594 Episodic Reward -146.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 595 Episodic Reward -176.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 596 Episodic Reward -179.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 597 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 598 Episodic Reward -119.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604
# Episode 599 Episodic Reward -200.0 Maximum Reward -95.0 EPSILON 0.0009920974201040604

# %% [markdown]
# ## Plotting Rewards vs Episodes [Section 4.4]

# %%
# model.set_weights(best_weights)
plt.figure(figsize=(8, 4))
plt.plot(rewards)
plt.xlabel("Episode", fontsize=14)
plt.ylabel("Reward", fontsize=14)
plt.title("Rewards vs. Episodes", fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# # Plotting Moving Average over 50 episodes [Section 4.4]

# %%
mean_rewards = np.zeros(600)
for t in range(600):
    mean_rewards[t] = np.mean(rewards[max(0, t-50):(t+1)])
plt.plot(mean_rewards)
plt.xlabel("Episode", fontsize=14)
plt.ylabel("Reward", fontsize=14)
plt.title("Moving average over 50 episodes", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Moving average over 50 episodes')

# %% [markdown]
# ## Testing the pre-trained model for 50 episodes

# %%
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam

# %%
class DQNAgent:
    def __init__(self, action_dim, observation_dim):
        # Force keras to use the session that we have created

        self.action_dim = action_dim
        self.observation_dim = observation_dim
        self.model = self.create_model()

    def create_model(self):
        state_input = Input(shape=(self.observation_dim))
        state_h1 = Dense(400, activation='relu')(state_input)
        state_h2 = Dense(300, activation='relu')(state_h1)
        output = Dense(self.action_dim, activation='linear')(state_h2)
        model = Model(inputs=state_input, outputs=output)
        model.compile(loss='mse', optimizer=Adam(0.005))
        return model

# %%
# Loading the model weights
model_weight_file = 'agent-115.0_agent_.weights.h5'

# Creating the environment
env = gym.make('MountainCar-v0')

# Getting the action and observation space
action_dim = env.action_space.n
observation_dim = env.observation_space.shape

# create and load weights of the model
agent = DQNAgent(action_dim, observation_dim)
agent.model.load_weights(model_weight_file)
# Number of episodes in which agent manages to won the game before time is over
episodes_won = 0
# Number of episodes for which we want to test the agnet
TOTAL_EPISODES = 50

# Looping through the episodes
for _ in range(TOTAL_EPISODES):
    cur_state = env.reset()
    done = False
    episode_len = 0
    while not done:

        episode_len += 1
        # Taking the action based on the model prediction
        next_state, reward, done, _ = env.step(np.argmax(agent.model.predict(np.expand_dims(cur_state, axis=0), verbose=0)))
        if done and episode_len < 200:
            episodes_won += 1
        cur_state = next_state

# Printing the number of episodes won by the agent
print(episodes_won, 'EPISODES WON AMONG', TOTAL_EPISODES, 'EPISODES')
# Out:
# 48 EPISODES WON AMONG 50 EPISODES

# %% [markdown]
# <span style="color:green">This shows the game has reached the done state in under 200 episodes, which  means the car has reached the flag pole</span>

# %% [markdown]
# ---------------------------------------------------------------------------------------------

# %% [markdown]
# # 2. Fixed DQN [Section 5]

# %% [markdown]
# <span style='color:red'> In the above code, we were constantly chignign the parameters(weights) of the network we defined to improve the Q-values predicted, however we were also using the changing Q-value predictions to update the Q-values. This can leadto instability in the training.  </span>
#
# <span style='color:red'> Instead of updating the Q-values based on the continously changing network(training), we use a separate network(target network) to calculate the future Q-value in the Bellman equation. This target network has the same architecture as the training network, however, has frozen parameters(weights). These parameters are updated less frequently by copying the weights of the training network to the target network. Hence the target is more stable which helps to stabilize the training process.  </span>
#
# <span style='color:red'> NOTE: In the code below we refer to training network as model and the target network as target_model1.  </span>

# %%
import random
random.seed(2212)
np.random.seed(2212)
tf.random.set_seed(2212)
from collections import deque
input_shape = [2]


# Hyperparameters
EPISODES = 560
REPLAY_MEMORY_SIZE = 1_00_000
MINIMUM_REPLAY_MEMORY = 1_000
MINIBATCH_SIZE = 32
EPSILON = 1
EPSILON_DECAY = 0.99
MINIMUM_EPSILON = 0.001
DISCOUNT = 0.99
VISUALIZATION = False
ENV_NAME = 'MountainCar-v0'


# Environment details
env = gym.make(ENV_NAME)
action_dim = env.action_space.n
observation_dim = env.observation_space.shape

# defining the input shape and the number of outputs from the environment
input_shape = env.observation_space.shape  # Assuming self.observation_dim is a tuple
n_outputs = env.action_space.n

# Creating a simple sequential neural network model with 3 layers (400, 300, 2)
model = tf.keras.Sequential([
    tf.keras.layers.Dense(400, activation='relu', input_shape=input_shape),
    tf.keras.layers.Dense(300, activation='relu'),
    tf.keras.layers.Dense(n_outputs, activation='linear')
])
# Compiling the neural network using Mean Square Error as loss function and
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(learning_rate=0.005))

# Cloning the model to create a target model
target_model1 = tf.keras.models.clone_model(model)

from collections import deque
# Replay memory to store experiances of the model with the environment
replay_buffer = deque(maxlen=REPLAY_MEMORY_SIZE)

'''Defining epsilon greedy policy function to determine an action
to decide whether to explore or exploit the knowledge acquired'''
def epsilon_greedy_policy(state, epsilon):
    if np.random.uniform(0, 1) < epsilon:
        action = np.random.randint(0, action_dim)
        return action
    else:
        action = np.argmax(model.predict(np.expand_dims(state, axis=0), verbose=0)[0])
        return action

'''This function samples a batch of experiences from the replay buffer for training the model.'''
def sample_experiences(batch_size):
    indices = np.random.randint(len(replay_buffer), size=batch_size)
    batch = [replay_buffer[index] for index in indices]
    return [
        np.array([experience[field_index] for experience in batch])
        for field_index in range(5)
    ] 

max_reward = -999999
'''This function defines the steps the agent has to take based on the epsilon greedy policy
 and accumulates the reward'''
def play_one_step(env, state, epsilon, episode_length):
    # defining reward acquired in each episode
    global episode_reward
    # Calling epsilon greedy function to select action
    action = epsilon_greedy_policy(state, epsilon)
    # Executing the action and returns 4 values
    next_state, reward, done, info = env.step(action)
    # accumulating rewards in each step of the epsiode(max=-200)
    episode_reward += reward
    # truncating if the car reaches the flag on the mountain top within 200 steps
    if done and episode_length < 200:
        # If episode is ended then we have won the game. Defining Stratagem to make the agent learn faster
        reward = 250 + episode_reward
        # save the model weights if we get a epsiode reward greater than maximum reward defined
        if(episode_reward > max_reward):
            print("Saving the model with reward", episode_reward)
            model.save_weights("agent"+str(episode_reward)+"_agent_.weights.h5")
    else:
        # In oher cases reward will be proportional to the distance that car has travelled
        # from it's previous location + velocity of the car
        reward = 5*abs(next_state[0] - state[0]) + 3*abs(state[1])

    # append this result to the replay buffer(experince replay)
    replay_buffer.append((state, action, reward, next_state, done))

    return next_state, action, episode_reward, max_reward, done, info



np.random.seed(42)
tf.random.set_seed(42)
rewards = []
best_score = 0

batch_size = 32
discount_factor = 0.95
optimizer = tf.keras.optimizers.Nadam(learning_rate=1e-1)
loss_fn = tf.keras.losses.mean_squared_error

def training_step(batch_size):

    # Randomly sample a batch of experiences from the replay buffer
    minibatch = random.sample(replay_buffer, MINIBATCH_SIZE)
    # Initialize lists to store the current and next states
    X_cur_states = []
    X_next_states = []

    # Populate the current and next states lists with data from the sampled experiences
    for index, sample in enumerate(minibatch):
        cur_state, action, reward, next_state, done = sample
        X_cur_states.append(cur_state)
        X_next_states.append(next_state)

    # Convert the lists to arrays
    X_cur_states = np.array(X_cur_states)
    X_next_states = np.array(X_next_states)

    # Initialize an array to store the Q values for the current state-action pairs
    cur_action_values = model.predict(X_cur_states, verbose =0)

    # Use the target model to predict the Q values for the next states
    next_action_values = target_model1.predict(X_next_states, verbose=0)
    
    '''Update the Q values for the current state-action pairs based on the rewards 
       and the maximum predicted Q values for the next states'''
    for index, sample in enumerate(minibatch):
        cur_state, action, reward, next_state, done = sample
        if not done:
            # if episode is not done then we have to calculate the Q value using Bellman's equation
            # Q(st, at) = rt + DISCOUNT * max(Q(s(t+1), a(t+1)))
            cur_action_values[index][action] = reward + DISCOUNT * np.amax(next_action_values[index])
        else:
            # if episode is done then Q value will be the reward
            # Q(st, at) = rt
            cur_action_values[index][action] = reward
            
    # train the agent with new Q values for the states and the actions
    model.fit(X_cur_states, cur_action_values, verbose=0)
    
# Initialize lists to store Q-values, positions, velocities, and actions taken
q_values = []
positions = []
velocities = []
actiion_taken = []

# Loop through the episodes
for episode in range(600):
    # Reset the environment for the state to be reset
    state = env.reset()
    done = False
    episode_reward = 0
    episode_length = 0

    # Run through different sets of steps untill 200 steps are completed or the car reaches the flag
    while not done:
        # Increment the episode length
        episode_length += 1

        # Play one step in the environment and get the next state, action, reward, max reward, done status, and info
        next_state, action, reward, max_reward, done, info  = play_one_step(env,state, EPSILON, episode_length)
        # Append the position, velocity, and action to their respective lists
        positions.append(next_state[0])
        velocities.append(next_state[1])
        actiion_taken.append(action)

        # Update the current state to the next state
        state = next_state

        # If the replay buffer is not large enough, skip the training step
        if(len(replay_buffer) < MINIMUM_REPLAY_MEMORY):
            continue
        training_step(batch_size)

    # Update the maximum reward if the current reward is greater
    max_reward = max(reward, max_reward)

    # Print the episode number, episodic reward, maximum reward, and epsilon
    print('Episode', episode, 'Episodic Reward', reward, 'Maximum Reward', max_reward, 'EPSILON', EPSILON)
    rewards.append(reward)
    # Append the mean Q-value of the current state to the Q-values list
    q_values.append(np.mean(model.predict(np.array([(state)]), verbose=0)[0]))
    
    # Every 20 episodes, update the weights of the target model with the weights of the training model
    if episode % 20 == 0:
        target_model1.set_weights(model.get_weights())
    
    # If epsilon is greater than the minimum epsilon and the replay buffer is large enough, decay epsilon
    if(EPSILON > MINIMUM_EPSILON and len(replay_buffer) > MINIMUM_REPLAY_MEMORY):
        EPSILON *= EPSILON_DECAY
# Out:
# Episode 0 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 1
# Episode 1 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 1
# Episode 2 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 1
# Episode 3 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 1
# Episode 4 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 1
# Episode 5 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 1
# Episode 6 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.99
# Episode 7 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.9801
# Episode 8 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.9702989999999999
# Episode 9 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.96059601
# Episode 10 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.9509900498999999
# Episode 11 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.9414801494009999
# Episode 12 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.9320653479069899
# Episode 13 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.92274469442792
# Episode 14 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.9135172474836407
# Episode 15 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.9043820750088043
# Episode 16 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.8953382542587163
# Episode 17 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.8863848717161291
# Episode 18 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.8775210229989678
# Episode 19 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.8687458127689781
# Episode 20 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.8600583546412883
# Episode 21 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.8514577710948754
# Episode 22 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.8429431933839266
# Episode 23 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.8345137614500874
# Episode 24 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.8261686238355865
# Episode 25 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.8179069375972307
# Episode 26 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.8097278682212583
# Episode 27 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.8016305895390458
# Episode 28 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.7936142836436553
# Episode 29 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.7856781408072188
# Episode 30 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.7778213593991465
# Episode 31 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.7700431458051551
# Episode 32 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.7623427143471035
# Episode 33 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.7547192872036325
# Episode 34 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.7471720943315961
# Episode 35 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.7397003733882802
# Episode 36 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.7323033696543974
# Episode 37 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.7249803359578534
# Episode 38 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.7177305325982748
# Episode 39 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.7105532272722921
# Episode 40 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.7034476949995692
# Episode 41 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.6964132180495735
# Episode 42 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.6894490858690777
# Episode 43 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.682554595010387
# Episode 44 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.6757290490602831
# Episode 45 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.6689717585696803
# Episode 46 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.6622820409839835
# Episode 47 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.6556592205741436
# Episode 48 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.6491026283684022
# Episode 49 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.6426116020847181
# Episode 50 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.6361854860638709
# Episode 51 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.6298236312032323
# Episode 52 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.6235253948912
# Episode 53 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.617290140942288
# Episode 54 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.6111172395328651
# Episode 55 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.6050060671375365
# Episode 56 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.5989560064661611
# Episode 57 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.5929664464014994
# Episode 58 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.5870367819374844
# Episode 59 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.5811664141181095
# Episode 60 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.5753547499769285
# Episode 61 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.5696012024771592
# Episode 62 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.5639051904523876
# Episode 63 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.5582661385478638
# Episode 64 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.5526834771623851
# Episode 65 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.5471566423907612
# Episode 66 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.5416850759668536
# Episode 67 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.536268225207185
# Saving the model with reward -165.0
# Episode 68 Episodic Reward -165.0 Maximum Reward -165.0 EPSILON 0.5309055429551132
# Episode 69 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.525596487525562
# Episode 70 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.5203405226503064
# Episode 71 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.5151371174238033
# Episode 72 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.5099857462495653
# Episode 73 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.5048858887870696
# Episode 74 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.4998370298991989
# Episode 75 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.49483865960020695
# Episode 76 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.4898902730042049
# Episode 77 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.48499137027416284
# Episode 78 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.4801414565714212
# Episode 79 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.475340042005707
# Episode 80 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.47058664158564995
# Episode 81 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.4658807751697934
# Episode 82 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.4612219674180955
# Episode 83 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.45660974774391455
# Episode 84 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.4520436502664754
# Episode 85 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.44752321376381066
# Episode 86 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.44304798162617254
# Episode 87 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.4386175018099108
# Episode 88 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.4342313267918117
# Episode 89 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.4298890135238936
# Episode 90 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.42559012338865465
# Episode 91 Episodic Reward -192.0 Maximum Reward -165.0 EPSILON 0.4213342221547681
# Episode 92 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.41712087993322045
# Episode 93 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.41294967113388825
# Episode 94 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.40882017442254937
# Episode 95 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.4047319726783239
# Episode 96 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.40068465295154065
# Episode 97 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.39667780642202527
# Episode 98 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.392711028357805
# Episode 99 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.38878391807422696
# Episode 100 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.3848960788934847
# Episode 101 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.38104711810454983
# Episode 102 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.37723664692350434
# Episode 103 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.37346428045426927
# Episode 104 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.36972963764972655
# Episode 105 Episodic Reward -183.0 Maximum Reward -165.0 EPSILON 0.36603234127322926
# Episode 106 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.36237201786049694
# Episode 107 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.358748297681892
# Episode 108 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.35516081470507305
# Episode 109 Episodic Reward -198.0 Maximum Reward -165.0 EPSILON 0.3516092065580223
# Episode 110 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.34809311449244207
# Episode 111 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.34461218334751764
# Episode 112 Episodic Reward -178.0 Maximum Reward -165.0 EPSILON 0.34116606151404244
# Episode 113 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.337754400898902
# Episode 114 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.334376856889913
# Episode 115 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.33103308832101386
# Episode 116 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.3277227574378037
# Episode 117 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.3244455298634257
# Episode 118 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.3212010745647914
# Episode 119 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.3179890638191435
# Episode 120 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.31480917318095203
# Episode 121 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.3116610814491425
# Episode 122 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.30854447063465107
# Episode 123 Episodic Reward -176.0 Maximum Reward -165.0 EPSILON 0.30545902592830454
# Episode 124 Episodic Reward -166.0 Maximum Reward -165.0 EPSILON 0.3024044356690215
# Episode 125 Episodic Reward -192.0 Maximum Reward -165.0 EPSILON 0.29938039131233124
# Episode 126 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.2963865873992079
# Episode 127 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.29342272152521587
# Episode 128 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.2904884943099637
# Episode 129 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.28758360936686406
# Episode 130 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.2847077732731954
# Episode 131 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.28186069554046345
# Episode 132 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.2790420885850588
# Episode 133 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.2762516676992082
# Episode 134 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.27348915102221616
# Episode 135 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.270754259511994
# Episode 136 Episodic Reward -200.0 Maximum Reward -165.0 EPSILON 0.26804671691687404
# Saving the model with reward -161.0
# Episode 137 Episodic Reward -161.0 Maximum Reward -161.0 EPSILON 0.2653662497477053
# Saving the model with reward -160.0
# Episode 138 Episodic Reward -160.0 Maximum Reward -160.0 EPSILON 0.2627125872502282
# Saving the model with reward -156.0
# Episode 139 Episodic Reward -156.0 Maximum Reward -156.0 EPSILON 0.2600854613777259
# Episode 140 Episodic Reward -166.0 Maximum Reward -156.0 EPSILON 0.2574846067639487
# Episode 141 Episodic Reward -177.0 Maximum Reward -156.0 EPSILON 0.2549097606963092
# Episode 142 Episodic Reward -200.0 Maximum Reward -156.0 EPSILON 0.2523606630893461
# Episode 143 Episodic Reward -200.0 Maximum Reward -156.0 EPSILON 0.24983705645845267
# Episode 144 Episodic Reward -200.0 Maximum Reward -156.0 EPSILON 0.24733868589386815
# Episode 145 Episodic Reward -200.0 Maximum Reward -156.0 EPSILON 0.24486529903492946
# Episode 146 Episodic Reward -200.0 Maximum Reward -156.0 EPSILON 0.24241664604458016
# Episode 147 Episodic Reward -200.0 Maximum Reward -156.0 EPSILON 0.23999247958413436
# Episode 148 Episodic Reward -200.0 Maximum Reward -156.0 EPSILON 0.23759255478829303
# Episode 149 Episodic Reward -183.0 Maximum Reward -156.0 EPSILON 0.2352166292404101
# Episode 150 Episodic Reward -187.0 Maximum Reward -156.0 EPSILON 0.232864462948006
# Episode 151 Episodic Reward -180.0 Maximum Reward -156.0 EPSILON 0.23053581831852593
# Episode 152 Episodic Reward -200.0 Maximum Reward -156.0 EPSILON 0.22823046013534068
# Episode 153 Episodic Reward -163.0 Maximum Reward -156.0 EPSILON 0.22594815553398728
# Episode 154 Episodic Reward -193.0 Maximum Reward -156.0 EPSILON 0.22368867397864742
# Episode 155 Episodic Reward -200.0 Maximum Reward -156.0 EPSILON 0.22145178723886094
# Episode 156 Episodic Reward -200.0 Maximum Reward -156.0 EPSILON 0.21923726936647234
# Saving the model with reward -142.0
# Episode 157 Episodic Reward -142.0 Maximum Reward -142.0 EPSILON 0.2170448966728076
# Episode 158 Episodic Reward -200.0 Maximum Reward -142.0 EPSILON 0.21487444770607952
# Saving the model with reward -135.0
# Episode 159 Episodic Reward -135.0 Maximum Reward -135.0 EPSILON 0.21272570322901874
# Episode 160 Episodic Reward -164.0 Maximum Reward -135.0 EPSILON 0.21059844619672854
# Episode 161 Episodic Reward -200.0 Maximum Reward -135.0 EPSILON 0.20849246173476127
# Episode 162 Episodic Reward -168.0 Maximum Reward -135.0 EPSILON 0.20640753711741366
# Episode 163 Episodic Reward -137.0 Maximum Reward -135.0 EPSILON 0.20434346174623952
# Episode 164 Episodic Reward -200.0 Maximum Reward -135.0 EPSILON 0.20230002712877712
# Episode 165 Episodic Reward -167.0 Maximum Reward -135.0 EPSILON 0.20027702685748935
# Episode 166 Episodic Reward -175.0 Maximum Reward -135.0 EPSILON 0.19827425658891445
# Saving the model with reward -124.0
# Episode 167 Episodic Reward -124.0 Maximum Reward -124.0 EPSILON 0.1962915140230253
# Episode 168 Episodic Reward -129.0 Maximum Reward -124.0 EPSILON 0.19432859888279505
# Episode 169 Episodic Reward -200.0 Maximum Reward -124.0 EPSILON 0.1923853128939671
# Episode 170 Episodic Reward -173.0 Maximum Reward -124.0 EPSILON 0.19046145976502743
# Episode 171 Episodic Reward -167.0 Maximum Reward -124.0 EPSILON 0.18855684516737714
# Episode 172 Episodic Reward -161.0 Maximum Reward -124.0 EPSILON 0.18667127671570335
# Episode 173 Episodic Reward -200.0 Maximum Reward -124.0 EPSILON 0.18480456394854633
# Episode 174 Episodic Reward -170.0 Maximum Reward -124.0 EPSILON 0.18295651830906087
# Episode 175 Episodic Reward -189.0 Maximum Reward -124.0 EPSILON 0.18112695312597027
# Episode 176 Episodic Reward -168.0 Maximum Reward -124.0 EPSILON 0.17931568359471056
# Episode 177 Episodic Reward -177.0 Maximum Reward -124.0 EPSILON 0.17752252675876345
# Episode 178 Episodic Reward -200.0 Maximum Reward -124.0 EPSILON 0.17574730149117582
# Episode 179 Episodic Reward -200.0 Maximum Reward -124.0 EPSILON 0.17398982847626407
# Episode 180 Episodic Reward -200.0 Maximum Reward -124.0 EPSILON 0.17224993019150142
# Episode 181 Episodic Reward -200.0 Maximum Reward -124.0 EPSILON 0.1705274308895864
# Episode 182 Episodic Reward -186.0 Maximum Reward -124.0 EPSILON 0.16882215658069055
# Episode 183 Episodic Reward -200.0 Maximum Reward -124.0 EPSILON 0.16713393501488363
# Episode 184 Episodic Reward -166.0 Maximum Reward -124.0 EPSILON 0.16546259566473479
# Episode 185 Episodic Reward -187.0 Maximum Reward -124.0 EPSILON 0.16380796970808745
# Episode 186 Episodic Reward -200.0 Maximum Reward -124.0 EPSILON 0.16216989001100657
# Episode 187 Episodic Reward -190.0 Maximum Reward -124.0 EPSILON 0.1605481911108965
# Episode 188 Episodic Reward -179.0 Maximum Reward -124.0 EPSILON 0.15894270919978754
# Episode 189 Episodic Reward -179.0 Maximum Reward -124.0 EPSILON 0.15735328210778965
# Episode 190 Episodic Reward -200.0 Maximum Reward -124.0 EPSILON 0.15577974928671176
# Episode 191 Episodic Reward -174.0 Maximum Reward -124.0 EPSILON 0.15422195179384465
# Episode 192 Episodic Reward -133.0 Maximum Reward -124.0 EPSILON 0.1526797322759062
# Episode 193 Episodic Reward -200.0 Maximum Reward -124.0 EPSILON 0.15115293495314713
# Episode 194 Episodic Reward -126.0 Maximum Reward -124.0 EPSILON 0.14964140560361566
# Episode 195 Episodic Reward -191.0 Maximum Reward -124.0 EPSILON 0.1481449915475795
# Episode 196 Episodic Reward -194.0 Maximum Reward -124.0 EPSILON 0.1466635416321037
# Episode 197 Episodic Reward -200.0 Maximum Reward -124.0 EPSILON 0.14519690621578268
# Episode 198 Episodic Reward -171.0 Maximum Reward -124.0 EPSILON 0.14374493715362485
# Episode 199 Episodic Reward -200.0 Maximum Reward -124.0 EPSILON 0.1423074877820886
# Episode 200 Episodic Reward -152.0 Maximum Reward -124.0 EPSILON 0.1408844129042677
# Episode 201 Episodic Reward -179.0 Maximum Reward -124.0 EPSILON 0.13947556877522502
# Episode 202 Episodic Reward -186.0 Maximum Reward -124.0 EPSILON 0.13808081308747278
# Episode 203 Episodic Reward -200.0 Maximum Reward -124.0 EPSILON 0.13670000495659804
# Episode 204 Episodic Reward -200.0 Maximum Reward -124.0 EPSILON 0.13533300490703207
# Saving the model with reward -123.0
# Episode 205 Episodic Reward -123.0 Maximum Reward -123.0 EPSILON 0.13397967485796175
# Episode 206 Episodic Reward -183.0 Maximum Reward -123.0 EPSILON 0.13263987810938213
# Episode 207 Episodic Reward -200.0 Maximum Reward -123.0 EPSILON 0.1313134793282883
# Episode 208 Episodic Reward -178.0 Maximum Reward -123.0 EPSILON 0.13000034453500542
# Episode 209 Episodic Reward -181.0 Maximum Reward -123.0 EPSILON 0.12870034108965536
# Episode 210 Episodic Reward -200.0 Maximum Reward -123.0 EPSILON 0.12741333767875881
# Episode 211 Episodic Reward -185.0 Maximum Reward -123.0 EPSILON 0.12613920430197123
# Episode 212 Episodic Reward -200.0 Maximum Reward -123.0 EPSILON 0.12487781225895152
# Episode 213 Episodic Reward -200.0 Maximum Reward -123.0 EPSILON 0.123629034136362
# Episode 214 Episodic Reward -200.0 Maximum Reward -123.0 EPSILON 0.12239274379499838
# Episode 215 Episodic Reward -192.0 Maximum Reward -123.0 EPSILON 0.1211688163570484
# Episode 216 Episodic Reward -188.0 Maximum Reward -123.0 EPSILON 0.11995712819347792
# Episode 217 Episodic Reward -200.0 Maximum Reward -123.0 EPSILON 0.11875755691154315
# Episode 218 Episodic Reward -200.0 Maximum Reward -123.0 EPSILON 0.11756998134242772
# Episode 219 Episodic Reward -180.0 Maximum Reward -123.0 EPSILON 0.11639428152900344
# Episode 220 Episodic Reward -153.0 Maximum Reward -123.0 EPSILON 0.11523033871371341
# Episode 221 Episodic Reward -169.0 Maximum Reward -123.0 EPSILON 0.11407803532657627
# Episode 222 Episodic Reward -171.0 Maximum Reward -123.0 EPSILON 0.11293725497331052
# Episode 223 Episodic Reward -180.0 Maximum Reward -123.0 EPSILON 0.1118078824235774
# Episode 224 Episodic Reward -130.0 Maximum Reward -123.0 EPSILON 0.11068980359934164
# Episode 225 Episodic Reward -179.0 Maximum Reward -123.0 EPSILON 0.10958290556334822
# Episode 226 Episodic Reward -200.0 Maximum Reward -123.0 EPSILON 0.10848707650771475
# Episode 227 Episodic Reward -180.0 Maximum Reward -123.0 EPSILON 0.1074022057426376
# Episode 228 Episodic Reward -170.0 Maximum Reward -123.0 EPSILON 0.10632818368521123
# Episode 229 Episodic Reward -181.0 Maximum Reward -123.0 EPSILON 0.10526490184835911
# Episode 230 Episodic Reward -200.0 Maximum Reward -123.0 EPSILON 0.10421225282987552
# Episode 231 Episodic Reward -179.0 Maximum Reward -123.0 EPSILON 0.10317013030157676
# Episode 232 Episodic Reward -196.0 Maximum Reward -123.0 EPSILON 0.10213842899856099
# Episode 233 Episodic Reward -172.0 Maximum Reward -123.0 EPSILON 0.10111704470857538
# Episode 234 Episodic Reward -200.0 Maximum Reward -123.0 EPSILON 0.10010587426148963
# Episode 235 Episodic Reward -200.0 Maximum Reward -123.0 EPSILON 0.09910481551887473
# Episode 236 Episodic Reward -200.0 Maximum Reward -123.0 EPSILON 0.09811376736368599
# Episode 237 Episodic Reward -200.0 Maximum Reward -123.0 EPSILON 0.09713262969004913
# Episode 238 Episodic Reward -166.0 Maximum Reward -123.0 EPSILON 0.09616130339314863
# Episode 239 Episodic Reward -138.0 Maximum Reward -123.0 EPSILON 0.09519969035921715
# Episode 240 Episodic Reward -200.0 Maximum Reward -123.0 EPSILON 0.09424769345562498
# Episode 241 Episodic Reward -172.0 Maximum Reward -123.0 EPSILON 0.09330521652106873
# Episode 242 Episodic Reward -200.0 Maximum Reward -123.0 EPSILON 0.09237216435585804
# Episode 243 Episodic Reward -184.0 Maximum Reward -123.0 EPSILON 0.09144844271229946
# Episode 244 Episodic Reward -200.0 Maximum Reward -123.0 EPSILON 0.09053395828517646
# Episode 245 Episodic Reward -176.0 Maximum Reward -123.0 EPSILON 0.08962861870232469
# Episode 246 Episodic Reward -158.0 Maximum Reward -123.0 EPSILON 0.08873233251530144
# Episode 247 Episodic Reward -200.0 Maximum Reward -123.0 EPSILON 0.08784500919014843
# Episode 248 Episodic Reward -200.0 Maximum Reward -123.0 EPSILON 0.08696655909824694
# Episode 249 Episodic Reward -200.0 Maximum Reward -123.0 EPSILON 0.08609689350726446
# Episode 250 Episodic Reward -172.0 Maximum Reward -123.0 EPSILON 0.08523592457219181
# Episode 251 Episodic Reward -182.0 Maximum Reward -123.0 EPSILON 0.0843835653264699
# Episode 252 Episodic Reward -194.0 Maximum Reward -123.0 EPSILON 0.0835397296732052
# Episode 253 Episodic Reward -182.0 Maximum Reward -123.0 EPSILON 0.08270433237647315
# Episode 254 Episodic Reward -167.0 Maximum Reward -123.0 EPSILON 0.08187728905270841
# Episode 255 Episodic Reward -185.0 Maximum Reward -123.0 EPSILON 0.08105851616218133
# Episode 256 Episodic Reward -174.0 Maximum Reward -123.0 EPSILON 0.08024793100055952
# Episode 257 Episodic Reward -200.0 Maximum Reward -123.0 EPSILON 0.07944545169055392
# Episode 258 Episodic Reward -200.0 Maximum Reward -123.0 EPSILON 0.07865099717364837
# Episode 259 Episodic Reward -200.0 Maximum Reward -123.0 EPSILON 0.07786448720191189
# Episode 260 Episodic Reward -182.0 Maximum Reward -123.0 EPSILON 0.07708584232989277
# Episode 261 Episodic Reward -200.0 Maximum Reward -123.0 EPSILON 0.07631498390659384
# Episode 262 Episodic Reward -200.0 Maximum Reward -123.0 EPSILON 0.07555183406752791
# Episode 263 Episodic Reward -164.0 Maximum Reward -123.0 EPSILON 0.07479631572685264
# Episode 264 Episodic Reward -200.0 Maximum Reward -123.0 EPSILON 0.07404835256958411
# Episode 265 Episodic Reward -161.0 Maximum Reward -123.0 EPSILON 0.07330786904388827
# Episode 266 Episodic Reward -200.0 Maximum Reward -123.0 EPSILON 0.07257479035344938
# Episode 267 Episodic Reward -177.0 Maximum Reward -123.0 EPSILON 0.07184904244991488
# Saving the model with reward -114.0
# Episode 268 Episodic Reward -114.0 Maximum Reward -114.0 EPSILON 0.07113055202541574
# Episode 269 Episodic Reward -136.0 Maximum Reward -114.0 EPSILON 0.07041924650516158
# Episode 270 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.06971505404010997
# Episode 271 Episodic Reward -123.0 Maximum Reward -114.0 EPSILON 0.06901790349970886
# Episode 272 Episodic Reward -146.0 Maximum Reward -114.0 EPSILON 0.06832772446471178
# Episode 273 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.06764444722006466
# Episode 274 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.066968002747864
# Episode 275 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.06629832272038537
# Episode 276 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.06563533949318151
# Episode 277 Episodic Reward -176.0 Maximum Reward -114.0 EPSILON 0.06497898609824969
# Episode 278 Episodic Reward -164.0 Maximum Reward -114.0 EPSILON 0.0643291962372672
# Episode 279 Episodic Reward -178.0 Maximum Reward -114.0 EPSILON 0.06368590427489453
# Episode 280 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.06304904523214558
# Episode 281 Episodic Reward -133.0 Maximum Reward -114.0 EPSILON 0.06241855477982412
# Episode 282 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.06179436923202588
# Episode 283 Episodic Reward -165.0 Maximum Reward -114.0 EPSILON 0.06117642553970562
# Episode 284 Episodic Reward -175.0 Maximum Reward -114.0 EPSILON 0.06056466128430856
# Episode 285 Episodic Reward -183.0 Maximum Reward -114.0 EPSILON 0.05995901467146548
# Episode 286 Episodic Reward -182.0 Maximum Reward -114.0 EPSILON 0.05935942452475082
# Episode 287 Episodic Reward -165.0 Maximum Reward -114.0 EPSILON 0.058765830279503314
# Episode 288 Episodic Reward -176.0 Maximum Reward -114.0 EPSILON 0.05817817197670828
# Episode 289 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.057596390256941195
# Episode 290 Episodic Reward -185.0 Maximum Reward -114.0 EPSILON 0.05702042635437178
# Episode 291 Episodic Reward -184.0 Maximum Reward -114.0 EPSILON 0.05645022209082806
# Episode 292 Episodic Reward -149.0 Maximum Reward -114.0 EPSILON 0.05588571986991978
# Episode 293 Episodic Reward -126.0 Maximum Reward -114.0 EPSILON 0.055326862671220584
# Episode 294 Episodic Reward -187.0 Maximum Reward -114.0 EPSILON 0.05477359404450838
# Episode 295 Episodic Reward -162.0 Maximum Reward -114.0 EPSILON 0.054225858104063294
# Episode 296 Episodic Reward -154.0 Maximum Reward -114.0 EPSILON 0.05368359952302266
# Episode 297 Episodic Reward -179.0 Maximum Reward -114.0 EPSILON 0.053146763527792434
# Episode 298 Episodic Reward -119.0 Maximum Reward -114.0 EPSILON 0.052615295892514506
# Episode 299 Episodic Reward -128.0 Maximum Reward -114.0 EPSILON 0.052089142933589364
# Episode 300 Episodic Reward -180.0 Maximum Reward -114.0 EPSILON 0.05156825150425347
# Episode 301 Episodic Reward -185.0 Maximum Reward -114.0 EPSILON 0.051052568989210935
# Episode 302 Episodic Reward -188.0 Maximum Reward -114.0 EPSILON 0.05054204329931883
# Episode 303 Episodic Reward -162.0 Maximum Reward -114.0 EPSILON 0.05003662286632564
# Episode 304 Episodic Reward -192.0 Maximum Reward -114.0 EPSILON 0.04953625663766238
# Episode 305 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.04904089407128576
# Episode 306 Episodic Reward -124.0 Maximum Reward -114.0 EPSILON 0.0485504851305729
# Episode 307 Episodic Reward -170.0 Maximum Reward -114.0 EPSILON 0.048064980279267165
# Episode 308 Episodic Reward -148.0 Maximum Reward -114.0 EPSILON 0.04758433047647449
# Episode 309 Episodic Reward -170.0 Maximum Reward -114.0 EPSILON 0.04710848717170975
# Episode 310 Episodic Reward -139.0 Maximum Reward -114.0 EPSILON 0.04663740229999265
# Episode 311 Episodic Reward -191.0 Maximum Reward -114.0 EPSILON 0.04617102827699272
# Episode 312 Episodic Reward -176.0 Maximum Reward -114.0 EPSILON 0.045709317994222794
# Episode 313 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.04525222481428057
# Episode 314 Episodic Reward -193.0 Maximum Reward -114.0 EPSILON 0.04479970256613776
# Episode 315 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.04435170554047638
# Episode 316 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.043908188485071616
# Episode 317 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.0434691066002209
# Episode 318 Episodic Reward -132.0 Maximum Reward -114.0 EPSILON 0.04303441553421869
# Episode 319 Episodic Reward -166.0 Maximum Reward -114.0 EPSILON 0.0426040713788765
# Episode 320 Episodic Reward -129.0 Maximum Reward -114.0 EPSILON 0.04217803066508773
# Episode 321 Episodic Reward -142.0 Maximum Reward -114.0 EPSILON 0.04175625035843686
# Episode 322 Episodic Reward -146.0 Maximum Reward -114.0 EPSILON 0.041338687854852486
# Episode 323 Episodic Reward -188.0 Maximum Reward -114.0 EPSILON 0.04092530097630396
# Episode 324 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.040516047966540916
# Episode 325 Episodic Reward -191.0 Maximum Reward -114.0 EPSILON 0.04011088748687551
# Episode 326 Episodic Reward -195.0 Maximum Reward -114.0 EPSILON 0.03970977861200675
# Episode 327 Episodic Reward -125.0 Maximum Reward -114.0 EPSILON 0.03931268082588668
# Episode 328 Episodic Reward -190.0 Maximum Reward -114.0 EPSILON 0.03891955401762781
# Episode 329 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.03853035847745153
# Episode 330 Episodic Reward -165.0 Maximum Reward -114.0 EPSILON 0.03814505489267701
# Episode 331 Episodic Reward -154.0 Maximum Reward -114.0 EPSILON 0.03776360434375024
# Episode 332 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.03738596830031274
# Episode 333 Episodic Reward -134.0 Maximum Reward -114.0 EPSILON 0.03701210861730961
# Episode 334 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.03664198753113651
# Episode 335 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.036275567655825146
# Episode 336 Episodic Reward -182.0 Maximum Reward -114.0 EPSILON 0.03591281197926689
# Episode 337 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.035553683859474224
# Episode 338 Episodic Reward -172.0 Maximum Reward -114.0 EPSILON 0.03519814702087948
# Episode 339 Episodic Reward -180.0 Maximum Reward -114.0 EPSILON 0.03484616555067068
# Episode 340 Episodic Reward -195.0 Maximum Reward -114.0 EPSILON 0.034497703895163975
# Episode 341 Episodic Reward -193.0 Maximum Reward -114.0 EPSILON 0.03415272685621234
# Episode 342 Episodic Reward -179.0 Maximum Reward -114.0 EPSILON 0.03381119958765021
# Episode 343 Episodic Reward -192.0 Maximum Reward -114.0 EPSILON 0.03347308759177371
# Episode 344 Episodic Reward -121.0 Maximum Reward -114.0 EPSILON 0.03313835671585597
# Episode 345 Episodic Reward -130.0 Maximum Reward -114.0 EPSILON 0.03280697314869741
# Episode 346 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.032478903417210436
# Episode 347 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.032154114383038335
# Episode 348 Episodic Reward -122.0 Maximum Reward -114.0 EPSILON 0.03183257323920795
# Episode 349 Episodic Reward -140.0 Maximum Reward -114.0 EPSILON 0.03151424750681587
# Episode 350 Episodic Reward -122.0 Maximum Reward -114.0 EPSILON 0.03119910503174771
# Episode 351 Episodic Reward -181.0 Maximum Reward -114.0 EPSILON 0.030887113981430233
# Episode 352 Episodic Reward -144.0 Maximum Reward -114.0 EPSILON 0.03057824284161593
# Episode 353 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.03027246041319977
# Episode 354 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.029969735809067772
# Episode 355 Episodic Reward -175.0 Maximum Reward -114.0 EPSILON 0.029670038450977095
# Episode 356 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.029373338066467324
# Episode 357 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.02907960468580265
# Episode 358 Episodic Reward -140.0 Maximum Reward -114.0 EPSILON 0.028788808638944622
# Episode 359 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.028500920552555174
# Episode 360 Episodic Reward -125.0 Maximum Reward -114.0 EPSILON 0.028215911347029624
# Episode 361 Episodic Reward -122.0 Maximum Reward -114.0 EPSILON 0.027933752233559327
# Episode 362 Episodic Reward -179.0 Maximum Reward -114.0 EPSILON 0.027654414711223735
# Episode 363 Episodic Reward -119.0 Maximum Reward -114.0 EPSILON 0.027377870564111496
# Episode 364 Episodic Reward -138.0 Maximum Reward -114.0 EPSILON 0.027104091858470382
# Episode 365 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.026833050939885677
# Episode 366 Episodic Reward -114.0 Maximum Reward -114.0 EPSILON 0.02656472043048682
# Episode 367 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.02629907322618195
# Episode 368 Episodic Reward -173.0 Maximum Reward -114.0 EPSILON 0.026036082493920133
# Episode 369 Episodic Reward -180.0 Maximum Reward -114.0 EPSILON 0.02577572166898093
# Episode 370 Episodic Reward -197.0 Maximum Reward -114.0 EPSILON 0.025517964452291122
# Episode 371 Episodic Reward -188.0 Maximum Reward -114.0 EPSILON 0.02526278480776821
# Episode 372 Episodic Reward -186.0 Maximum Reward -114.0 EPSILON 0.025010156959690527
# Episode 373 Episodic Reward -114.0 Maximum Reward -114.0 EPSILON 0.02476005539009362
# Episode 374 Episodic Reward -176.0 Maximum Reward -114.0 EPSILON 0.024512454836192684
# Episode 375 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.024267330287830756
# Episode 376 Episodic Reward -189.0 Maximum Reward -114.0 EPSILON 0.024024656984952448
# Episode 377 Episodic Reward -199.0 Maximum Reward -114.0 EPSILON 0.023784410415102923
# Episode 378 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.023546566310951894
# Episode 379 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.023311100647842375
# Episode 380 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.02307798964136395
# Episode 381 Episodic Reward -126.0 Maximum Reward -114.0 EPSILON 0.022847209744950314
# Episode 382 Episodic Reward -173.0 Maximum Reward -114.0 EPSILON 0.02261873764750081
# Episode 383 Episodic Reward -195.0 Maximum Reward -114.0 EPSILON 0.022392550271025803
# Episode 384 Episodic Reward -194.0 Maximum Reward -114.0 EPSILON 0.022168624768315544
# Episode 385 Episodic Reward -171.0 Maximum Reward -114.0 EPSILON 0.02194693852063239
# Episode 386 Episodic Reward -186.0 Maximum Reward -114.0 EPSILON 0.021727469135426065
# Episode 387 Episodic Reward -177.0 Maximum Reward -114.0 EPSILON 0.021510194444071803
# Episode 388 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.021295092499631085
# Episode 389 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.021082141574634772
# Episode 390 Episodic Reward -138.0 Maximum Reward -114.0 EPSILON 0.020871320158888425
# Episode 391 Episodic Reward -169.0 Maximum Reward -114.0 EPSILON 0.020662606957299542
# Episode 392 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.020455980887726547
# Episode 393 Episodic Reward -173.0 Maximum Reward -114.0 EPSILON 0.02025142107884928
# Episode 394 Episodic Reward -174.0 Maximum Reward -114.0 EPSILON 0.020048906868060788
# Episode 395 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.01984841779938018
# Episode 396 Episodic Reward -190.0 Maximum Reward -114.0 EPSILON 0.019649933621386378
# Episode 397 Episodic Reward -190.0 Maximum Reward -114.0 EPSILON 0.019453434285172513
# Episode 398 Episodic Reward -195.0 Maximum Reward -114.0 EPSILON 0.019258899942320787
# Episode 399 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.01906631094289758
# Episode 400 Episodic Reward -191.0 Maximum Reward -114.0 EPSILON 0.018875647833468602
# Episode 401 Episodic Reward -176.0 Maximum Reward -114.0 EPSILON 0.018686891355133916
# Episode 402 Episodic Reward -179.0 Maximum Reward -114.0 EPSILON 0.018500022441582577
# Episode 403 Episodic Reward -183.0 Maximum Reward -114.0 EPSILON 0.01831502221716675
# Episode 404 Episodic Reward -182.0 Maximum Reward -114.0 EPSILON 0.018131871994995084
# Episode 405 Episodic Reward -196.0 Maximum Reward -114.0 EPSILON 0.017950553275045134
# Episode 406 Episodic Reward -189.0 Maximum Reward -114.0 EPSILON 0.017771047742294682
# Episode 407 Episodic Reward -180.0 Maximum Reward -114.0 EPSILON 0.017593337264871736
# Episode 408 Episodic Reward -115.0 Maximum Reward -114.0 EPSILON 0.01741740389222302
# Episode 409 Episodic Reward -194.0 Maximum Reward -114.0 EPSILON 0.01724322985330079
# Episode 410 Episodic Reward -163.0 Maximum Reward -114.0 EPSILON 0.017070797554767782
# Episode 411 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.016900089579220106
# Episode 412 Episodic Reward -186.0 Maximum Reward -114.0 EPSILON 0.016731088683427906
# Episode 413 Episodic Reward -191.0 Maximum Reward -114.0 EPSILON 0.016563777796593626
# Episode 414 Episodic Reward -185.0 Maximum Reward -114.0 EPSILON 0.016398140018627688
# Episode 415 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.01623415861844141
# Episode 416 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.016071817032256998
# Episode 417 Episodic Reward -187.0 Maximum Reward -114.0 EPSILON 0.01591109886193443
# Episode 418 Episodic Reward -198.0 Maximum Reward -114.0 EPSILON 0.015751987873315085
# Episode 419 Episodic Reward -192.0 Maximum Reward -114.0 EPSILON 0.015594467994581935
# Episode 420 Episodic Reward -196.0 Maximum Reward -114.0 EPSILON 0.015438523314636115
# Episode 421 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.015284138081489753
# Episode 422 Episodic Reward -152.0 Maximum Reward -114.0 EPSILON 0.015131296700674856
# Episode 423 Episodic Reward -147.0 Maximum Reward -114.0 EPSILON 0.014979983733668108
# Episode 424 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.014830183896331426
# Episode 425 Episodic Reward -175.0 Maximum Reward -114.0 EPSILON 0.014681882057368112
# Episode 426 Episodic Reward -174.0 Maximum Reward -114.0 EPSILON 0.01453506323679443
# Episode 427 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.014389712604426485
# Episode 428 Episodic Reward -193.0 Maximum Reward -114.0 EPSILON 0.01424581547838222
# Episode 429 Episodic Reward -185.0 Maximum Reward -114.0 EPSILON 0.014103357323598397
# Episode 430 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.013962323750362413
# Episode 431 Episodic Reward -197.0 Maximum Reward -114.0 EPSILON 0.013822700512858789
# Episode 432 Episodic Reward -186.0 Maximum Reward -114.0 EPSILON 0.0136844735077302
# Episode 433 Episodic Reward -199.0 Maximum Reward -114.0 EPSILON 0.013547628772652899
# Episode 434 Episodic Reward -162.0 Maximum Reward -114.0 EPSILON 0.01341215248492637
# Episode 435 Episodic Reward -183.0 Maximum Reward -114.0 EPSILON 0.013278030960077106
# Episode 436 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.013145250650476335
# Episode 437 Episodic Reward -162.0 Maximum Reward -114.0 EPSILON 0.01301379814397157
# Episode 438 Episodic Reward -197.0 Maximum Reward -114.0 EPSILON 0.012883660162531854
# Episode 439 Episodic Reward -197.0 Maximum Reward -114.0 EPSILON 0.012754823560906535
# Episode 440 Episodic Reward -170.0 Maximum Reward -114.0 EPSILON 0.01262727532529747
# Episode 441 Episodic Reward -166.0 Maximum Reward -114.0 EPSILON 0.012501002572044496
# Episode 442 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.01237599254632405
# Episode 443 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.01225223262086081
# Episode 444 Episodic Reward -121.0 Maximum Reward -114.0 EPSILON 0.012129710294652202
# Episode 445 Episodic Reward -194.0 Maximum Reward -114.0 EPSILON 0.01200841319170568
# Episode 446 Episodic Reward -183.0 Maximum Reward -114.0 EPSILON 0.011888329059788623
# Episode 447 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.011769445769190737
# Episode 448 Episodic Reward -184.0 Maximum Reward -114.0 EPSILON 0.01165175131149883
# Episode 449 Episodic Reward -170.0 Maximum Reward -114.0 EPSILON 0.011535233798383842
# Episode 450 Episodic Reward -182.0 Maximum Reward -114.0 EPSILON 0.011419881460400004
# Episode 451 Episodic Reward -182.0 Maximum Reward -114.0 EPSILON 0.011305682645796004
# Episode 452 Episodic Reward -198.0 Maximum Reward -114.0 EPSILON 0.011192625819338045
# Episode 453 Episodic Reward -173.0 Maximum Reward -114.0 EPSILON 0.011080699561144665
# Episode 454 Episodic Reward -174.0 Maximum Reward -114.0 EPSILON 0.010969892565533218
# Episode 455 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.010860193639877886
# Episode 456 Episodic Reward -124.0 Maximum Reward -114.0 EPSILON 0.010751591703479106
# Episode 457 Episodic Reward -194.0 Maximum Reward -114.0 EPSILON 0.010644075786444315
# Episode 458 Episodic Reward -197.0 Maximum Reward -114.0 EPSILON 0.010537635028579873
# Episode 459 Episodic Reward -185.0 Maximum Reward -114.0 EPSILON 0.010432258678294073
# Episode 460 Episodic Reward -185.0 Maximum Reward -114.0 EPSILON 0.010327936091511133
# Episode 461 Episodic Reward -175.0 Maximum Reward -114.0 EPSILON 0.010224656730596022
# Episode 462 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.01012241016329006
# Episode 463 Episodic Reward -183.0 Maximum Reward -114.0 EPSILON 0.01002118606165716
# Episode 464 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.009920974201040588
# Episode 465 Episodic Reward -186.0 Maximum Reward -114.0 EPSILON 0.009821764459030182
# Episode 466 Episodic Reward -187.0 Maximum Reward -114.0 EPSILON 0.00972354681443988
# Episode 467 Episodic Reward -178.0 Maximum Reward -114.0 EPSILON 0.00962631134629548
# Episode 468 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.009530048232832525
# Episode 469 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.009434747750504199
# Episode 470 Episodic Reward -186.0 Maximum Reward -114.0 EPSILON 0.009340400272999157
# Episode 471 Episodic Reward -196.0 Maximum Reward -114.0 EPSILON 0.009246996270269165
# Episode 472 Episodic Reward -196.0 Maximum Reward -114.0 EPSILON 0.009154526307566474
# Episode 473 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.009062981044490808
# Episode 474 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.0089723512340459
# Episode 475 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.00888262772170544
# Episode 476 Episodic Reward -175.0 Maximum Reward -114.0 EPSILON 0.008793801444488386
# Episode 477 Episodic Reward -185.0 Maximum Reward -114.0 EPSILON 0.008705863430043502
# Episode 478 Episodic Reward -187.0 Maximum Reward -114.0 EPSILON 0.008618804795743068
# Episode 479 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.008532616747785637
# Episode 480 Episodic Reward -126.0 Maximum Reward -114.0 EPSILON 0.00844729058030778
# Episode 481 Episodic Reward -183.0 Maximum Reward -114.0 EPSILON 0.008362817674504702
# Episode 482 Episodic Reward -188.0 Maximum Reward -114.0 EPSILON 0.008279189497759654
# Episode 483 Episodic Reward -183.0 Maximum Reward -114.0 EPSILON 0.008196397602782058
# Episode 484 Episodic Reward -184.0 Maximum Reward -114.0 EPSILON 0.008114433626754238
# Episode 485 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.008033289290486696
# Episode 486 Episodic Reward -182.0 Maximum Reward -114.0 EPSILON 0.00795295639758183
# Episode 487 Episodic Reward -186.0 Maximum Reward -114.0 EPSILON 0.00787342683360601
# Episode 488 Episodic Reward -176.0 Maximum Reward -114.0 EPSILON 0.0077946925652699495
# Episode 489 Episodic Reward -192.0 Maximum Reward -114.0 EPSILON 0.00771674563961725
# Episode 490 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.007639578183221077
# Episode 491 Episodic Reward -187.0 Maximum Reward -114.0 EPSILON 0.0075631824013888665
# Episode 492 Episodic Reward -170.0 Maximum Reward -114.0 EPSILON 0.007487550577374978
# Episode 493 Episodic Reward -196.0 Maximum Reward -114.0 EPSILON 0.007412675071601228
# Episode 494 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.007338548320885215
# Episode 495 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.0072651628376763635
# Episode 496 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.0071925112092996
# Episode 497 Episodic Reward -170.0 Maximum Reward -114.0 EPSILON 0.007120586097206604
# Episode 498 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.007049380236234538
# Episode 499 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.006978886433872193
# Episode 500 Episodic Reward -189.0 Maximum Reward -114.0 EPSILON 0.006909097569533471
# Episode 501 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.006840006593838137
# Episode 502 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.0067716065278997555
# Episode 503 Episodic Reward -186.0 Maximum Reward -114.0 EPSILON 0.006703890462620758
# Episode 504 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.006636851557994551
# Episode 505 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.006570483042414605
# Episode 506 Episodic Reward -182.0 Maximum Reward -114.0 EPSILON 0.006504778211990459
# Episode 507 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.006439730429870554
# Episode 508 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.0063753331255718484
# Episode 509 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.00631157979431613
# Episode 510 Episodic Reward -181.0 Maximum Reward -114.0 EPSILON 0.006248463996372969
# Episode 511 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.006185979356409239
# Episode 512 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.006124119562845147
# Episode 513 Episodic Reward -187.0 Maximum Reward -114.0 EPSILON 0.006062878367216695
# Episode 514 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.006002249583544528
# Episode 515 Episodic Reward -175.0 Maximum Reward -114.0 EPSILON 0.005942227087709083
# Episode 516 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.005882804816831992
# Episode 517 Episodic Reward -186.0 Maximum Reward -114.0 EPSILON 0.005823976768663672
# Episode 518 Episodic Reward -183.0 Maximum Reward -114.0 EPSILON 0.005765737000977035
# Episode 519 Episodic Reward -183.0 Maximum Reward -114.0 EPSILON 0.005708079630967265
# Episode 520 Episodic Reward -127.0 Maximum Reward -114.0 EPSILON 0.005650998834657592
# Episode 521 Episodic Reward -125.0 Maximum Reward -114.0 EPSILON 0.005594488846311016
# Episode 522 Episodic Reward -185.0 Maximum Reward -114.0 EPSILON 0.005538543957847906
# Episode 523 Episodic Reward -184.0 Maximum Reward -114.0 EPSILON 0.005483158518269427
# Episode 524 Episodic Reward -184.0 Maximum Reward -114.0 EPSILON 0.005428326933086733
# Episode 525 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.005374043663755866
# Episode 526 Episodic Reward -190.0 Maximum Reward -114.0 EPSILON 0.005320303227118307
# Episode 527 Episodic Reward -192.0 Maximum Reward -114.0 EPSILON 0.005267100194847124
# Episode 528 Episodic Reward -179.0 Maximum Reward -114.0 EPSILON 0.005214429192898652
# Episode 529 Episodic Reward -123.0 Maximum Reward -114.0 EPSILON 0.005162284900969666
# Episode 530 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.005110662051959969
# Episode 531 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.005059555431440369
# Episode 532 Episodic Reward -186.0 Maximum Reward -114.0 EPSILON 0.005008959877125965
# Episode 533 Episodic Reward -175.0 Maximum Reward -114.0 EPSILON 0.004958870278354705
# Episode 534 Episodic Reward -189.0 Maximum Reward -114.0 EPSILON 0.004909281575571158
# Episode 535 Episodic Reward -191.0 Maximum Reward -114.0 EPSILON 0.004860188759815446
# Episode 536 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.004811586872217292
# Episode 537 Episodic Reward -175.0 Maximum Reward -114.0 EPSILON 0.004763471003495119
# Episode 538 Episodic Reward -183.0 Maximum Reward -114.0 EPSILON 0.004715836293460168
# Episode 539 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.004668677930525566
# Episode 540 Episodic Reward -190.0 Maximum Reward -114.0 EPSILON 0.00462199115122031
# Episode 541 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.004575771239708107
# Episode 542 Episodic Reward -187.0 Maximum Reward -114.0 EPSILON 0.004530013527311026
# Episode 543 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.004484713392037916
# Episode 544 Episodic Reward -183.0 Maximum Reward -114.0 EPSILON 0.004439866258117537
# Episode 545 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.004395467595536362
# Episode 546 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.004351512919580998
# Episode 547 Episodic Reward -186.0 Maximum Reward -114.0 EPSILON 0.004307997790385188
# Episode 548 Episodic Reward -182.0 Maximum Reward -114.0 EPSILON 0.004264917812481336
# Episode 549 Episodic Reward -183.0 Maximum Reward -114.0 EPSILON 0.0042222686343565225
# Episode 550 Episodic Reward -184.0 Maximum Reward -114.0 EPSILON 0.0041800459480129575
# Episode 551 Episodic Reward -180.0 Maximum Reward -114.0 EPSILON 0.0041382454885328275
# Episode 552 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.004096863033647499
# Episode 553 Episodic Reward -182.0 Maximum Reward -114.0 EPSILON 0.0040558944033110235
# Episode 554 Episodic Reward -180.0 Maximum Reward -114.0 EPSILON 0.0040153354592779135
# Episode 555 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.0039751821046851345
# Episode 556 Episodic Reward -200.0 Maximum Reward -114.0 EPSILON 0.003935430283638283
# Episode 557 Episodic Reward -193.0 Maximum Reward -114.0 EPSILON 0.0038960759808019003
# Episode 558 Episodic Reward -181.0 Maximum Reward -114.0 EPSILON 0.003857115220993881
# Episode 559 Episodic Reward -182.0 Maximum Reward -114.0 EPSILON 0.003818544068783942
# Episode 560 Episodic Reward -196.0 Maximum Reward -114.0 EPSILON 0.0037803586280961026
# Episode 561 Episodic Reward -181.0 Maximum Reward -114.0 EPSILON 0.0037425550418151415
# Saving the model with reward -93.0
# Episode 562 Episodic Reward -93.0 Maximum Reward -93.0 EPSILON 0.00370512949139699
# Episode 563 Episodic Reward -182.0 Maximum Reward -93.0 EPSILON 0.0036680781964830204
# Episode 564 Episodic Reward -93.0 Maximum Reward -93.0 EPSILON 0.00363139741451819
# Episode 565 Episodic Reward -200.0 Maximum Reward -93.0 EPSILON 0.003595083440373008
# Episode 566 Episodic Reward -190.0 Maximum Reward -93.0 EPSILON 0.003559132605969278
# Episode 567 Episodic Reward -200.0 Maximum Reward -93.0 EPSILON 0.003523541279909585
# Episode 568 Episodic Reward -200.0 Maximum Reward -93.0 EPSILON 0.003488305867110489
# Episode 569 Episodic Reward -200.0 Maximum Reward -93.0 EPSILON 0.0034534228084393843
# Episode 570 Episodic Reward -179.0 Maximum Reward -93.0 EPSILON 0.0034188885803549903
# Episode 571 Episodic Reward -93.0 Maximum Reward -93.0 EPSILON 0.0033846996945514404
# Episode 572 Episodic Reward -179.0 Maximum Reward -93.0 EPSILON 0.003350852697605926
# Episode 573 Episodic Reward -194.0 Maximum Reward -93.0 EPSILON 0.0033173441706298664
# Episode 574 Episodic Reward -180.0 Maximum Reward -93.0 EPSILON 0.0032841707289235677
# Episode 575 Episodic Reward -181.0 Maximum Reward -93.0 EPSILON 0.0032513290216343318
# Episode 576 Episodic Reward -200.0 Maximum Reward -93.0 EPSILON 0.0032188157314179885
# Episode 577 Episodic Reward -200.0 Maximum Reward -93.0 EPSILON 0.003186627574103809
# Episode 578 Episodic Reward -181.0 Maximum Reward -93.0 EPSILON 0.0031547612983627705
# Episode 579 Episodic Reward -179.0 Maximum Reward -93.0 EPSILON 0.003123213685379143
# Episode 580 Episodic Reward -180.0 Maximum Reward -93.0 EPSILON 0.0030919815485253516
# Episode 581 Episodic Reward -180.0 Maximum Reward -93.0 EPSILON 0.003061061733040098
# Episode 582 Episodic Reward -180.0 Maximum Reward -93.0 EPSILON 0.003030451115709697
# Episode 583 Episodic Reward -180.0 Maximum Reward -93.0 EPSILON 0.0030001466045526
# Episode 584 Episodic Reward -200.0 Maximum Reward -93.0 EPSILON 0.002970145138507074
# Episode 585 Episodic Reward -200.0 Maximum Reward -93.0 EPSILON 0.002940443687122003
# Episode 586 Episodic Reward -200.0 Maximum Reward -93.0 EPSILON 0.002911039250250783
# Episode 587 Episodic Reward -200.0 Maximum Reward -93.0 EPSILON 0.0028819288577482754
# Episode 588 Episodic Reward -200.0 Maximum Reward -93.0 EPSILON 0.0028531095691707925
# Episode 589 Episodic Reward -187.0 Maximum Reward -93.0 EPSILON 0.0028245784734790844
# Episode 590 Episodic Reward -189.0 Maximum Reward -93.0 EPSILON 0.0027963326887442937
# Episode 591 Episodic Reward -200.0 Maximum Reward -93.0 EPSILON 0.0027683693618568506
# Episode 592 Episodic Reward -185.0 Maximum Reward -93.0 EPSILON 0.002740685668238282
# Episode 593 Episodic Reward -184.0 Maximum Reward -93.0 EPSILON 0.0027132788115558993
# Episode 594 Episodic Reward -185.0 Maximum Reward -93.0 EPSILON 0.0026861460234403403
# Episode 595 Episodic Reward -178.0 Maximum Reward -93.0 EPSILON 0.002659284563205937
# Episode 596 Episodic Reward -185.0 Maximum Reward -93.0 EPSILON 0.0026326917175738774
# Episode 597 Episodic Reward -200.0 Maximum Reward -93.0 EPSILON 0.0026063648003981387
# Episode 598 Episodic Reward -183.0 Maximum Reward -93.0 EPSILON 0.0025803011523941573
# Episode 599 Episodic Reward -181.0 Maximum Reward -93.0 EPSILON 0.0025544981408702158

# %%
plt.plot(q_values)
plt.xlabel('Episode')
plt.ylabel('Average Q-value')
plt.title('Q-value Convergence')
plt.show()

# %% [markdown]
# # Plot Rewards vs episodes [Section 5.3]

# %%
plt.figure(figsize=(8, 4))
plt.plot(rewards)
plt.xlabel("episodes", fontsize=14)
plt.ylabel("Rewards", fontsize=14)
plt.title("Rewards vs. Episodes", fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# # Plotting moving average of rewards over the last 50 episodes [Section 5.3]

# %%
mean_rewards = np.zeros(600)
for t in range(600):
    # plotting the moving average over the last 50 episodes
    mean_rewards[t] = np.mean(rewards[max(0, t-50):(t+1)])
plt.plot(mean_rewards)
plt.xlabel("Episode", fontsize=14)
plt.ylabel("Reward", fontsize=14)
plt.title("Moving average over 50 episodes", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Moving average over 50 episodes')

# %% [markdown]
# # Moving Average over episodes [Section 5.3]

# %%
import pandas as pd
rewards_series = pd.Series(rewards)
window_size = 20
rewards_moving_average = rewards_series.rolling(window=window_size).mean()
plt.figure(figsize=(12, 6))
plt.plot(rewards, alpha=0.5, label='Original Rewards')
plt.plot(rewards_moving_average, color='red', linewidth=2, label='Moving Average of Rewards')
plt.title("Moving Average of Episode Rewards")
plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.legend()
plt.show()

# %% [markdown]
# ## Position vs. Velocity [Section 5.3]

# %%
import matplotlib.patches as mpatches
# List of possible positions
X = np.random.uniform(-1.2, 0.6, 111043)
# List of possible velocities
Y = np.random.uniform(-0.07, 0.07, 111043)

# For each possible state, retreive the most rewarding action and record it
actions = []

colors = {0:'blue',1:'lime',2:'red'}
# Convert action_taken to array
actions = np.array(actiion_taken)
# Map action indices to colors
colors = np.array([colors[action] for action in actions])
labels = ['Left',  'Nothing', 'Right']

# Visualize the policy
fig = plt.figure(3, figsize=[7,7])
ax = fig.gca()
plt.set_cmap('brg')
# Plot scatter plot with X and Y as state[0] and state[1]
surf = ax.scatter(X, Y, c=colors)
ax.set_xlabel('Position')
ax.set_ylabel('Velocity')
ax.set_title('Policy')
recs = []
unique_colors = np.unique(colors)
for i in range(len(unique_colors)):
     recs.append(mpatches.Rectangle((0,0),1,1,fc=unique_colors[i]))
plt.legend(recs,labels,loc=4,ncol=3)
plt.show()

# %% [markdown]
# <span style='color:green'>The above position vs velocity graph tells us the actions taken by the car at each position and velocity. As expected the car(agent) chose to move left(blue) and right(red) more often than staying and doing nothing(green). This tells us that the agent was constantly moving around except for a fewew occasions where the reward obtained from it doing nothing, outweighed the rewards from moving left or right, as per Bellman Equation.</span>

# %% [markdown]
# ---------------------------------------------------------------------------------------------

# %% [markdown]
# # 3. Double DQN [Section 6]

# %% [markdown]
# <span style ='color:red'> There are two problems with vanilla DQN and Fixed DQN -> Maximization bias which is the problem of overestimating the action-values of a state, that is, the agent tends to believe certain actions are valuable even though it is not so. And this happens because we are referring to the same table values to select an action and evaluate that action. -> Catastrophic forgetting   </span>
#
# <span style ='color:red'> The solution to this problem of overestimation is using two different Q tables (that is two different neural network models).
# The best action can be taken based on the first Q table values and tha target value can be taken on the second Q table values </span>

# %% [markdown]
# ## Importing required packages and libraries

# %%
import imageio
import matplotlib.pyplot as plt
import pandas as pd

# %%
random.seed(2212)
np.random.seed(2212)
tf.random.set_seed(2212)

# %% [markdown]
# ## Defining Hyperparameters

# %%
# The number of sequential interacgtions the car has with its environment.
EPISODES = 600
# The size of the experience replay (section ---)
REPLAY_MEMORY_SIZE = 1_00_000
# Minimum size of experience replay required
MINIMUM_REPLAY_MEMORY = 1_000
# The number of sample we fetch from the experience replay during training
MINIBATCH_SIZE = 32
# The hyperparameter which balances exploration and exploitation by agent
EPSILON = 0.1
# The rate at which the epsilon decreases
EPSILON_DECAY = 0.99
MINIMUM_EPSILON = 0.001
# The discount factor which doiscunts future reward in favor of immediate reward (gamma)
DISCOUNT = 0.99
# The number of episodes before run before the learning is recorded
record_frequency = 20

# %% [markdown]
# ## Defining the Simulated Environment

# %%
# The simulated environment used by the agent (car)
ENV_NAME = 'MountainCar-v0'
# Creates an environment
env = gym.make(ENV_NAME)
# Returns dimensionality of action space (0-> push left, 1-> no acceleration, 2-> push right)
action_dim = env.action_space.n
# Returns dimensionality of observation space (position [-1.2, 0.6], velocity[-0.07,0.07])
observation_dim = env.observation_space.shape

# %% [markdown]
# ## Defining Deep Q Network model and Target Network Model

# %%
# Creating simple sequential neural network model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(400, activation='relu', input_shape=observation_dim),
    tf.keras.layers.Dense(300, activation='relu'),
    tf.keras.layers.Dense(action_dim, activation='linear')
])

'''Compiling the neural network using Mean Square Error as loss function and
Adam as the optimizer which will learn at a rate of 0.005'''
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(learning_rate=0.005))
# Creating target network model which is the same as Deep Q network by cloning it
target_model1 = tf.keras.models.clone_model(model)

# %% [markdown]
# ## Defining Epsilon Greedy Policy

# %%
'''Defining epsilon greedy policy function to determine an action
to decide whether to explore or exploit the knowledge acquired'''
def epsilon_greedy_policy(state, epsilon):
    # Explore if random value from uniform distribution is less than exploration factor epsilon
    if np.random.uniform(0, 1) < epsilon:
        action = np.random.randint(0, action_dim)
        return action
    else:
    # Exploit
        action = np.argmax(model.predict(np.expand_dims(state, axis=0), verbose=0)[0])
        return action

# %% [markdown]
# ## Defining the step function

# %%
max_reward = -999999


'''This function defines the steps the agent has to take based on the epsilon greedy policy
 and accumulates the reward'''
def play_one_step(env, state, epsilon, episode_length):
    # defining reward acquired in each episode
    global episode_reward
    # Calling epsilon greedy function to select action
    action = epsilon_greedy_policy(state, epsilon)
    # Executing the action and returns 4 values
    next_state, reward, done, info = env.step(action)
    # accumulating rewards in each step of the epsiode(max=-200)
    episode_reward += reward
    # truncating if the car reaches the flag on the mountain top within 200 steps
    if done and episode_length < 200:
        # If episode is ended then we have won the game. Defining Stratagem to make the agent learn faster
        reward = 250 + episode_reward
        # save the model weights if we get a epsiode reward greater than maximum reward defined
        # if(episode_reward > max_reward):
            # print("Saving the model with reward", episode_reward)
            # model.save_weights("agent"+str(episode_reward)+"_agent_.weights.h5")
    else:
        # In oher cases reward will be proportional to the distance that car has travelled
        # from it's previous location + velocity of the car
        reward = 5*abs(next_state[0] - state[0]) + 3*abs(state[1])

    # append this result to the replay buffer(experince replay)
    replay_buffer.append((state, action, reward, next_state, done))

    return next_state, episode_reward, max_reward, done, info

# %% [markdown]
# ## Sampling experience and Training function [Section 6.3]

# %%
# Replay memory (experience replay) to store experiances of the model with the environment
replay_buffer = deque(maxlen=REPLAY_MEMORY_SIZE)
rewards = []

def training_step(MINIBATCH_SIZE):
    # Samples batches of size MiniBatch_size(32) from  the replay buffer
    minibatch = random.sample(replay_buffer, MINIBATCH_SIZE)
    # Array containing current state values from each sample in the minibatch
    X_cur_states = np.array([sample[0] for sample in minibatch])
    # Array containing next state values from each sample in the minibatch
    X_next_states = np.array([sample[3] for sample in minibatch])

    # Predicting the action using main neural network 
    '''The inputs for the Neural Network selecting the action using main network.
    This uses the main neural network model to predict the current Q-values for all actions given the current states'''
    cur_action_values = model.predict(X_cur_states, verbose=0)
    
    ''' This step predicts the Q-values for the next states using the same main network and
    helps to decide the next action to take'''
    next_action_values_main = model.predict(X_next_states, verbose=0)
    # Evaluating the action using target network
    ''' This uses a separate target network to predict the Q-values for the next states. 
    This target network is an older version of the main network and is used to stabilize the training'''
    next_action_values_target = target_model1.predict(X_next_states, verbose=0)

    # This loop iterates over each sample from sample experience
    for index, (cur_state, action, reward, next_state, done) in enumerate(minibatch):
        # If the episode is not completed,
        if not done:
            # Return action with highest Q value in next state as per the main neural network
            best_action_next = np.argmax(next_action_values_main[index])
            ''' The bellman equation is updated to to return Q value for the action taken using reward, 
            discount and best next action from the target network and not the main network'''
            cur_action_values[index][action] = reward + DISCOUNT * next_action_values_target[index][best_action_next]
        else:
            cur_action_values[index][action] = reward
    # updates model weights using Q values to minimize the error between target value and predicted value.
    model.fit(X_cur_states, cur_action_values, verbose=0)

# %% [markdown]
# ## Running the episodes

# %%
episode_lengths = [] 
# Looping through episodes
for episode in range(EPISODES):
    # resetting the environment for the state to be reset
    state = env.reset()
    # initializing variables used
    done = False
    episode_reward = 0
    episode_length = 0
    # creating a list to capture and append the learning through animation
    frames = []

    # Running through different sets of steps
    while not done:
        # incrementing episode length(number of steps)
        episode_length += 1
        # calling the play_one_step function to execute the steps
        next_state, reward, max_reward, done, info  = play_one_step(env,state, EPSILON, episode_length)
        # update the current state with the next state for the episode to continue
        state = next_state

        # Checking if the replay buffer size is less than the minimum required replay buffer size for training to start
        if(len(replay_buffer) < MINIMUM_REPLAY_MEMORY):
            continue
        # when the minimum replay buffer size is populated
        training_step(MINIBATCH_SIZE)

        # Recording and collecting the learning through frames for every 20 episodes
        if episode % record_frequency ==0:
            frames.append(env.render(mode='rgb_array'))

    # # Creating learning animation
    if episode % record_frequency ==0:
            imageio.mimsave(f'episode_{episode}.mp4', frames, fps=30)

    # recording the values for visualizing the results
    max_reward = max(reward, max_reward)
    print('Episode', episode, 'Episodic Reward', reward, 'Maximum Reward', max_reward, 'EPSILON', EPSILON)
    rewards.append(reward)

    # Saving the weights for the episode that received maximum reward
    if episode % 20 == 0:
        target_model1.set_weights(model.get_weights())
    # Epsilon decay for the next episode
    if(EPSILON > MINIMUM_EPSILON and len(replay_buffer) > MINIMUM_REPLAY_MEMORY):
        EPSILON *= EPSILON_DECAY

    # recording the number of time steps taken by agent from the beginning of an episode to its termination
    episode_lengths.append(episode_length)
# Out:
# Episode 0 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.1
# Episode 1 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.1
# Episode 2 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.1
# Episode 3 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.1
# Episode 4 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.1
# Episode 5 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.1
# Episode 6 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.099
# Episode 7 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.09801
# Episode 8 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.0970299
# Episode 9 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.096059601
# Episode 10 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.09509900499
# Episode 11 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.0941480149401
# Episode 12 Episodic Reward -174.0 Maximum Reward -174.0 EPSILON 0.093206534790699
# Episode 13 Episodic Reward -200.0 Maximum Reward -174.0 EPSILON 0.09227446944279201
# Episode 14 Episodic Reward -200.0 Maximum Reward -174.0 EPSILON 0.09135172474836409
# Episode 15 Episodic Reward -200.0 Maximum Reward -174.0 EPSILON 0.09043820750088044
# Episode 16 Episodic Reward -200.0 Maximum Reward -174.0 EPSILON 0.08953382542587164
# Episode 17 Episodic Reward -200.0 Maximum Reward -174.0 EPSILON 0.08863848717161292
# Episode 18 Episodic Reward -200.0 Maximum Reward -174.0 EPSILON 0.08775210229989679
# Episode 19 Episodic Reward -200.0 Maximum Reward -174.0 EPSILON 0.08687458127689782
# Episode 20 Episodic Reward -200.0 Maximum Reward -174.0 EPSILON 0.08600583546412884
# Episode 21 Episodic Reward -200.0 Maximum Reward -174.0 EPSILON 0.08514577710948755
# Episode 22 Episodic Reward -164.0 Maximum Reward -164.0 EPSILON 0.08429431933839267
# Episode 23 Episodic Reward -200.0 Maximum Reward -164.0 EPSILON 0.08345137614500873
# Episode 24 Episodic Reward -200.0 Maximum Reward -164.0 EPSILON 0.08261686238355864
# Episode 25 Episodic Reward -200.0 Maximum Reward -164.0 EPSILON 0.08179069375972306
# Episode 26 Episodic Reward -200.0 Maximum Reward -164.0 EPSILON 0.08097278682212583
# Episode 27 Episodic Reward -194.0 Maximum Reward -164.0 EPSILON 0.08016305895390458
# Episode 28 Episodic Reward -200.0 Maximum Reward -164.0 EPSILON 0.07936142836436554
# Episode 29 Episodic Reward -200.0 Maximum Reward -164.0 EPSILON 0.07856781408072187
# Episode 30 Episodic Reward -200.0 Maximum Reward -164.0 EPSILON 0.07778213593991465
# Episode 31 Episodic Reward -200.0 Maximum Reward -164.0 EPSILON 0.0770043145805155
# Episode 32 Episodic Reward -200.0 Maximum Reward -164.0 EPSILON 0.07623427143471034
# Episode 33 Episodic Reward -200.0 Maximum Reward -164.0 EPSILON 0.07547192872036323
# Episode 34 Episodic Reward -200.0 Maximum Reward -164.0 EPSILON 0.0747172094331596
# Episode 35 Episodic Reward -122.0 Maximum Reward -122.0 EPSILON 0.073970037338828
# Episode 36 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.07323033696543972
# Episode 37 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.07249803359578533
# Episode 38 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.07177305325982747
# Episode 39 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.0710553227272292
# Episode 40 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.07034476949995691
# Episode 41 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.06964132180495734
# Episode 42 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.06894490858690777
# Episode 43 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.06825545950103869
# Episode 44 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.0675729049060283
# Episode 45 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.06689717585696801
# Episode 46 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.06622820409839833
# Episode 47 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.06556592205741435
# Episode 48 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.0649102628368402
# Episode 49 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.06426116020847181
# Episode 50 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.06361854860638709
# Episode 51 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.06298236312032322
# Episode 52 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.06235253948911999
# Episode 53 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.06172901409422879
# Episode 54 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.061111723953286505
# Episode 55 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.06050060671375364
# Episode 56 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.0598956006466161
# Episode 57 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.05929664464014994
# Episode 58 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.05870367819374844
# Episode 59 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.05811664141181096
# Episode 60 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.05753547499769285
# Episode 61 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.05696012024771592
# Episode 62 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.05639051904523876
# Episode 63 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.05582661385478637
# Episode 64 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.05526834771623851
# Episode 65 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.054715664239076124
# Episode 66 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.054168507596685365
# Episode 67 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.053626822520718515
# Episode 68 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.05309055429551133
# Episode 69 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.05255964875255621
# Episode 70 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.05203405226503065
# Episode 71 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.05151371174238034
# Episode 72 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.050998574624956536
# Episode 73 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.05048858887870697
# Episode 74 Episodic Reward -153.0 Maximum Reward -122.0 EPSILON 0.0499837029899199
# Episode 75 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.049483865960020704
# Episode 76 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.0489890273004205
# Episode 77 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.048499137027416296
# Episode 78 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.048014145657142134
# Episode 79 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.04753400420057071
# Episode 80 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.047058664158565
# Episode 81 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.046588077516979354
# Episode 82 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.04612219674180956
# Episode 83 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.04566097477439147
# Episode 84 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.045204365026647556
# Episode 85 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.04475232137638108
# Episode 86 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.044304798162617266
# Episode 87 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.043861750180991095
# Episode 88 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.04342313267918119
# Episode 89 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.04298890135238938
# Episode 90 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.042559012338865485
# Episode 91 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.04213342221547683
# Episode 92 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.04171208799332206
# Episode 93 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.041294967113388835
# Episode 94 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.04088201744225495
# Episode 95 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.0404731972678324
# Episode 96 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.04006846529515407
# Episode 97 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.039667780642202534
# Episode 98 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.03927110283578051
# Episode 99 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.0388783918074227
# Episode 100 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.03848960788934848
# Episode 101 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.038104711810454994
# Episode 102 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.037723664692350445
# Episode 103 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.03734642804542694
# Episode 104 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.03697296376497267
# Episode 105 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.03660323412732295
# Episode 106 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.03623720178604972
# Episode 107 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.035874829768189224
# Episode 108 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.03551608147050733
# Episode 109 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.03516092065580226
# Episode 110 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.034809311449244235
# Episode 111 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.03446121833475179
# Episode 112 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.03411660615140427
# Episode 113 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.03377544008989023
# Episode 114 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.03343768568899133
# Episode 115 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.03310330883210142
# Episode 116 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.03277227574378041
# Episode 117 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.032444552986342606
# Episode 118 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.03212010745647918
# Episode 119 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.03179890638191439
# Episode 120 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.03148091731809525
# Episode 121 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.031166108144914297
# Episode 122 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.030854447063465153
# Episode 123 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.030545902592830503
# Episode 124 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.030240443566902198
# Episode 125 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.029938039131233177
# Episode 126 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.029638658739920845
# Episode 127 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.029342272152521637
# Episode 128 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.02904884943099642
# Episode 129 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.028758360936686458
# Episode 130 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.028470777327319594
# Episode 131 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.028186069554046397
# Episode 132 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.027904208858505933
# Episode 133 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.027625166769920873
# Episode 134 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.027348915102221663
# Episode 135 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.027075425951199446
# Episode 136 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.026804671691687453
# Episode 137 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.02653662497477058
# Episode 138 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.026271258725022874
# Episode 139 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.026008546137772644
# Episode 140 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.025748460676394917
# Episode 141 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.025490976069630966
# Episode 142 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.025236066308934657
# Episode 143 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.02498370564584531
# Episode 144 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.024733868589386858
# Episode 145 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.02448652990349299
# Episode 146 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.02424166460445806
# Episode 147 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.02399924795841348
# Episode 148 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.023759255478829344
# Episode 149 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.02352166292404105
# Episode 150 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.02328644629480064
# Episode 151 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.023053581831852635
# Episode 152 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.022823046013534107
# Episode 153 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.022594815553398765
# Episode 154 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.022368867397864776
# Episode 155 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.02214517872388613
# Episode 156 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.021923726936647268
# Episode 157 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.021704489667280794
# Episode 158 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.021487444770607985
# Episode 159 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.021272570322901904
# Episode 160 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.021059844619672884
# Episode 161 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.020849246173476155
# Episode 162 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.020640753711741393
# Episode 163 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.020434346174623978
# Episode 164 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.020230002712877736
# Episode 165 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.02002770268574896
# Episode 166 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.01982742565889147
# Episode 167 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.019629151402302553
# Episode 168 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.019432859888279527
# Episode 169 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.019238531289396732
# Episode 170 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.019046145976502765
# Episode 171 Episodic Reward -200.0 Maximum Reward -122.0 EPSILON 0.018855684516737737
# Episode 172 Episodic Reward -178.0 Maximum Reward -122.0 EPSILON 0.01866712767157036
# Episode 173 Episodic Reward -150.0 Maximum Reward -122.0 EPSILON 0.018480456394854655
# Episode 174 Episodic Reward -117.0 Maximum Reward -117.0 EPSILON 0.018295651830906107
# Episode 175 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.018112695312597047
# Episode 176 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.017931568359471076
# Episode 177 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.017752252675876365
# Episode 178 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.0175747301491176
# Episode 179 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.017398982847626424
# Episode 180 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.01722499301915016
# Episode 181 Episodic Reward -172.0 Maximum Reward -117.0 EPSILON 0.01705274308895866
# Episode 182 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.01688221565806907
# Episode 183 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.01671339350148838
# Episode 184 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.016546259566473494
# Episode 185 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.01638079697080876
# Episode 186 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.016216989001100673
# Episode 187 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.016054819111089667
# Episode 188 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.01589427091997877
# Episode 189 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.01573532821077898
# Episode 190 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.015577974928671192
# Episode 191 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.01542219517938448
# Episode 192 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.015267973227590634
# Episode 193 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.015115293495314729
# Episode 194 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.01496414056036158
# Episode 195 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.014814499154757965
# Episode 196 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.014666354163210386
# Episode 197 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.014519690621578282
# Episode 198 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.014374493715362499
# Episode 199 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.014230748778208874
# Episode 200 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.014088441290426785
# Episode 201 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.013947556877522518
# Episode 202 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.013808081308747293
# Episode 203 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.01367000049565982
# Episode 204 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.013533300490703223
# Episode 205 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.01339796748579619
# Episode 206 Episodic Reward -184.0 Maximum Reward -117.0 EPSILON 0.013263987810938228
# Episode 207 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.013131347932828845
# Episode 208 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.013000034453500557
# Episode 209 Episodic Reward -120.0 Maximum Reward -117.0 EPSILON 0.01287003410896555
# Episode 210 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.012741333767875895
# Episode 211 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.012613920430197136
# Episode 212 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.012487781225895164
# Episode 213 Episodic Reward -197.0 Maximum Reward -117.0 EPSILON 0.012362903413636212
# Episode 214 Episodic Reward -123.0 Maximum Reward -117.0 EPSILON 0.01223927437949985
# Episode 215 Episodic Reward -125.0 Maximum Reward -117.0 EPSILON 0.012116881635704851
# Episode 216 Episodic Reward -141.0 Maximum Reward -117.0 EPSILON 0.011995712819347802
# Episode 217 Episodic Reward -141.0 Maximum Reward -117.0 EPSILON 0.011875755691154323
# Episode 218 Episodic Reward -150.0 Maximum Reward -117.0 EPSILON 0.01175699813424278
# Episode 219 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.011639428152900352
# Episode 220 Episodic Reward -183.0 Maximum Reward -117.0 EPSILON 0.011523033871371349
# Episode 221 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.011407803532657634
# Episode 222 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.011293725497331058
# Episode 223 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.011180788242357747
# Episode 224 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.01106898035993417
# Episode 225 Episodic Reward -151.0 Maximum Reward -117.0 EPSILON 0.010958290556334828
# Episode 226 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.01084870765077148
# Episode 227 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.010740220574263765
# Episode 228 Episodic Reward -180.0 Maximum Reward -117.0 EPSILON 0.010632818368521127
# Episode 229 Episodic Reward -142.0 Maximum Reward -117.0 EPSILON 0.010526490184835915
# Episode 230 Episodic Reward -143.0 Maximum Reward -117.0 EPSILON 0.010421225282987556
# Episode 231 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.01031701303015768
# Episode 232 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.010213842899856104
# Episode 233 Episodic Reward -191.0 Maximum Reward -117.0 EPSILON 0.010111704470857543
# Episode 234 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.010010587426148968
# Episode 235 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.009910481551887479
# Episode 236 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.009811376736368603
# Episode 237 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.009713262969004917
# Episode 238 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.009616130339314867
# Episode 239 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.009519969035921718
# Episode 240 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.009424769345562502
# Episode 241 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.009330521652106877
# Episode 242 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.009237216435585808
# Episode 243 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.009144844271229951
# Episode 244 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.00905339582851765
# Episode 245 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.008962861870232474
# Episode 246 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.008873233251530149
# Episode 247 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.008784500919014848
# Episode 248 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.0086966559098247
# Episode 249 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.008609689350726452
# Episode 250 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.008523592457219188
# Episode 251 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.008438356532646995
# Episode 252 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.008353972967320525
# Episode 253 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.00827043323764732
# Episode 254 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.008187728905270846
# Episode 255 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.008105851616218138
# Episode 256 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.008024793100055957
# Episode 257 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.007944545169055397
# Episode 258 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.007865099717364843
# Episode 259 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.0077864487201911945
# Episode 260 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.0077085842329892825
# Episode 261 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.00763149839065939
# Episode 262 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.0075551834067527955
# Episode 263 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.007479631572685268
# Episode 264 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.007404835256958415
# Episode 265 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.007330786904388831
# Episode 266 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.007257479035344943
# Episode 267 Episodic Reward -155.0 Maximum Reward -117.0 EPSILON 0.007184904244991494
# Episode 268 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.007113055202541579
# Episode 269 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.007041924650516163
# Episode 270 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.006971505404011002
# Episode 271 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.006901790349970892
# Episode 272 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.006832772446471183
# Episode 273 Episodic Reward -165.0 Maximum Reward -117.0 EPSILON 0.006764444722006471
# Episode 274 Episodic Reward -162.0 Maximum Reward -117.0 EPSILON 0.006696800274786406
# Episode 275 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.006629832272038541
# Episode 276 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.006563533949318156
# Episode 277 Episodic Reward -164.0 Maximum Reward -117.0 EPSILON 0.006497898609824975
# Episode 278 Episodic Reward -185.0 Maximum Reward -117.0 EPSILON 0.006432919623726724
# Episode 279 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.006368590427489457
# Episode 280 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.006304904523214563
# Episode 281 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.006241855477982417
# Episode 282 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.0061794369232025925
# Episode 283 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.006117642553970567
# Episode 284 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.006056466128430861
# Episode 285 Episodic Reward -166.0 Maximum Reward -117.0 EPSILON 0.005995901467146553
# Episode 286 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.005935942452475087
# Episode 287 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.005876583027950337
# Episode 288 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.005817817197670833
# Episode 289 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.005759639025694124
# Episode 290 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.005702042635437183
# Episode 291 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.005645022209082811
# Episode 292 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.0055885719869919834
# Episode 293 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.005532686267122063
# Episode 294 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.005477359404450843
# Episode 295 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.005422585810406335
# Episode 296 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.005368359952302271
# Episode 297 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.0053146763527792485
# Episode 298 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.005261529589251456
# Episode 299 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.0052089142933589416
# Episode 300 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.005156825150425352
# Episode 301 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.005105256898921099
# Episode 302 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.005054204329931888
# Episode 303 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.005003662286632569
# Episode 304 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.004953625663766243
# Episode 305 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.00490408940712858
# Episode 306 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.004855048513057294
# Episode 307 Episodic Reward -136.0 Maximum Reward -117.0 EPSILON 0.004806498027926721
# Episode 308 Episodic Reward -156.0 Maximum Reward -117.0 EPSILON 0.004758433047647454
# Episode 309 Episodic Reward -143.0 Maximum Reward -117.0 EPSILON 0.004710848717170979
# Episode 310 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.004663740229999269
# Episode 311 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.004617102827699277
# Episode 312 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.004570931799422284
# Episode 313 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.004525222481428061
# Episode 314 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.00447997025661378
# Episode 315 Episodic Reward -136.0 Maximum Reward -117.0 EPSILON 0.004435170554047642
# Episode 316 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.004390818848507166
# Episode 317 Episodic Reward -133.0 Maximum Reward -117.0 EPSILON 0.004346910660022094
# Episode 318 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.004303441553421873
# Episode 319 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.004260407137887654
# Episode 320 Episodic Reward -121.0 Maximum Reward -117.0 EPSILON 0.004217803066508778
# Episode 321 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.00417562503584369
# Episode 322 Episodic Reward -134.0 Maximum Reward -117.0 EPSILON 0.004133868785485253
# Episode 323 Episodic Reward -200.0 Maximum Reward -117.0 EPSILON 0.004092530097630401
# Episode 324 Episodic Reward -106.0 Maximum Reward -106.0 EPSILON 0.004051604796654096
# Episode 325 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.004011088748687555
# Episode 326 Episodic Reward -164.0 Maximum Reward -106.0 EPSILON 0.003970977861200679
# Episode 327 Episodic Reward -137.0 Maximum Reward -106.0 EPSILON 0.003931268082588672
# Episode 328 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.0038919554017627853
# Episode 329 Episodic Reward -137.0 Maximum Reward -106.0 EPSILON 0.0038530358477451574
# Episode 330 Episodic Reward -139.0 Maximum Reward -106.0 EPSILON 0.003814505489267706
# Episode 331 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.003776360434375029
# Episode 332 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.0037385968300312784
# Episode 333 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.0037012108617309656
# Episode 334 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.003664198753113656
# Episode 335 Episodic Reward -138.0 Maximum Reward -106.0 EPSILON 0.0036275567655825194
# Episode 336 Episodic Reward -158.0 Maximum Reward -106.0 EPSILON 0.003591281197926694
# Episode 337 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.003555368385947427
# Episode 338 Episodic Reward -114.0 Maximum Reward -106.0 EPSILON 0.0035198147020879525
# Episode 339 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.003484616555067073
# Episode 340 Episodic Reward -190.0 Maximum Reward -106.0 EPSILON 0.003449770389516402
# Episode 341 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.003415272685621238
# Episode 342 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.003381119958765026
# Episode 343 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.0033473087591773757
# Episode 344 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.003313835671585602
# Episode 345 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.003280697314869746
# Episode 346 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.003247890341721049
# Episode 347 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.003215411438303838
# Episode 348 Episodic Reward -137.0 Maximum Reward -106.0 EPSILON 0.0031832573239207996
# Episode 349 Episodic Reward -145.0 Maximum Reward -106.0 EPSILON 0.0031514247506815914
# Episode 350 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.0031199105031747753
# Episode 351 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.0030887113981430277
# Episode 352 Episodic Reward -163.0 Maximum Reward -106.0 EPSILON 0.0030578242841615972
# Episode 353 Episodic Reward -136.0 Maximum Reward -106.0 EPSILON 0.0030272460413199812
# Episode 354 Episodic Reward -137.0 Maximum Reward -106.0 EPSILON 0.0029969735809067814
# Episode 355 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.0029670038450977138
# Episode 356 Episodic Reward -170.0 Maximum Reward -106.0 EPSILON 0.0029373338066467367
# Episode 357 Episodic Reward -178.0 Maximum Reward -106.0 EPSILON 0.0029079604685802694
# Episode 358 Episodic Reward -106.0 Maximum Reward -106.0 EPSILON 0.0028788808638944667
# Episode 359 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.002850092055255522
# Episode 360 Episodic Reward -114.0 Maximum Reward -106.0 EPSILON 0.002821591134702967
# Episode 361 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.0027933752233559373
# Episode 362 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.002765441471122378
# Episode 363 Episodic Reward -141.0 Maximum Reward -106.0 EPSILON 0.002737787056411154
# Episode 364 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.0027104091858470426
# Episode 365 Episodic Reward -137.0 Maximum Reward -106.0 EPSILON 0.002683305093988572
# Episode 366 Episodic Reward -194.0 Maximum Reward -106.0 EPSILON 0.0026564720430486866
# Episode 367 Episodic Reward -114.0 Maximum Reward -106.0 EPSILON 0.0026299073226182
# Episode 368 Episodic Reward -189.0 Maximum Reward -106.0 EPSILON 0.0026036082493920178
# Episode 369 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.0025775721668980975
# Episode 370 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.0025517964452291164
# Episode 371 Episodic Reward -177.0 Maximum Reward -106.0 EPSILON 0.0025262784807768253
# Episode 372 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.0025010156959690572
# Episode 373 Episodic Reward -158.0 Maximum Reward -106.0 EPSILON 0.0024760055390093665
# Episode 374 Episodic Reward -192.0 Maximum Reward -106.0 EPSILON 0.002451245483619273
# Episode 375 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.0024267330287830804
# Episode 376 Episodic Reward -132.0 Maximum Reward -106.0 EPSILON 0.00240246569849525
# Episode 377 Episodic Reward -136.0 Maximum Reward -106.0 EPSILON 0.002378441041510297
# Episode 378 Episodic Reward -121.0 Maximum Reward -106.0 EPSILON 0.002354656631095194
# Episode 379 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.002331110064784242
# Episode 380 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.0023077989641364
# Episode 381 Episodic Reward -133.0 Maximum Reward -106.0 EPSILON 0.002284720974495036
# Episode 382 Episodic Reward -173.0 Maximum Reward -106.0 EPSILON 0.0022618737647500855
# Episode 383 Episodic Reward -163.0 Maximum Reward -106.0 EPSILON 0.002239255027102585
# Episode 384 Episodic Reward -182.0 Maximum Reward -106.0 EPSILON 0.002216862476831559
# Episode 385 Episodic Reward -107.0 Maximum Reward -106.0 EPSILON 0.0021946938520632435
# Episode 386 Episodic Reward -199.0 Maximum Reward -106.0 EPSILON 0.002172746913542611
# Episode 387 Episodic Reward -119.0 Maximum Reward -106.0 EPSILON 0.0021510194444071848
# Episode 388 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.002129509249963113
# Episode 389 Episodic Reward -166.0 Maximum Reward -106.0 EPSILON 0.002108214157463482
# Episode 390 Episodic Reward -111.0 Maximum Reward -106.0 EPSILON 0.0020871320158888473
# Episode 391 Episodic Reward -176.0 Maximum Reward -106.0 EPSILON 0.0020662606957299588
# Episode 392 Episodic Reward -169.0 Maximum Reward -106.0 EPSILON 0.002045598088772659
# Episode 393 Episodic Reward -162.0 Maximum Reward -106.0 EPSILON 0.0020251421078849325
# Episode 394 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.002004890686806083
# Episode 395 Episodic Reward -169.0 Maximum Reward -106.0 EPSILON 0.001984841779938022
# Episode 396 Episodic Reward -107.0 Maximum Reward -106.0 EPSILON 0.0019649933621386415
# Episode 397 Episodic Reward -112.0 Maximum Reward -106.0 EPSILON 0.001945343428517255
# Episode 398 Episodic Reward -111.0 Maximum Reward -106.0 EPSILON 0.0019258899942320826
# Episode 399 Episodic Reward -120.0 Maximum Reward -106.0 EPSILON 0.0019066310942897618
# Episode 400 Episodic Reward -174.0 Maximum Reward -106.0 EPSILON 0.0018875647833468641
# Episode 401 Episodic Reward -173.0 Maximum Reward -106.0 EPSILON 0.0018686891355133954
# Episode 402 Episodic Reward -134.0 Maximum Reward -106.0 EPSILON 0.0018500022441582614
# Episode 403 Episodic Reward -169.0 Maximum Reward -106.0 EPSILON 0.0018315022217166787
# Episode 404 Episodic Reward -163.0 Maximum Reward -106.0 EPSILON 0.001813187199499512
# Episode 405 Episodic Reward -147.0 Maximum Reward -106.0 EPSILON 0.0017950553275045168
# Episode 406 Episodic Reward -137.0 Maximum Reward -106.0 EPSILON 0.0017771047742294716
# Episode 407 Episodic Reward -106.0 Maximum Reward -106.0 EPSILON 0.001759333726487177
# Episode 408 Episodic Reward -197.0 Maximum Reward -106.0 EPSILON 0.001741740389222305
# Episode 409 Episodic Reward -177.0 Maximum Reward -106.0 EPSILON 0.001724322985330082
# Episode 410 Episodic Reward -199.0 Maximum Reward -106.0 EPSILON 0.0017070797554767812
# Episode 411 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.0016900089579220134
# Episode 412 Episodic Reward -125.0 Maximum Reward -106.0 EPSILON 0.0016731088683427933
# Episode 413 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.0016563777796593654
# Episode 414 Episodic Reward -128.0 Maximum Reward -106.0 EPSILON 0.0016398140018627717
# Episode 415 Episodic Reward -155.0 Maximum Reward -106.0 EPSILON 0.001623415861844144
# Episode 416 Episodic Reward -130.0 Maximum Reward -106.0 EPSILON 0.0016071817032257026
# Episode 417 Episodic Reward -138.0 Maximum Reward -106.0 EPSILON 0.0015911098861934455
# Episode 418 Episodic Reward -146.0 Maximum Reward -106.0 EPSILON 0.001575198787331511
# Episode 419 Episodic Reward -189.0 Maximum Reward -106.0 EPSILON 0.001559446799458196
# Episode 420 Episodic Reward -114.0 Maximum Reward -106.0 EPSILON 0.001543852331463614
# Episode 421 Episodic Reward -121.0 Maximum Reward -106.0 EPSILON 0.0015284138081489778
# Episode 422 Episodic Reward -200.0 Maximum Reward -106.0 EPSILON 0.001513129670067488
# Episode 423 Episodic Reward -145.0 Maximum Reward -106.0 EPSILON 0.0014979983733668131
# Episode 424 Episodic Reward -104.0 Maximum Reward -104.0 EPSILON 0.001483018389633145
# Episode 425 Episodic Reward -108.0 Maximum Reward -104.0 EPSILON 0.0014681882057368135
# Episode 426 Episodic Reward -176.0 Maximum Reward -104.0 EPSILON 0.0014535063236794453
# Episode 427 Episodic Reward -113.0 Maximum Reward -104.0 EPSILON 0.0014389712604426508
# Episode 428 Episodic Reward -152.0 Maximum Reward -104.0 EPSILON 0.0014245815478382243
# Episode 429 Episodic Reward -116.0 Maximum Reward -104.0 EPSILON 0.001410335732359842
# Episode 430 Episodic Reward -200.0 Maximum Reward -104.0 EPSILON 0.0013962323750362437
# Episode 431 Episodic Reward -147.0 Maximum Reward -104.0 EPSILON 0.0013822700512858813
# Episode 432 Episodic Reward -200.0 Maximum Reward -104.0 EPSILON 0.0013684473507730225
# Episode 433 Episodic Reward -146.0 Maximum Reward -104.0 EPSILON 0.0013547628772652921
# Episode 434 Episodic Reward -142.0 Maximum Reward -104.0 EPSILON 0.0013412152484926392
# Episode 435 Episodic Reward -135.0 Maximum Reward -104.0 EPSILON 0.0013278030960077129
# Episode 436 Episodic Reward -152.0 Maximum Reward -104.0 EPSILON 0.0013145250650476357
# Episode 437 Episodic Reward -160.0 Maximum Reward -104.0 EPSILON 0.0013013798143971594
# Episode 438 Episodic Reward -178.0 Maximum Reward -104.0 EPSILON 0.0012883660162531878
# Episode 439 Episodic Reward -170.0 Maximum Reward -104.0 EPSILON 0.001275482356090656
# Episode 440 Episodic Reward -98.0 Maximum Reward -98.0 EPSILON 0.0012627275325297494
# Episode 441 Episodic Reward -189.0 Maximum Reward -98.0 EPSILON 0.0012501002572044518
# Episode 442 Episodic Reward -179.0 Maximum Reward -98.0 EPSILON 0.0012375992546324072
# Episode 443 Episodic Reward -114.0 Maximum Reward -98.0 EPSILON 0.0012252232620860832
# Episode 444 Episodic Reward -108.0 Maximum Reward -98.0 EPSILON 0.0012129710294652223
# Episode 445 Episodic Reward -187.0 Maximum Reward -98.0 EPSILON 0.0012008413191705702
# Episode 446 Episodic Reward -114.0 Maximum Reward -98.0 EPSILON 0.0011888329059788645
# Episode 447 Episodic Reward -136.0 Maximum Reward -98.0 EPSILON 0.001176944576919076
# Episode 448 Episodic Reward -147.0 Maximum Reward -98.0 EPSILON 0.0011651751311498853
# Episode 449 Episodic Reward -200.0 Maximum Reward -98.0 EPSILON 0.0011535233798383865
# Episode 450 Episodic Reward -200.0 Maximum Reward -98.0 EPSILON 0.0011419881460400026
# Episode 451 Episodic Reward -128.0 Maximum Reward -98.0 EPSILON 0.0011305682645796026
# Episode 452 Episodic Reward -157.0 Maximum Reward -98.0 EPSILON 0.0011192625819338065
# Episode 453 Episodic Reward -134.0 Maximum Reward -98.0 EPSILON 0.0011080699561144684
# Episode 454 Episodic Reward -194.0 Maximum Reward -98.0 EPSILON 0.0010969892565533238
# Episode 455 Episodic Reward -108.0 Maximum Reward -98.0 EPSILON 0.0010860193639877906
# Episode 456 Episodic Reward -159.0 Maximum Reward -98.0 EPSILON 0.0010751591703479127
# Episode 457 Episodic Reward -93.0 Maximum Reward -93.0 EPSILON 0.0010644075786444334
# Episode 458 Episodic Reward -155.0 Maximum Reward -93.0 EPSILON 0.001053763502857989
# Episode 459 Episodic Reward -107.0 Maximum Reward -93.0 EPSILON 0.001043225867829409
# Episode 460 Episodic Reward -123.0 Maximum Reward -93.0 EPSILON 0.001032793609151115
# Episode 461 Episodic Reward -156.0 Maximum Reward -93.0 EPSILON 0.0010224656730596037
# Episode 462 Episodic Reward -116.0 Maximum Reward -93.0 EPSILON 0.0010122410163290077
# Episode 463 Episodic Reward -112.0 Maximum Reward -93.0 EPSILON 0.0010021186061657176
# Episode 464 Episodic Reward -113.0 Maximum Reward -93.0 EPSILON 0.0009920974201040604
# Episode 465 Episodic Reward -191.0 Maximum Reward -93.0 EPSILON 0.0009920974201040604
# Episode 466 Episodic Reward -142.0 Maximum Reward -93.0 EPSILON 0.0009920974201040604
# Episode 467 Episodic Reward -142.0 Maximum Reward -93.0 EPSILON 0.0009920974201040604
# Episode 468 Episodic Reward -137.0 Maximum Reward -93.0 EPSILON 0.0009920974201040604
# Episode 469 Episodic Reward -200.0 Maximum Reward -93.0 EPSILON 0.0009920974201040604
# Episode 470 Episodic Reward -200.0 Maximum Reward -93.0 EPSILON 0.0009920974201040604
# Episode 471 Episodic Reward -146.0 Maximum Reward -93.0 EPSILON 0.0009920974201040604
# Episode 472 Episodic Reward -145.0 Maximum Reward -93.0 EPSILON 0.0009920974201040604
# Episode 473 Episodic Reward -200.0 Maximum Reward -93.0 EPSILON 0.0009920974201040604
# Episode 474 Episodic Reward -200.0 Maximum Reward -93.0 EPSILON 0.0009920974201040604
# Episode 475 Episodic Reward -165.0 Maximum Reward -93.0 EPSILON 0.0009920974201040604
# Episode 476 Episodic Reward -135.0 Maximum Reward -93.0 EPSILON 0.0009920974201040604
# Episode 477 Episodic Reward -183.0 Maximum Reward -93.0 EPSILON 0.0009920974201040604
# Episode 478 Episodic Reward -144.0 Maximum Reward -93.0 EPSILON 0.0009920974201040604
# Episode 479 Episodic Reward -112.0 Maximum Reward -93.0 EPSILON 0.0009920974201040604
# Episode 480 Episodic Reward -200.0 Maximum Reward -93.0 EPSILON 0.0009920974201040604
# Episode 481 Episodic Reward -137.0 Maximum Reward -93.0 EPSILON 0.0009920974201040604
# Episode 482 Episodic Reward -195.0 Maximum Reward -93.0 EPSILON 0.0009920974201040604
# Episode 483 Episodic Reward -200.0 Maximum Reward -93.0 EPSILON 0.0009920974201040604
# Episode 484 Episodic Reward -118.0 Maximum Reward -93.0 EPSILON 0.0009920974201040604
# Episode 485 Episodic Reward -189.0 Maximum Reward -93.0 EPSILON 0.0009920974201040604
# Episode 486 Episodic Reward -196.0 Maximum Reward -93.0 EPSILON 0.0009920974201040604
# Episode 487 Episodic Reward -108.0 Maximum Reward -93.0 EPSILON 0.0009920974201040604
# Episode 488 Episodic Reward -135.0 Maximum Reward -93.0 EPSILON 0.0009920974201040604
# Episode 489 Episodic Reward -154.0 Maximum Reward -93.0 EPSILON 0.0009920974201040604
# Episode 490 Episodic Reward -109.0 Maximum Reward -93.0 EPSILON 0.0009920974201040604
# Episode 491 Episodic Reward -89.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 492 Episodic Reward -200.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 493 Episodic Reward -197.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 494 Episodic Reward -130.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 495 Episodic Reward -137.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 496 Episodic Reward -111.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 497 Episodic Reward -144.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 498 Episodic Reward -113.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 499 Episodic Reward -137.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 500 Episodic Reward -90.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 501 Episodic Reward -108.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 502 Episodic Reward -180.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 503 Episodic Reward -136.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 504 Episodic Reward -123.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 505 Episodic Reward -108.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 506 Episodic Reward -200.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 507 Episodic Reward -149.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 508 Episodic Reward -172.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 509 Episodic Reward -107.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 510 Episodic Reward -169.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 511 Episodic Reward -200.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 512 Episodic Reward -194.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 513 Episodic Reward -151.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 514 Episodic Reward -139.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 515 Episodic Reward -145.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 516 Episodic Reward -200.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 517 Episodic Reward -120.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 518 Episodic Reward -112.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 519 Episodic Reward -146.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 520 Episodic Reward -131.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 521 Episodic Reward -107.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 522 Episodic Reward -175.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 523 Episodic Reward -147.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 524 Episodic Reward -138.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 525 Episodic Reward -128.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 526 Episodic Reward -180.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 527 Episodic Reward -117.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 528 Episodic Reward -108.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 529 Episodic Reward -110.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 530 Episodic Reward -117.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 531 Episodic Reward -118.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 532 Episodic Reward -109.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 533 Episodic Reward -182.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 534 Episodic Reward -112.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 535 Episodic Reward -192.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 536 Episodic Reward -109.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 537 Episodic Reward -151.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 538 Episodic Reward -120.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 539 Episodic Reward -152.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 540 Episodic Reward -114.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 541 Episodic Reward -115.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 542 Episodic Reward -178.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 543 Episodic Reward -116.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 544 Episodic Reward -117.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 545 Episodic Reward -200.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 546 Episodic Reward -200.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 547 Episodic Reward -139.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 548 Episodic Reward -113.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 549 Episodic Reward -111.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 550 Episodic Reward -199.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 551 Episodic Reward -197.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 552 Episodic Reward -123.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 553 Episodic Reward -175.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 554 Episodic Reward -179.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 555 Episodic Reward -182.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 556 Episodic Reward -138.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 557 Episodic Reward -120.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 558 Episodic Reward -140.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 559 Episodic Reward -200.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 560 Episodic Reward -108.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 561 Episodic Reward -193.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 562 Episodic Reward -107.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 563 Episodic Reward -195.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 564 Episodic Reward -111.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 565 Episodic Reward -113.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 566 Episodic Reward -108.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 567 Episodic Reward -154.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 568 Episodic Reward -118.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 569 Episodic Reward -94.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 570 Episodic Reward -141.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 571 Episodic Reward -159.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 572 Episodic Reward -199.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 573 Episodic Reward -200.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 574 Episodic Reward -123.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 575 Episodic Reward -141.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 576 Episodic Reward -185.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 577 Episodic Reward -95.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 578 Episodic Reward -114.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 579 Episodic Reward -127.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 580 Episodic Reward -120.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 581 Episodic Reward -110.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 582 Episodic Reward -106.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 583 Episodic Reward -128.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 584 Episodic Reward -200.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 585 Episodic Reward -109.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 586 Episodic Reward -163.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 587 Episodic Reward -118.0 Maximum Reward -89.0 EPSILON 0.0009920974201040604
# Episode 588 Episodic Reward -84.0 Maximum Reward -84.0 EPSILON 0.0009920974201040604
# Episode 589 Episodic Reward -117.0 Maximum Reward -84.0 EPSILON 0.0009920974201040604
# Episode 590 Episodic Reward -111.0 Maximum Reward -84.0 EPSILON 0.0009920974201040604
# Episode 591 Episodic Reward -111.0 Maximum Reward -84.0 EPSILON 0.0009920974201040604
# Episode 592 Episodic Reward -200.0 Maximum Reward -84.0 EPSILON 0.0009920974201040604
# Episode 593 Episodic Reward -109.0 Maximum Reward -84.0 EPSILON 0.0009920974201040604
# Episode 594 Episodic Reward -155.0 Maximum Reward -84.0 EPSILON 0.0009920974201040604
# Episode 595 Episodic Reward -166.0 Maximum Reward -84.0 EPSILON 0.0009920974201040604
# Episode 596 Episodic Reward -171.0 Maximum Reward -84.0 EPSILON 0.0009920974201040604
# Episode 597 Episodic Reward -114.0 Maximum Reward -84.0 EPSILON 0.0009920974201040604
# Episode 598 Episodic Reward -116.0 Maximum Reward -84.0 EPSILON 0.0009920974201040604
# Episode 599 Episodic Reward -171.0 Maximum Reward -84.0 EPSILON 0.0009920974201040604

# %% [markdown]
# ## Rewards [Section 6.4]

# %%
# plot Rewards vs Episodes
plt.plot(rewards)
plt.title('Rewards per Episode')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.grid(True)
plt.show()

# plot Mean of Rewards with window size 10
data = rewards
data_series = pd.Series(data)
window_size = 10
moving_average = data_series.rolling(window=window_size).mean()

plt.figure(figsize=(12, 6))
plt.plot(data, label='Original Data')
plt.plot(moving_average, label='Mean of Rewards', linewidth=2)
plt.title("Mean of Rewards Over Time")
plt.xlabel("Episode")
plt.ylabel("Rewards")
plt.legend()
plt.show()

# plot Movig average of rewards over 600 episodes with window size 50
mean_rewards = np.zeros(600)
for t in range(600):
    mean_rewards[t] = np.mean(rewards[max(0,t-50):(t+1)])
plt.plot(mean_rewards)
plt.title("Moving average of Rewards Over last 50 Episodes")
plt.xlabel("Episodes")
plt.ylabel("Rewards")
plt.show()


# plot Epsilon Decay Over Episodes
epsilons = [EPSILON * (EPSILON_DECAY ** episode) for episode in range(EPISODES)]

# plot Episode Lengths Over Time
plt.figure(figsize=(10, 6))
plt.plot(epsilons)
plt.title("Epsilon Decay Over Episodes")
plt.xlabel("Episode")
plt.ylabel("Epsilon")
plt.show()

# plot Episode Lengths Over Time
plt.figure(figsize=(10, 6))
plt.plot(episode_lengths)
plt.title("Episode Lengths(steps) Over Time")
plt.xlabel("Episode")
plt.ylabel("Length")
plt.show()

# %% [markdown]
# ---------------------------------------------------------------------------------------------

# %% [markdown]
# # 4. Double DQN with Double Q Learning Approach(Coin Flip Approach) [Section 7]

# %% [markdown]
# <span style ='color:red'> There are two problems with vanilla DQN and Fixed DQN -> Maximization bias which is the problem of overestimating the action-values of a state, that is, the agent tends to believe certain actions are valuable even though it is not so. And this happens because we are referring to the same table values to select an action and evaluate that action. -> Catastrophic forgetting   </span>
#
# <span style ='color:red'> The solution to this problem of overestimation is using two different Q tables (we adopt this to two different neural network models).
# The best action can be taken based on the first Q table values and tha target value can be taken on the second Q table values ie. Action Selection from one network Q1 and evaluation from the other network Q2</span>
#
# <span style ='color:red'> Training the above two networks (Q1 + Q2) is based on "flip coin" approach (that is decisions are made randomly) and here, the main Q network model (Q1) is used to select the action(a) and the target network model (Q2) is used to evaluate that action(a) for the first half of randomness say when randomness < 0.5 and vice versa when randomness is > 0.5.  </span>
#
# <span style ='color:red'>Following this method helps the agent to not overestimate for both the halves of the action values in the Q tables (randomness < 0.5 and randomness > 0.5). Because we update both the networks when trying the coin flip approach, the logic of updating the target network with the weights of the train network does not make sense, hence we call the fit() method on the train network and thereby remove the updation of target network weights every 20 episodes. While this might impact stability of training we are trying to minimize the maximization bian using the coin flip approach</span>

# %% [markdown]
# ## Creating the model and the target model and defining the loss function and the optimizer for both the models

# %%
# Creating simple sequential neural network model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(400, activation='relu', input_shape=observation_dim),
    tf.keras.layers.Dense(300, activation='relu'),
    tf.keras.layers.Dense(action_dim, activation='linear')
])

'''Compiling the neural network using Mean Square Error as loss function and
Adam as the optimizer which will learn at a rate of 0.005'''
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(learning_rate=0.005))

# Creating target network model which is the same as Deep Q network by cloning it
target_model1 = tf.keras.models.clone_model(model)
target_model1.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(learning_rate=0.005))
# Out:
# /Users/Sajin/MultiPDFchatMistral-7B/myenv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ## Defining training steps [Section 7.2]

# %%
# Replay memory (experience replay) to store experiances of the model with the environment
replay_buffer = deque(maxlen=REPLAY_MEMORY_SIZE)
rewards = []



def training_step(MINIBATCH_SIZE):
    # Samples batches of size MiniBatch_size(32) from  the replay buffer
    minibatch = random.sample(replay_buffer, MINIBATCH_SIZE)
    # Array containing current state values from each sample in the minibatch as the replay buffer looks like (state, action, reward, next_state, done)
    X_cur_states = np.array([sample[0] for sample in minibatch])
    # Array containing next state values from each sample in the minibatch as the replay buffer looks like (state, action, reward, next_state, done)
    X_next_states = np.array([sample[3] for sample in minibatch])
    # Predicting the action using main neural network
    '''The inputs for the Neural Network selecting the action using main network.
    This uses the main neural network model to predict the current Q-values for all actions given the current states'''
    cur_action_values = model.predict(X_cur_states, verbose=0)

    '''The inputs for the Neural Network selecting the action using target network.
    This uses the target neural network model to predict the current Q-values for all actions given the current states'''
    cur_action_values_target = target_model1.predict(X_cur_states, verbose=0)
    ''' This step predicts the Q-values for the next states using the same main network and
    helps to decide the next action to take'''
    # Q1(a)
    next_action_values_main = model.predict(X_next_states, verbose=0)
    # Evaluating the action using target network
    ''' This uses a separate target network to predict the Q-values for the next states.
    This target network is an older version of the main network and is used to stabilize the training'''
    # Q2(a)
    next_action_values_target = target_model1.predict(X_next_states, verbose=0)
    # This loop iterates over each sample from sample experience
    for index, (cur_state, action, reward, next_state, done) in enumerate(minibatch):
        # If the episode is not completed,

        if not done:
            ''' Using "coin flip" approach to randomly select the networks to be used
            for predicting an action and evaluate the selected action during training'''
            if np.random.rand() < 0.5:
                # Return action with highest Q value in next state as per the main neural network
                # Q2(A*) = Q2(argmax(Q1(a)))
                best_action_next = np.argmax(next_action_values_main[index])
                ''' The action selection (the 'argmax' in the max Q-value) for the next state is done using the main network, 
                    while the Q-value of this selected action is estimated using the target network. 
                    This helps to decouple the action selection from the target Q-value estimation, 
                    reducing the overestimation bias of standard DQN.'''
                # E|Q2(A*)| = q(A*)
                cur_action_values[index][action] = reward + DISCOUNT * next_action_values_target[index][best_action_next]
            else:
                # Q1(A*) = Q1(argmax(Q2(a)))
                best_action_next = np.argmax(next_action_values_target[index])
                ''' The action selection (the 'argmax' in the max Q-value) for the next state is done using the target network, 
                    while the Q-value of this selected action is estimated using the main network. 
                    This helps to decouple the action selection from the target Q-value estimation, 
                    reducing the overestimation bias of standard DQN.'''
                # E|Q1(A*)| = q(A*)
                cur_action_values_target[index][action] = reward + DISCOUNT * next_action_values_main[index][best_action_next]
        else:
            cur_action_values[index][action] = reward
    # updates model weights using Q values to minimize the error between target value and predicted value.
    model.fit(X_cur_states, cur_action_values, verbose=0)
    target_model1.fit(X_cur_states, cur_action_values_target, verbose=0)

# %% [markdown]
# ## Running the episodes

# %%
episode_lengths = []

# Looping through episodes
for episode in range(EPISODES):
    # resetting the environment for the state to be reset
    state = env.reset()
    # initializing variables used
    done = False
    episode_reward = 0
    episode_length = 0
    # creating a list to capture and append the learning through animation
    frames = []

    # Running through different sets of steps
    while not done:
        # incrementing episode length(number of steps)
        episode_length += 1
        # calling the play_one_step function to execute the steps
        next_state, reward, max_reward, done, info  = play_one_step(env,state, EPSILON, episode_length)
        # update the current state with the next state for the episode to continue
        state = next_state

        # Checking if the replay buffer size is less than the minimum required replay buffer size for training to start
        if(len(replay_buffer) < MINIMUM_REPLAY_MEMORY):
            continue
        # when the minimum replay buffer size is populated
        training_step(MINIBATCH_SIZE)

        # Recording and collecting the learning through frames for every 20 episodes
        if episode % record_frequency ==0:
            frames.append(env.render(mode='rgb_array'))

    # Creating learning animation
    if episode % record_frequency ==0:
            imageio.mimsave(f'episode_{episode}.mp4', frames, fps=30)

    # recording the values for visualizing the results
    max_reward = max(reward, max_reward)
    print('Episode', episode, 'Episodic Reward', reward, 'Maximum Reward', max_reward, 'EPSILON', EPSILON)
    rewards.append(reward)

    # Epsilon decay for the next episode
    if(EPSILON > MINIMUM_EPSILON and len(replay_buffer) > MINIMUM_REPLAY_MEMORY):
        EPSILON *= EPSILON_DECAY

    # recording the number of time steps taken by agent from the beginning of an episode to its termination

    episode_lengths.append(episode_length)
# Out:
# Episode 0 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.1
# Episode 1 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.1
# Episode 2 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.1
# Episode 3 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.1
# Episode 4 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.1
# Episode 5 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.1
# Episode 6 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.099
# Episode 7 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.09801
# Episode 8 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.0970299
# Episode 9 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.096059601
# Episode 10 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.09509900499
# Episode 11 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.0941480149401
# Episode 12 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.093206534790699
# Episode 13 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.09227446944279201
# Episode 14 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.09135172474836409
# Episode 15 Episodic Reward -200.0 Maximum Reward -200.0 EPSILON 0.09043820750088044
# Episode 16 Episodic Reward -148.0 Maximum Reward -148.0 EPSILON 0.08953382542587164
# Episode 17 Episodic Reward -200.0 Maximum Reward -148.0 EPSILON 0.08863848717161292
# Episode 18 Episodic Reward -200.0 Maximum Reward -148.0 EPSILON 0.08775210229989679
# Episode 19 Episodic Reward -200.0 Maximum Reward -148.0 EPSILON 0.08687458127689782
# Episode 20 Episodic Reward -200.0 Maximum Reward -148.0 EPSILON 0.08600583546412884
# Episode 21 Episodic Reward -200.0 Maximum Reward -148.0 EPSILON 0.08514577710948755
# Episode 22 Episodic Reward -200.0 Maximum Reward -148.0 EPSILON 0.08429431933839267
# Episode 23 Episodic Reward -200.0 Maximum Reward -148.0 EPSILON 0.08345137614500873
# Episode 24 Episodic Reward -200.0 Maximum Reward -148.0 EPSILON 0.08261686238355864
# Episode 25 Episodic Reward -199.0 Maximum Reward -148.0 EPSILON 0.08179069375972306
# Episode 26 Episodic Reward -200.0 Maximum Reward -148.0 EPSILON 0.08097278682212583
# Episode 27 Episodic Reward -200.0 Maximum Reward -148.0 EPSILON 0.08016305895390458
# Episode 28 Episodic Reward -200.0 Maximum Reward -148.0 EPSILON 0.07936142836436554
# Episode 29 Episodic Reward -200.0 Maximum Reward -148.0 EPSILON 0.07856781408072187
# Episode 30 Episodic Reward -200.0 Maximum Reward -148.0 EPSILON 0.07778213593991465
# Episode 31 Episodic Reward -200.0 Maximum Reward -148.0 EPSILON 0.0770043145805155
# Episode 32 Episodic Reward -200.0 Maximum Reward -148.0 EPSILON 0.07623427143471034
# Episode 33 Episodic Reward -200.0 Maximum Reward -148.0 EPSILON 0.07547192872036323
# Episode 34 Episodic Reward -200.0 Maximum Reward -148.0 EPSILON 0.0747172094331596
# Episode 35 Episodic Reward -200.0 Maximum Reward -148.0 EPSILON 0.073970037338828
# Episode 36 Episodic Reward -200.0 Maximum Reward -148.0 EPSILON 0.07323033696543972
# Episode 37 Episodic Reward -200.0 Maximum Reward -148.0 EPSILON 0.07249803359578533
# Episode 38 Episodic Reward -200.0 Maximum Reward -148.0 EPSILON 0.07177305325982747
# Episode 39 Episodic Reward -200.0 Maximum Reward -148.0 EPSILON 0.0710553227272292
# Episode 40 Episodic Reward -200.0 Maximum Reward -148.0 EPSILON 0.07034476949995691
# Episode 41 Episodic Reward -200.0 Maximum Reward -148.0 EPSILON 0.06964132180495734
# Episode 42 Episodic Reward -200.0 Maximum Reward -148.0 EPSILON 0.06894490858690777
# Episode 43 Episodic Reward -200.0 Maximum Reward -148.0 EPSILON 0.06825545950103869
# Episode 44 Episodic Reward -200.0 Maximum Reward -148.0 EPSILON 0.0675729049060283
# Episode 45 Episodic Reward -200.0 Maximum Reward -148.0 EPSILON 0.06689717585696801
# Episode 46 Episodic Reward -200.0 Maximum Reward -148.0 EPSILON 0.06622820409839833
# Episode 47 Episodic Reward -200.0 Maximum Reward -148.0 EPSILON 0.06556592205741435
# Episode 48 Episodic Reward -144.0 Maximum Reward -144.0 EPSILON 0.0649102628368402
# Episode 49 Episodic Reward -151.0 Maximum Reward -144.0 EPSILON 0.06426116020847181
# Episode 50 Episodic Reward -200.0 Maximum Reward -144.0 EPSILON 0.06361854860638709
# Episode 51 Episodic Reward -200.0 Maximum Reward -144.0 EPSILON 0.06298236312032322
# Episode 52 Episodic Reward -200.0 Maximum Reward -144.0 EPSILON 0.06235253948911999
# Episode 53 Episodic Reward -200.0 Maximum Reward -144.0 EPSILON 0.06172901409422879
# Episode 54 Episodic Reward -140.0 Maximum Reward -140.0 EPSILON 0.061111723953286505
# Episode 55 Episodic Reward -200.0 Maximum Reward -140.0 EPSILON 0.06050060671375364
# Episode 56 Episodic Reward -200.0 Maximum Reward -140.0 EPSILON 0.0598956006466161
# Episode 57 Episodic Reward -190.0 Maximum Reward -140.0 EPSILON 0.05929664464014994
# Episode 58 Episodic Reward -200.0 Maximum Reward -140.0 EPSILON 0.05870367819374844
# Episode 59 Episodic Reward -200.0 Maximum Reward -140.0 EPSILON 0.05811664141181096
# Episode 60 Episodic Reward -178.0 Maximum Reward -140.0 EPSILON 0.05753547499769285
# Episode 61 Episodic Reward -200.0 Maximum Reward -140.0 EPSILON 0.05696012024771592
# Episode 62 Episodic Reward -200.0 Maximum Reward -140.0 EPSILON 0.05639051904523876
# Episode 63 Episodic Reward -195.0 Maximum Reward -140.0 EPSILON 0.05582661385478637
# Episode 64 Episodic Reward -152.0 Maximum Reward -140.0 EPSILON 0.05526834771623851
# Episode 65 Episodic Reward -170.0 Maximum Reward -140.0 EPSILON 0.054715664239076124
# Episode 66 Episodic Reward -200.0 Maximum Reward -140.0 EPSILON 0.054168507596685365
# Episode 67 Episodic Reward -200.0 Maximum Reward -140.0 EPSILON 0.053626822520718515
# Episode 68 Episodic Reward -200.0 Maximum Reward -140.0 EPSILON 0.05309055429551133
# Episode 69 Episodic Reward -200.0 Maximum Reward -140.0 EPSILON 0.05255964875255621
# Episode 70 Episodic Reward -200.0 Maximum Reward -140.0 EPSILON 0.05203405226503065
# Episode 71 Episodic Reward -200.0 Maximum Reward -140.0 EPSILON 0.05151371174238034
# Episode 72 Episodic Reward -200.0 Maximum Reward -140.0 EPSILON 0.050998574624956536
# Episode 73 Episodic Reward -200.0 Maximum Reward -140.0 EPSILON 0.05048858887870697
# Episode 74 Episodic Reward -200.0 Maximum Reward -140.0 EPSILON 0.0499837029899199
# Episode 75 Episodic Reward -200.0 Maximum Reward -140.0 EPSILON 0.049483865960020704
# Episode 76 Episodic Reward -196.0 Maximum Reward -140.0 EPSILON 0.0489890273004205
# Episode 77 Episodic Reward -200.0 Maximum Reward -140.0 EPSILON 0.048499137027416296
# Episode 78 Episodic Reward -175.0 Maximum Reward -140.0 EPSILON 0.048014145657142134
# Episode 79 Episodic Reward -183.0 Maximum Reward -140.0 EPSILON 0.04753400420057071
# Episode 80 Episodic Reward -140.0 Maximum Reward -140.0 EPSILON 0.047058664158565
# Episode 81 Episodic Reward -149.0 Maximum Reward -140.0 EPSILON 0.046588077516979354
# Episode 82 Episodic Reward -200.0 Maximum Reward -140.0 EPSILON 0.04612219674180956
# Episode 83 Episodic Reward -198.0 Maximum Reward -140.0 EPSILON 0.04566097477439147
# Episode 84 Episodic Reward -167.0 Maximum Reward -140.0 EPSILON 0.045204365026647556
# Episode 85 Episodic Reward -192.0 Maximum Reward -140.0 EPSILON 0.04475232137638108
# Episode 86 Episodic Reward -200.0 Maximum Reward -140.0 EPSILON 0.044304798162617266
# Episode 87 Episodic Reward -180.0 Maximum Reward -140.0 EPSILON 0.043861750180991095
# Episode 88 Episodic Reward -164.0 Maximum Reward -140.0 EPSILON 0.04342313267918119
# Episode 89 Episodic Reward -144.0 Maximum Reward -140.0 EPSILON 0.04298890135238938
# Episode 90 Episodic Reward -163.0 Maximum Reward -140.0 EPSILON 0.042559012338865485
# Episode 91 Episodic Reward -200.0 Maximum Reward -140.0 EPSILON 0.04213342221547683
# Episode 92 Episodic Reward -161.0 Maximum Reward -140.0 EPSILON 0.04171208799332206
# Episode 93 Episodic Reward -150.0 Maximum Reward -140.0 EPSILON 0.041294967113388835
# Episode 94 Episodic Reward -159.0 Maximum Reward -140.0 EPSILON 0.04088201744225495
# Episode 95 Episodic Reward -200.0 Maximum Reward -140.0 EPSILON 0.0404731972678324
# Episode 96 Episodic Reward -200.0 Maximum Reward -140.0 EPSILON 0.04006846529515407
# Episode 97 Episodic Reward -167.0 Maximum Reward -140.0 EPSILON 0.039667780642202534
# Episode 98 Episodic Reward -200.0 Maximum Reward -140.0 EPSILON 0.03927110283578051
# Episode 99 Episodic Reward -190.0 Maximum Reward -140.0 EPSILON 0.0388783918074227
# Episode 100 Episodic Reward -135.0 Maximum Reward -135.0 EPSILON 0.03848960788934848
# Episode 101 Episodic Reward -194.0 Maximum Reward -135.0 EPSILON 0.038104711810454994
# Episode 102 Episodic Reward -200.0 Maximum Reward -135.0 EPSILON 0.037723664692350445
# Episode 103 Episodic Reward -162.0 Maximum Reward -135.0 EPSILON 0.03734642804542694
# Episode 104 Episodic Reward -85.0 Maximum Reward -85.0 EPSILON 0.03697296376497267
# Episode 105 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.03660323412732295
# Episode 106 Episodic Reward -168.0 Maximum Reward -85.0 EPSILON 0.03623720178604972
# Episode 107 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.035874829768189224
# Episode 108 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.03551608147050733
# Episode 109 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.03516092065580226
# Episode 110 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.034809311449244235
# Episode 111 Episodic Reward -155.0 Maximum Reward -85.0 EPSILON 0.03446121833475179
# Episode 112 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.03411660615140427
# Episode 113 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.03377544008989023
# Episode 114 Episodic Reward -143.0 Maximum Reward -85.0 EPSILON 0.03343768568899133
# Episode 115 Episodic Reward -145.0 Maximum Reward -85.0 EPSILON 0.03310330883210142
# Episode 116 Episodic Reward -189.0 Maximum Reward -85.0 EPSILON 0.03277227574378041
# Episode 117 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.032444552986342606
# Episode 118 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.03212010745647918
# Episode 119 Episodic Reward -140.0 Maximum Reward -85.0 EPSILON 0.03179890638191439
# Episode 120 Episodic Reward -193.0 Maximum Reward -85.0 EPSILON 0.03148091731809525
# Episode 121 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.031166108144914297
# Episode 122 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.030854447063465153
# Episode 123 Episodic Reward -103.0 Maximum Reward -85.0 EPSILON 0.030545902592830503
# Episode 124 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.030240443566902198
# Episode 125 Episodic Reward -152.0 Maximum Reward -85.0 EPSILON 0.029938039131233177
# Episode 126 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.029638658739920845
# Episode 127 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.029342272152521637
# Episode 128 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.02904884943099642
# Episode 129 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.028758360936686458
# Episode 130 Episodic Reward -96.0 Maximum Reward -85.0 EPSILON 0.028470777327319594
# Episode 131 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.028186069554046397
# Episode 132 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.027904208858505933
# Episode 133 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.027625166769920873
# Episode 134 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.027348915102221663
# Episode 135 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.027075425951199446
# Episode 136 Episodic Reward -121.0 Maximum Reward -85.0 EPSILON 0.026804671691687453
# Episode 137 Episodic Reward -136.0 Maximum Reward -85.0 EPSILON 0.02653662497477058
# Episode 138 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.026271258725022874
# Episode 139 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.026008546137772644
# Episode 140 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.025748460676394917
# Episode 141 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.025490976069630966
# Episode 142 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.025236066308934657
# Episode 143 Episodic Reward -140.0 Maximum Reward -85.0 EPSILON 0.02498370564584531
# Episode 144 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.024733868589386858
# Episode 145 Episodic Reward -125.0 Maximum Reward -85.0 EPSILON 0.02448652990349299
# Episode 146 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.02424166460445806
# Episode 147 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.02399924795841348
# Episode 148 Episodic Reward -195.0 Maximum Reward -85.0 EPSILON 0.023759255478829344
# Episode 149 Episodic Reward -169.0 Maximum Reward -85.0 EPSILON 0.02352166292404105
# Episode 150 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.02328644629480064
# Episode 151 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.023053581831852635
# Episode 152 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.022823046013534107
# Episode 153 Episodic Reward -175.0 Maximum Reward -85.0 EPSILON 0.022594815553398765
# Episode 154 Episodic Reward -136.0 Maximum Reward -85.0 EPSILON 0.022368867397864776
# Episode 155 Episodic Reward -116.0 Maximum Reward -85.0 EPSILON 0.02214517872388613
# Episode 156 Episodic Reward -162.0 Maximum Reward -85.0 EPSILON 0.021923726936647268
# Episode 157 Episodic Reward -166.0 Maximum Reward -85.0 EPSILON 0.021704489667280794
# Episode 158 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.021487444770607985
# Episode 159 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.021272570322901904
# Episode 160 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.021059844619672884
# Episode 161 Episodic Reward -126.0 Maximum Reward -85.0 EPSILON 0.020849246173476155
# Episode 162 Episodic Reward -146.0 Maximum Reward -85.0 EPSILON 0.020640753711741393
# Episode 163 Episodic Reward -117.0 Maximum Reward -85.0 EPSILON 0.020434346174623978
# Episode 164 Episodic Reward -129.0 Maximum Reward -85.0 EPSILON 0.020230002712877736
# Episode 165 Episodic Reward -160.0 Maximum Reward -85.0 EPSILON 0.02002770268574896
# Episode 166 Episodic Reward -122.0 Maximum Reward -85.0 EPSILON 0.01982742565889147
# Episode 167 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.019629151402302553
# Episode 168 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.019432859888279527
# Episode 169 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.019238531289396732
# Episode 170 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.019046145976502765
# Episode 171 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.018855684516737737
# Episode 172 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.01866712767157036
# Episode 173 Episodic Reward -134.0 Maximum Reward -85.0 EPSILON 0.018480456394854655
# Episode 174 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.018295651830906107
# Episode 175 Episodic Reward -149.0 Maximum Reward -85.0 EPSILON 0.018112695312597047
# Episode 176 Episodic Reward -164.0 Maximum Reward -85.0 EPSILON 0.017931568359471076
# Episode 177 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.017752252675876365
# Episode 178 Episodic Reward -120.0 Maximum Reward -85.0 EPSILON 0.0175747301491176
# Episode 179 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.017398982847626424
# Episode 180 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.01722499301915016
# Episode 181 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.01705274308895866
# Episode 182 Episodic Reward -106.0 Maximum Reward -85.0 EPSILON 0.01688221565806907
# Episode 183 Episodic Reward -179.0 Maximum Reward -85.0 EPSILON 0.01671339350148838
# Episode 184 Episodic Reward -181.0 Maximum Reward -85.0 EPSILON 0.016546259566473494
# Episode 185 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.01638079697080876
# Episode 186 Episodic Reward -160.0 Maximum Reward -85.0 EPSILON 0.016216989001100673
# Episode 187 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.016054819111089667
# Episode 188 Episodic Reward -198.0 Maximum Reward -85.0 EPSILON 0.01589427091997877
# Episode 189 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.01573532821077898
# Episode 190 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.015577974928671192
# Episode 191 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.01542219517938448
# Episode 192 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.015267973227590634
# Episode 193 Episodic Reward -166.0 Maximum Reward -85.0 EPSILON 0.015115293495314729
# Episode 194 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.01496414056036158
# Episode 195 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.014814499154757965
# Episode 196 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.014666354163210386
# Episode 197 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.014519690621578282
# Episode 198 Episodic Reward -193.0 Maximum Reward -85.0 EPSILON 0.014374493715362499
# Episode 199 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.014230748778208874
# Episode 200 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.014088441290426785
# Episode 201 Episodic Reward -184.0 Maximum Reward -85.0 EPSILON 0.013947556877522518
# Episode 202 Episodic Reward -178.0 Maximum Reward -85.0 EPSILON 0.013808081308747293
# Episode 203 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.01367000049565982
# Episode 204 Episodic Reward -135.0 Maximum Reward -85.0 EPSILON 0.013533300490703223
# Episode 205 Episodic Reward -180.0 Maximum Reward -85.0 EPSILON 0.01339796748579619
# Episode 206 Episodic Reward -177.0 Maximum Reward -85.0 EPSILON 0.013263987810938228
# Episode 207 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.013131347932828845
# Episode 208 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.013000034453500557
# Episode 209 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.01287003410896555
# Episode 210 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.012741333767875895
# Episode 211 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.012613920430197136
# Episode 212 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.012487781225895164
# Episode 213 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.012362903413636212
# Episode 214 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.01223927437949985
# Episode 215 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.012116881635704851
# Episode 216 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.011995712819347802
# Episode 217 Episodic Reward -192.0 Maximum Reward -85.0 EPSILON 0.011875755691154323
# Episode 218 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.01175699813424278
# Episode 219 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.011639428152900352
# Episode 220 Episodic Reward -154.0 Maximum Reward -85.0 EPSILON 0.011523033871371349
# Episode 221 Episodic Reward -172.0 Maximum Reward -85.0 EPSILON 0.011407803532657634
# Episode 222 Episodic Reward -117.0 Maximum Reward -85.0 EPSILON 0.011293725497331058
# Episode 223 Episodic Reward -153.0 Maximum Reward -85.0 EPSILON 0.011180788242357747
# Episode 224 Episodic Reward -166.0 Maximum Reward -85.0 EPSILON 0.01106898035993417
# Episode 225 Episodic Reward -118.0 Maximum Reward -85.0 EPSILON 0.010958290556334828
# Episode 226 Episodic Reward -123.0 Maximum Reward -85.0 EPSILON 0.01084870765077148
# Episode 227 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.010740220574263765
# Episode 228 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.010632818368521127
# Episode 229 Episodic Reward -127.0 Maximum Reward -85.0 EPSILON 0.010526490184835915
# Episode 230 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.010421225282987556
# Episode 231 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.01031701303015768
# Episode 232 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.010213842899856104
# Episode 233 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.010111704470857543
# Episode 234 Episodic Reward -126.0 Maximum Reward -85.0 EPSILON 0.010010587426148968
# Episode 235 Episodic Reward -142.0 Maximum Reward -85.0 EPSILON 0.009910481551887479
# Episode 236 Episodic Reward -139.0 Maximum Reward -85.0 EPSILON 0.009811376736368603
# Episode 237 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.009713262969004917
# Episode 238 Episodic Reward -169.0 Maximum Reward -85.0 EPSILON 0.009616130339314867
# Episode 239 Episodic Reward -85.0 Maximum Reward -85.0 EPSILON 0.009519969035921718
# Episode 240 Episodic Reward -163.0 Maximum Reward -85.0 EPSILON 0.009424769345562502
# Episode 241 Episodic Reward -161.0 Maximum Reward -85.0 EPSILON 0.009330521652106877
# Episode 242 Episodic Reward -148.0 Maximum Reward -85.0 EPSILON 0.009237216435585808
# Episode 243 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.009144844271229951
# Episode 244 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.00905339582851765
# Episode 245 Episodic Reward -170.0 Maximum Reward -85.0 EPSILON 0.008962861870232474
# Episode 246 Episodic Reward -123.0 Maximum Reward -85.0 EPSILON 0.008873233251530149
# Episode 247 Episodic Reward -143.0 Maximum Reward -85.0 EPSILON 0.008784500919014848
# Episode 248 Episodic Reward -145.0 Maximum Reward -85.0 EPSILON 0.0086966559098247
# Episode 249 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.008609689350726452
# Episode 250 Episodic Reward -178.0 Maximum Reward -85.0 EPSILON 0.008523592457219188
# Episode 251 Episodic Reward -185.0 Maximum Reward -85.0 EPSILON 0.008438356532646995
# Episode 252 Episodic Reward -184.0 Maximum Reward -85.0 EPSILON 0.008353972967320525
# Episode 253 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.00827043323764732
# Episode 254 Episodic Reward -188.0 Maximum Reward -85.0 EPSILON 0.008187728905270846
# Episode 255 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.008105851616218138
# Episode 256 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.008024793100055957
# Episode 257 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.007944545169055397
# Episode 258 Episodic Reward -172.0 Maximum Reward -85.0 EPSILON 0.007865099717364843
# Episode 259 Episodic Reward -179.0 Maximum Reward -85.0 EPSILON 0.0077864487201911945
# Episode 260 Episodic Reward -149.0 Maximum Reward -85.0 EPSILON 0.0077085842329892825
# Episode 261 Episodic Reward -149.0 Maximum Reward -85.0 EPSILON 0.00763149839065939
# Episode 262 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0075551834067527955
# Episode 263 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.007479631572685268
# Episode 264 Episodic Reward -122.0 Maximum Reward -85.0 EPSILON 0.007404835256958415
# Episode 265 Episodic Reward -168.0 Maximum Reward -85.0 EPSILON 0.007330786904388831
# Episode 266 Episodic Reward -107.0 Maximum Reward -85.0 EPSILON 0.007257479035344943
# Episode 267 Episodic Reward -167.0 Maximum Reward -85.0 EPSILON 0.007184904244991494
# Episode 268 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.007113055202541579
# Episode 269 Episodic Reward -171.0 Maximum Reward -85.0 EPSILON 0.007041924650516163
# Episode 270 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.006971505404011002
# Episode 271 Episodic Reward -170.0 Maximum Reward -85.0 EPSILON 0.006901790349970892
# Episode 272 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.006832772446471183
# Episode 273 Episodic Reward -158.0 Maximum Reward -85.0 EPSILON 0.006764444722006471
# Episode 274 Episodic Reward -196.0 Maximum Reward -85.0 EPSILON 0.006696800274786406
# Episode 275 Episodic Reward -111.0 Maximum Reward -85.0 EPSILON 0.006629832272038541
# Episode 276 Episodic Reward -185.0 Maximum Reward -85.0 EPSILON 0.006563533949318156
# Episode 277 Episodic Reward -116.0 Maximum Reward -85.0 EPSILON 0.006497898609824975
# Episode 278 Episodic Reward -119.0 Maximum Reward -85.0 EPSILON 0.006432919623726724
# Episode 279 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.006368590427489457
# Episode 280 Episodic Reward -164.0 Maximum Reward -85.0 EPSILON 0.006304904523214563
# Episode 281 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.006241855477982417
# Episode 282 Episodic Reward -158.0 Maximum Reward -85.0 EPSILON 0.0061794369232025925
# Episode 283 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.006117642553970567
# Episode 284 Episodic Reward -174.0 Maximum Reward -85.0 EPSILON 0.006056466128430861
# Episode 285 Episodic Reward -114.0 Maximum Reward -85.0 EPSILON 0.005995901467146553
# Episode 286 Episodic Reward -99.0 Maximum Reward -85.0 EPSILON 0.005935942452475087
# Episode 287 Episodic Reward -186.0 Maximum Reward -85.0 EPSILON 0.005876583027950337
# Episode 288 Episodic Reward -147.0 Maximum Reward -85.0 EPSILON 0.005817817197670833
# Episode 289 Episodic Reward -93.0 Maximum Reward -85.0 EPSILON 0.005759639025694124
# Episode 290 Episodic Reward -168.0 Maximum Reward -85.0 EPSILON 0.005702042635437183
# Episode 291 Episodic Reward -126.0 Maximum Reward -85.0 EPSILON 0.005645022209082811
# Episode 292 Episodic Reward -110.0 Maximum Reward -85.0 EPSILON 0.0055885719869919834
# Episode 293 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.005532686267122063
# Episode 294 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.005477359404450843
# Episode 295 Episodic Reward -166.0 Maximum Reward -85.0 EPSILON 0.005422585810406335
# Episode 296 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.005368359952302271
# Episode 297 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0053146763527792485
# Episode 298 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.005261529589251456
# Episode 299 Episodic Reward -154.0 Maximum Reward -85.0 EPSILON 0.0052089142933589416
# Episode 300 Episodic Reward -139.0 Maximum Reward -85.0 EPSILON 0.005156825150425352
# Episode 301 Episodic Reward -112.0 Maximum Reward -85.0 EPSILON 0.005105256898921099
# Episode 302 Episodic Reward -156.0 Maximum Reward -85.0 EPSILON 0.005054204329931888
# Episode 303 Episodic Reward -184.0 Maximum Reward -85.0 EPSILON 0.005003662286632569
# Episode 304 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.004953625663766243
# Episode 305 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.00490408940712858
# Episode 306 Episodic Reward -168.0 Maximum Reward -85.0 EPSILON 0.004855048513057294
# Episode 307 Episodic Reward -107.0 Maximum Reward -85.0 EPSILON 0.004806498027926721
# Episode 308 Episodic Reward -173.0 Maximum Reward -85.0 EPSILON 0.004758433047647454
# Episode 309 Episodic Reward -133.0 Maximum Reward -85.0 EPSILON 0.004710848717170979
# Episode 310 Episodic Reward -149.0 Maximum Reward -85.0 EPSILON 0.004663740229999269
# Episode 311 Episodic Reward -161.0 Maximum Reward -85.0 EPSILON 0.004617102827699277
# Episode 312 Episodic Reward -106.0 Maximum Reward -85.0 EPSILON 0.004570931799422284
# Episode 313 Episodic Reward -90.0 Maximum Reward -85.0 EPSILON 0.004525222481428061
# Episode 314 Episodic Reward -186.0 Maximum Reward -85.0 EPSILON 0.00447997025661378
# Episode 315 Episodic Reward -167.0 Maximum Reward -85.0 EPSILON 0.004435170554047642
# Episode 316 Episodic Reward -118.0 Maximum Reward -85.0 EPSILON 0.004390818848507166
# Episode 317 Episodic Reward -152.0 Maximum Reward -85.0 EPSILON 0.004346910660022094
# Episode 318 Episodic Reward -147.0 Maximum Reward -85.0 EPSILON 0.004303441553421873
# Episode 319 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.004260407137887654
# Episode 320 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.004217803066508778
# Episode 321 Episodic Reward -141.0 Maximum Reward -85.0 EPSILON 0.00417562503584369
# Episode 322 Episodic Reward -166.0 Maximum Reward -85.0 EPSILON 0.004133868785485253
# Episode 323 Episodic Reward -170.0 Maximum Reward -85.0 EPSILON 0.004092530097630401
# Episode 324 Episodic Reward -110.0 Maximum Reward -85.0 EPSILON 0.004051604796654096
# Episode 325 Episodic Reward -191.0 Maximum Reward -85.0 EPSILON 0.004011088748687555
# Episode 326 Episodic Reward -162.0 Maximum Reward -85.0 EPSILON 0.003970977861200679
# Episode 327 Episodic Reward -150.0 Maximum Reward -85.0 EPSILON 0.003931268082588672
# Episode 328 Episodic Reward -180.0 Maximum Reward -85.0 EPSILON 0.0038919554017627853
# Episode 329 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0038530358477451574
# Episode 330 Episodic Reward -105.0 Maximum Reward -85.0 EPSILON 0.003814505489267706
# Episode 331 Episodic Reward -175.0 Maximum Reward -85.0 EPSILON 0.003776360434375029
# Episode 332 Episodic Reward -123.0 Maximum Reward -85.0 EPSILON 0.0037385968300312784
# Episode 333 Episodic Reward -157.0 Maximum Reward -85.0 EPSILON 0.0037012108617309656
# Episode 334 Episodic Reward -161.0 Maximum Reward -85.0 EPSILON 0.003664198753113656
# Episode 335 Episodic Reward -178.0 Maximum Reward -85.0 EPSILON 0.0036275567655825194
# Episode 336 Episodic Reward -197.0 Maximum Reward -85.0 EPSILON 0.003591281197926694
# Episode 337 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.003555368385947427
# Episode 338 Episodic Reward -193.0 Maximum Reward -85.0 EPSILON 0.0035198147020879525
# Episode 339 Episodic Reward -100.0 Maximum Reward -85.0 EPSILON 0.003484616555067073
# Episode 340 Episodic Reward -132.0 Maximum Reward -85.0 EPSILON 0.003449770389516402
# Episode 341 Episodic Reward -151.0 Maximum Reward -85.0 EPSILON 0.003415272685621238
# Episode 342 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.003381119958765026
# Episode 343 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0033473087591773757
# Episode 344 Episodic Reward -160.0 Maximum Reward -85.0 EPSILON 0.003313835671585602
# Episode 345 Episodic Reward -133.0 Maximum Reward -85.0 EPSILON 0.003280697314869746
# Episode 346 Episodic Reward -187.0 Maximum Reward -85.0 EPSILON 0.003247890341721049
# Episode 347 Episodic Reward -117.0 Maximum Reward -85.0 EPSILON 0.003215411438303838
# Episode 348 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0031832573239207996
# Episode 349 Episodic Reward -140.0 Maximum Reward -85.0 EPSILON 0.0031514247506815914
# Episode 350 Episodic Reward -183.0 Maximum Reward -85.0 EPSILON 0.0031199105031747753
# Episode 351 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0030887113981430277
# Episode 352 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0030578242841615972
# Episode 353 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0030272460413199812
# Episode 354 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0029969735809067814
# Episode 355 Episodic Reward -183.0 Maximum Reward -85.0 EPSILON 0.0029670038450977138
# Episode 356 Episodic Reward -193.0 Maximum Reward -85.0 EPSILON 0.0029373338066467367
# Episode 357 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0029079604685802694
# Episode 358 Episodic Reward -163.0 Maximum Reward -85.0 EPSILON 0.0028788808638944667
# Episode 359 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.002850092055255522
# Episode 360 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.002821591134702967
# Episode 361 Episodic Reward -146.0 Maximum Reward -85.0 EPSILON 0.0027933752233559373
# Episode 362 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.002765441471122378
# Episode 363 Episodic Reward -141.0 Maximum Reward -85.0 EPSILON 0.002737787056411154
# Episode 364 Episodic Reward -166.0 Maximum Reward -85.0 EPSILON 0.0027104091858470426
# Episode 365 Episodic Reward -126.0 Maximum Reward -85.0 EPSILON 0.002683305093988572
# Episode 366 Episodic Reward -172.0 Maximum Reward -85.0 EPSILON 0.0026564720430486866
# Episode 367 Episodic Reward -158.0 Maximum Reward -85.0 EPSILON 0.0026299073226182
# Episode 368 Episodic Reward -158.0 Maximum Reward -85.0 EPSILON 0.0026036082493920178
# Episode 369 Episodic Reward -121.0 Maximum Reward -85.0 EPSILON 0.0025775721668980975
# Episode 370 Episodic Reward -161.0 Maximum Reward -85.0 EPSILON 0.0025517964452291164
# Episode 371 Episodic Reward -185.0 Maximum Reward -85.0 EPSILON 0.0025262784807768253
# Episode 372 Episodic Reward -145.0 Maximum Reward -85.0 EPSILON 0.0025010156959690572
# Episode 373 Episodic Reward -150.0 Maximum Reward -85.0 EPSILON 0.0024760055390093665
# Episode 374 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.002451245483619273
# Episode 375 Episodic Reward -118.0 Maximum Reward -85.0 EPSILON 0.0024267330287830804
# Episode 376 Episodic Reward -189.0 Maximum Reward -85.0 EPSILON 0.00240246569849525
# Episode 377 Episodic Reward -153.0 Maximum Reward -85.0 EPSILON 0.002378441041510297
# Episode 378 Episodic Reward -123.0 Maximum Reward -85.0 EPSILON 0.002354656631095194
# Episode 379 Episodic Reward -191.0 Maximum Reward -85.0 EPSILON 0.002331110064784242
# Episode 380 Episodic Reward -106.0 Maximum Reward -85.0 EPSILON 0.0023077989641364
# Episode 381 Episodic Reward -156.0 Maximum Reward -85.0 EPSILON 0.002284720974495036
# Episode 382 Episodic Reward -168.0 Maximum Reward -85.0 EPSILON 0.0022618737647500855
# Episode 383 Episodic Reward -91.0 Maximum Reward -85.0 EPSILON 0.002239255027102585
# Episode 384 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.002216862476831559
# Episode 385 Episodic Reward -187.0 Maximum Reward -85.0 EPSILON 0.0021946938520632435
# Episode 386 Episodic Reward -187.0 Maximum Reward -85.0 EPSILON 0.002172746913542611
# Episode 387 Episodic Reward -163.0 Maximum Reward -85.0 EPSILON 0.0021510194444071848
# Episode 388 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.002129509249963113
# Episode 389 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.002108214157463482
# Episode 390 Episodic Reward -151.0 Maximum Reward -85.0 EPSILON 0.0020871320158888473
# Episode 391 Episodic Reward -122.0 Maximum Reward -85.0 EPSILON 0.0020662606957299588
# Episode 392 Episodic Reward -156.0 Maximum Reward -85.0 EPSILON 0.002045598088772659
# Episode 393 Episodic Reward -99.0 Maximum Reward -85.0 EPSILON 0.0020251421078849325
# Episode 394 Episodic Reward -146.0 Maximum Reward -85.0 EPSILON 0.002004890686806083
# Episode 395 Episodic Reward -110.0 Maximum Reward -85.0 EPSILON 0.001984841779938022
# Episode 396 Episodic Reward -144.0 Maximum Reward -85.0 EPSILON 0.0019649933621386415
# Episode 397 Episodic Reward -158.0 Maximum Reward -85.0 EPSILON 0.001945343428517255
# Episode 398 Episodic Reward -162.0 Maximum Reward -85.0 EPSILON 0.0019258899942320826
# Episode 399 Episodic Reward -186.0 Maximum Reward -85.0 EPSILON 0.0019066310942897618
# Episode 400 Episodic Reward -177.0 Maximum Reward -85.0 EPSILON 0.0018875647833468641
# Episode 401 Episodic Reward -114.0 Maximum Reward -85.0 EPSILON 0.0018686891355133954
# Episode 402 Episodic Reward -168.0 Maximum Reward -85.0 EPSILON 0.0018500022441582614
# Episode 403 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0018315022217166787
# Episode 404 Episodic Reward -146.0 Maximum Reward -85.0 EPSILON 0.001813187199499512
# Episode 405 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0017950553275045168
# Episode 406 Episodic Reward -161.0 Maximum Reward -85.0 EPSILON 0.0017771047742294716
# Episode 407 Episodic Reward -179.0 Maximum Reward -85.0 EPSILON 0.001759333726487177
# Episode 408 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.001741740389222305
# Episode 409 Episodic Reward -197.0 Maximum Reward -85.0 EPSILON 0.001724322985330082
# Episode 410 Episodic Reward -160.0 Maximum Reward -85.0 EPSILON 0.0017070797554767812
# Episode 411 Episodic Reward -167.0 Maximum Reward -85.0 EPSILON 0.0016900089579220134
# Episode 412 Episodic Reward -105.0 Maximum Reward -85.0 EPSILON 0.0016731088683427933
# Episode 413 Episodic Reward -163.0 Maximum Reward -85.0 EPSILON 0.0016563777796593654
# Episode 414 Episodic Reward -155.0 Maximum Reward -85.0 EPSILON 0.0016398140018627717
# Episode 415 Episodic Reward -115.0 Maximum Reward -85.0 EPSILON 0.001623415861844144
# Episode 416 Episodic Reward -166.0 Maximum Reward -85.0 EPSILON 0.0016071817032257026
# Episode 417 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0015911098861934455
# Episode 418 Episodic Reward -125.0 Maximum Reward -85.0 EPSILON 0.001575198787331511
# Episode 419 Episodic Reward -135.0 Maximum Reward -85.0 EPSILON 0.001559446799458196
# Episode 420 Episodic Reward -172.0 Maximum Reward -85.0 EPSILON 0.001543852331463614
# Episode 421 Episodic Reward -116.0 Maximum Reward -85.0 EPSILON 0.0015284138081489778
# Episode 422 Episodic Reward -148.0 Maximum Reward -85.0 EPSILON 0.001513129670067488
# Episode 423 Episodic Reward -139.0 Maximum Reward -85.0 EPSILON 0.0014979983733668131
# Episode 424 Episodic Reward -176.0 Maximum Reward -85.0 EPSILON 0.001483018389633145
# Episode 425 Episodic Reward -120.0 Maximum Reward -85.0 EPSILON 0.0014681882057368135
# Episode 426 Episodic Reward -174.0 Maximum Reward -85.0 EPSILON 0.0014535063236794453
# Episode 427 Episodic Reward -152.0 Maximum Reward -85.0 EPSILON 0.0014389712604426508
# Episode 428 Episodic Reward -153.0 Maximum Reward -85.0 EPSILON 0.0014245815478382243
# Episode 429 Episodic Reward -166.0 Maximum Reward -85.0 EPSILON 0.001410335732359842
# Episode 430 Episodic Reward -164.0 Maximum Reward -85.0 EPSILON 0.0013962323750362437
# Episode 431 Episodic Reward -143.0 Maximum Reward -85.0 EPSILON 0.0013822700512858813
# Episode 432 Episodic Reward -155.0 Maximum Reward -85.0 EPSILON 0.0013684473507730225
# Episode 433 Episodic Reward -133.0 Maximum Reward -85.0 EPSILON 0.0013547628772652921
# Episode 434 Episodic Reward -157.0 Maximum Reward -85.0 EPSILON 0.0013412152484926392
# Episode 435 Episodic Reward -192.0 Maximum Reward -85.0 EPSILON 0.0013278030960077129
# Episode 436 Episodic Reward -186.0 Maximum Reward -85.0 EPSILON 0.0013145250650476357
# Episode 437 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0013013798143971594
# Episode 438 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0012883660162531878
# Episode 439 Episodic Reward -121.0 Maximum Reward -85.0 EPSILON 0.001275482356090656
# Episode 440 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0012627275325297494
# Episode 441 Episodic Reward -187.0 Maximum Reward -85.0 EPSILON 0.0012501002572044518
# Episode 442 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0012375992546324072
# Episode 443 Episodic Reward -127.0 Maximum Reward -85.0 EPSILON 0.0012252232620860832
# Episode 444 Episodic Reward -91.0 Maximum Reward -85.0 EPSILON 0.0012129710294652223
# Episode 445 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0012008413191705702
# Episode 446 Episodic Reward -129.0 Maximum Reward -85.0 EPSILON 0.0011888329059788645
# Episode 447 Episodic Reward -165.0 Maximum Reward -85.0 EPSILON 0.001176944576919076
# Episode 448 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0011651751311498853
# Episode 449 Episodic Reward -187.0 Maximum Reward -85.0 EPSILON 0.0011535233798383865
# Episode 450 Episodic Reward -175.0 Maximum Reward -85.0 EPSILON 0.0011419881460400026
# Episode 451 Episodic Reward -165.0 Maximum Reward -85.0 EPSILON 0.0011305682645796026
# Episode 452 Episodic Reward -178.0 Maximum Reward -85.0 EPSILON 0.0011192625819338065
# Episode 453 Episodic Reward -118.0 Maximum Reward -85.0 EPSILON 0.0011080699561144684
# Episode 454 Episodic Reward -180.0 Maximum Reward -85.0 EPSILON 0.0010969892565533238
# Episode 455 Episodic Reward -157.0 Maximum Reward -85.0 EPSILON 0.0010860193639877906
# Episode 456 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0010751591703479127
# Episode 457 Episodic Reward -158.0 Maximum Reward -85.0 EPSILON 0.0010644075786444334
# Episode 458 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.001053763502857989
# Episode 459 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.001043225867829409
# Episode 460 Episodic Reward -181.0 Maximum Reward -85.0 EPSILON 0.001032793609151115
# Episode 461 Episodic Reward -121.0 Maximum Reward -85.0 EPSILON 0.0010224656730596037
# Episode 462 Episodic Reward -132.0 Maximum Reward -85.0 EPSILON 0.0010122410163290077
# Episode 463 Episodic Reward -109.0 Maximum Reward -85.0 EPSILON 0.0010021186061657176
# Episode 464 Episodic Reward -112.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 465 Episodic Reward -86.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 466 Episodic Reward -153.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 467 Episodic Reward -195.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 468 Episodic Reward -195.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 469 Episodic Reward -182.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 470 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 471 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 472 Episodic Reward -124.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 473 Episodic Reward -120.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 474 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 475 Episodic Reward -124.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 476 Episodic Reward -146.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 477 Episodic Reward -163.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 478 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 479 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 480 Episodic Reward -151.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 481 Episodic Reward -194.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 482 Episodic Reward -170.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 483 Episodic Reward -183.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 484 Episodic Reward -174.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 485 Episodic Reward -154.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 486 Episodic Reward -110.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 487 Episodic Reward -123.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 488 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 489 Episodic Reward -141.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 490 Episodic Reward -103.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 491 Episodic Reward -176.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 492 Episodic Reward -125.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 493 Episodic Reward -156.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 494 Episodic Reward -120.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 495 Episodic Reward -186.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 496 Episodic Reward -147.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 497 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 498 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 499 Episodic Reward -171.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 500 Episodic Reward -167.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 501 Episodic Reward -125.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 502 Episodic Reward -111.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 503 Episodic Reward -125.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 504 Episodic Reward -163.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 505 Episodic Reward -146.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 506 Episodic Reward -178.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 507 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 508 Episodic Reward -158.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 509 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 510 Episodic Reward -146.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 511 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 512 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 513 Episodic Reward -197.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 514 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 515 Episodic Reward -140.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 516 Episodic Reward -177.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 517 Episodic Reward -162.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 518 Episodic Reward -180.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 519 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 520 Episodic Reward -184.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 521 Episodic Reward -183.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 522 Episodic Reward -179.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 523 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 524 Episodic Reward -136.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 525 Episodic Reward -171.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 526 Episodic Reward -143.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 527 Episodic Reward -87.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 528 Episodic Reward -93.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 529 Episodic Reward -162.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 530 Episodic Reward -145.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 531 Episodic Reward -156.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 532 Episodic Reward -93.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 533 Episodic Reward -105.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 534 Episodic Reward -89.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 535 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 536 Episodic Reward -173.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 537 Episodic Reward -159.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 538 Episodic Reward -176.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 539 Episodic Reward -129.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 540 Episodic Reward -174.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 541 Episodic Reward -186.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 542 Episodic Reward -174.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 543 Episodic Reward -148.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 544 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 545 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 546 Episodic Reward -165.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 547 Episodic Reward -113.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 548 Episodic Reward -157.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 549 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 550 Episodic Reward -165.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 551 Episodic Reward -176.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 552 Episodic Reward -91.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 553 Episodic Reward -166.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 554 Episodic Reward -199.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 555 Episodic Reward -97.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 556 Episodic Reward -172.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 557 Episodic Reward -147.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 558 Episodic Reward -100.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 559 Episodic Reward -165.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 560 Episodic Reward -158.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 561 Episodic Reward -158.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 562 Episodic Reward -184.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 563 Episodic Reward -129.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 564 Episodic Reward -121.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 565 Episodic Reward -129.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 566 Episodic Reward -114.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 567 Episodic Reward -86.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 568 Episodic Reward -89.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 569 Episodic Reward -148.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 570 Episodic Reward -109.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 571 Episodic Reward -174.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 572 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 573 Episodic Reward -166.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 574 Episodic Reward -97.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 575 Episodic Reward -91.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 576 Episodic Reward -140.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 577 Episodic Reward -117.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 578 Episodic Reward -115.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 579 Episodic Reward -137.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 580 Episodic Reward -172.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 581 Episodic Reward -144.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 582 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 583 Episodic Reward -171.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 584 Episodic Reward -160.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 585 Episodic Reward -88.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 586 Episodic Reward -200.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 587 Episodic Reward -97.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 588 Episodic Reward -176.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 589 Episodic Reward -153.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 590 Episodic Reward -192.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 591 Episodic Reward -153.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 592 Episodic Reward -146.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 593 Episodic Reward -138.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 594 Episodic Reward -119.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 595 Episodic Reward -86.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 596 Episodic Reward -143.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 597 Episodic Reward -130.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 598 Episodic Reward -157.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604
# Episode 599 Episodic Reward -98.0 Maximum Reward -85.0 EPSILON 0.0009920974201040604

# %%
import pandas as pd

# %% [markdown]
# # Plots [Section 7.3]

# %%
# plot Rewards vs Episodes
plt.plot(rewards)
plt.title('Rewards per Episode')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.grid(True)
plt.show()

# plot Mean of Rewards with window size 10
data = rewards
data_series = pd.Series(data)
window_size = 10
moving_average = data_series.rolling(window=window_size).mean()

plt.figure(figsize=(12, 6))
plt.plot(data, label='Original Data')
plt.plot(moving_average, label='Mean of Rewards', linewidth=2)
plt.title("Mean of Rewards Over Time")
plt.xlabel("Episode")
plt.ylabel("Rewards")
plt.legend()
plt.show()

# plot Movig average of rewards over 600 episodes with window size 50
mean_rewards = np.zeros(600)
for t in range(600):
    mean_rewards[t] = np.mean(rewards[max(0,t-50):(t+1)])
plt.plot(mean_rewards)
plt.title("Moving average of Rewards Over last 50 Episodes")
plt.xlabel("Episodes")
plt.ylabel("Rewards")
plt.show()


# plot Epsilon Decay Over Episodes
epsilons = [EPSILON * (EPSILON_DECAY ** episode) for episode in range(EPISODES)]

# plot Episode Lengths Over Time
plt.figure(figsize=(10, 6))
plt.plot(epsilons)
plt.title("Epsilon Decay Over Episodes")
plt.xlabel("Episode")
plt.ylabel("Epsilon")
plt.show()

# plot Episode Lengths Over Time
plt.figure(figsize=(10, 6))
plt.plot(episode_lengths)
plt.title("Episode Lengths(steps) Over Time")
plt.xlabel("Episode")
plt.ylabel("Length")
plt.show()
